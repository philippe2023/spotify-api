# %%
import config
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                            client_secret= config.client_secret))

# %%
playlist_rock = sp.user_playlist_tracks("spotify", "37i9dQZF1DX3oM43CtKnRV",market="DE")
playlist_rock
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3oM43CtKnRV/tracks?offset=0&limit=100&market=DE&additional_types=track',
#  'items': [{'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/b5ee275ca337899f762b1c1883c11e24a04075b0?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2pKw6GERJVAD61449B1EEM',
#      'id': '2pKw6GERJVAD61449B1EEM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736741ca6e9ba6fdc166037321',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026741ca6e9ba6fdc166037321',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516741ca6e9ba6fdc166037321',
#        'width': 64}],
#      'name': 'Hybrid Theory',
#      'release_date': '2000',
#      'release_date_precision': 'year',
#      'uri': 'spotify:album:2pKw6GERJVAD61449B1EEM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#        'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#        'id': '6XyY86QOPPrYVGvF9ch6wz',
#        'name': 'Linkin Park',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2pKw6GERJVAD61449B1EEM'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#       'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#       'id': '6XyY86QOPPrYVGvF9ch6wz',
#       'name': 'Linkin Park',
#       'type': 'artist',
#       'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#     'disc_number': 1,
#     'track_number': 8,
#     'duration_ms': 216800,
#     'external_ids': {'isrc': 'USWB10002407'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3tSmXSxaAnU1EPGKa6NytH'},
#     'href': 'https://api.spotify.com/v1/tracks/3tSmXSxaAnU1EPGKa6NytH',
#     'id': '60a0Rd6pjrkxjPbaKzXjfq',
#     'name': 'In the End',
#     'popularity': 64,
#     'uri': 'spotify:track:60a0Rd6pjrkxjPbaKzXjfq',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3tSmXSxaAnU1EPGKa6NytH'},
#      'href': 'https://api.spotify.com/v1/tracks/3tSmXSxaAnU1EPGKa6NytH',
#      'id': '3tSmXSxaAnU1EPGKa6NytH',
#      'type': 'track',
#      'uri': 'spotify:track:3tSmXSxaAnU1EPGKa6NytH'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/dfac967b275f7fe44e71e037f78c0e205515c78b?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5Qhn2FpGWmTjCuntF09j7g',
#      'id': '5Qhn2FpGWmTjCuntF09j7g',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739079e678be6b947cc2b3b5c6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029079e678be6b947cc2b3b5c6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519079e678be6b947cc2b3b5c6',
#        'width': 64}],
#      'name': 'American Idiot - Deluxe',
#      'release_date': '2004-09-21',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5Qhn2FpGWmTjCuntF09j7g',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#        'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#        'id': '7oPftvlwr6VrsViSDV7fJY',
#        'name': 'Green Day',
#        'type': 'artist',
#        'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Qhn2FpGWmTjCuntF09j7g'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#       'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#       'id': '7oPftvlwr6VrsViSDV7fJY',
#       'name': 'Green Day',
#       'type': 'artist',
#       'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 174320,
#     'external_ids': {'isrc': 'USRE10400888'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/45zvStEMsXp8z45OQRhWFJ'},
#     'href': 'https://api.spotify.com/v1/tracks/45zvStEMsXp8z45OQRhWFJ',
#     'id': '45zvStEMsXp8z45OQRhWFJ',
#     'name': 'American Idiot',
#     'popularity': 61,
#     'uri': 'spotify:track:45zvStEMsXp8z45OQRhWFJ',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/1b3bc0aca1746a99cbb8dd07b2325f6499b58a2e?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/6deiaArbeoqp1xPEGdEKp1',
#      'id': '6deiaArbeoqp1xPEGdEKp1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de1af2785a83cc660155a0c4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de1af2785a83cc660155a0c4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de1af2785a83cc660155a0c4',
#        'width': 64}],
#      'name': 'By the Way (Deluxe Edition)',
#      'release_date': '2002-07-09',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6deiaArbeoqp1xPEGdEKp1',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6deiaArbeoqp1xPEGdEKp1'},
#      'total_tracks': 18},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#       'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#       'id': '0L8ExT028jH3ddEcZwqJJ5',
#       'name': 'Red Hot Chili Peppers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#     'disc_number': 1,
#     'track_number': 7,
#     'duration_ms': 269000,
#     'external_ids': {'isrc': 'USWB10201694'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ZOEytgrvLwQaqXreDs2Jx'},
#     'href': 'https://api.spotify.com/v1/tracks/3ZOEytgrvLwQaqXreDs2Jx',
#     'id': '3ZOEytgrvLwQaqXreDs2Jx',
#     'name': "Can't Stop",
#     'popularity': 84,
#     'uri': 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/d9b89161dacbb987b360417346591712c4023abd?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/6jWde94ln40epKIQCd8XUh',
#      'id': '6jWde94ln40epKIQCd8XUh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27330d45198d0c9e8841f9a9578',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0230d45198d0c9e8841f9a9578',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485130d45198d0c9e8841f9a9578',
#        'width': 64}],
#      'name': 'Toxicity',
#      'release_date': '2001-09-04',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6jWde94ln40epKIQCd8XUh',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#        'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#        'id': '5eAWCfyUhZtHHtBdNk56l1',
#        'name': 'System Of A Down',
#        'type': 'artist',
#        'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6jWde94ln40epKIQCd8XUh'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#       'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#       'id': '5eAWCfyUhZtHHtBdNk56l1',
#       'name': 'System Of A Down',
#       'type': 'artist',
#       'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#     'disc_number': 1,
#     'track_number': 12,
#     'duration_ms': 218933,
#     'external_ids': {'isrc': 'USSM10107262'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0snQkGI5qnAmohLE7jTsTn'},
#     'href': 'https://api.spotify.com/v1/tracks/0snQkGI5qnAmohLE7jTsTn',
#     'id': '0snQkGI5qnAmohLE7jTsTn',
#     'name': 'Toxicity',
#     'popularity': 84,
#     'uri': 'spotify:track:0snQkGI5qnAmohLE7jTsTn',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/02w1xMzzdF2OJxTeh1basm',
#      'id': '02w1xMzzdF2OJxTeh1basm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27325f49ab23f0ec6332efef432',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0225f49ab23f0ec6332efef432',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485125f49ab23f0ec6332efef432',
#        'width': 64}],
#      'name': 'Fallen',
#      'release_date': '2003-03-04',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:02w1xMzzdF2OJxTeh1basm',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nGIFgo0shDenQYSE0Sn7c'},
#        'href': 'https://api.spotify.com/v1/artists/5nGIFgo0shDenQYSE0Sn7c',
#        'id': '5nGIFgo0shDenQYSE0Sn7c',
#        'name': 'Evanescence',
#        'type': 'artist',
#        'uri': 'spotify:artist:5nGIFgo0shDenQYSE0Sn7c'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/02w1xMzzdF2OJxTeh1basm'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nGIFgo0shDenQYSE0Sn7c'},
#       'href': 'https://api.spotify.com/v1/artists/5nGIFgo0shDenQYSE0Sn7c',
#       'id': '5nGIFgo0shDenQYSE0Sn7c',
#       'name': 'Evanescence',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nGIFgo0shDenQYSE0Sn7c'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 235893,
#     'external_ids': {'isrc': 'USWU30200093'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0COqiPhxzoWICwFCS4eZcp'},
#     'href': 'https://api.spotify.com/v1/tracks/0COqiPhxzoWICwFCS4eZcp',
#     'id': '0COqiPhxzoWICwFCS4eZcp',
#     'name': 'Bring Me To Life',
#     'popularity': 83,
#     'uri': 'spotify:track:0COqiPhxzoWICwFCS4eZcp',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/6806855988e246016413cc8a34a2afe862f3988d?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5CZR6ljD0x9fTiS4mh9wMp',
#      'id': '5CZR6ljD0x9fTiS4mh9wMp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732519d01c0cca06f134eeadd8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022519d01c0cca06f134eeadd8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512519d01c0cca06f134eeadd8',
#        'width': 64}],
#      'name': 'Only By The Night',
#      'release_date': '2008-09-23',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5CZR6ljD0x9fTiS4mh9wMp',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#        'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#        'id': '2qk9voo8llSGYcZ6xrBzKx',
#        'name': 'Kings of Leon',
#        'type': 'artist',
#        'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5CZR6ljD0x9fTiS4mh9wMp'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#       'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#       'id': '2qk9voo8llSGYcZ6xrBzKx',
#       'name': 'Kings of Leon',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 203346,
#     'external_ids': {'isrc': 'USRC10800300'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ntQJM78wzOLVeCUAW7Y45'},
#     'href': 'https://api.spotify.com/v1/tracks/0ntQJM78wzOLVeCUAW7Y45',
#     'id': '0ntQJM78wzOLVeCUAW7Y45',
#     'name': 'Sex on Fire',
#     'popularity': 84,
#     'uri': 'spotify:track:0ntQJM78wzOLVeCUAW7Y45',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/529eb48df232955cdd3b870f21e2bd41f1657fae?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0eFHYz8NmK75zSplL5qlfM',
#      'id': '0eFHYz8NmK75zSplL5qlfM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b6d4566db0d12894a1a3b7a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b6d4566db0d12894a1a3b7a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b6d4566db0d12894a1a3b7a2',
#        'width': 64}],
#      'name': 'The Resistance',
#      'release_date': '2009-09-10',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0eFHYz8NmK75zSplL5qlfM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#        'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#        'id': '12Chz98pHFMPJEknJQMWvI',
#        'name': 'Muse',
#        'type': 'artist',
#        'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0eFHYz8NmK75zSplL5qlfM'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#       'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#       'id': '12Chz98pHFMPJEknJQMWvI',
#       'name': 'Muse',
#       'type': 'artist',
#       'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 304840,
#     'external_ids': {'isrc': 'GBAHT0900320'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4VqPOruhp5EdPBeR92t6lQ'},
#     'href': 'https://api.spotify.com/v1/tracks/4VqPOruhp5EdPBeR92t6lQ',
#     'id': '4VqPOruhp5EdPBeR92t6lQ',
#     'name': 'Uprising',
#     'popularity': 75,
#     'uri': 'spotify:track:4VqPOruhp5EdPBeR92t6lQ',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/ba87b3463a795afa81ee18d3fbb116bb7793140e?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3UoOO8m0oxxvUHXUKf3qcZ',
#      'id': '3UoOO8m0oxxvUHXUKf3qcZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27369966efa45b125ed6711b43c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0269966efa45b125ed6711b43c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485169966efa45b125ed6711b43c',
#        'width': 64}],
#      'name': 'Riot!',
#      'release_date': '2007-06-11',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3UoOO8m0oxxvUHXUKf3qcZ',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74XFHRwlV6OrjEM0A2NCMF'},
#        'href': 'https://api.spotify.com/v1/artists/74XFHRwlV6OrjEM0A2NCMF',
#        'id': '74XFHRwlV6OrjEM0A2NCMF',
#        'name': 'Paramore',
#        'type': 'artist',
#        'uri': 'spotify:artist:74XFHRwlV6OrjEM0A2NCMF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3UoOO8m0oxxvUHXUKf3qcZ'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74XFHRwlV6OrjEM0A2NCMF'},
#       'href': 'https://api.spotify.com/v1/artists/74XFHRwlV6OrjEM0A2NCMF',
#       'id': '74XFHRwlV6OrjEM0A2NCMF',
#       'name': 'Paramore',
#       'type': 'artist',
#       'uri': 'spotify:artist:74XFHRwlV6OrjEM0A2NCMF'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 211520,
#     'external_ids': {'isrc': 'USAT20702617'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3l9CW99AHtExIRV4hW2N5m'},
#     'href': 'https://api.spotify.com/v1/tracks/3l9CW99AHtExIRV4hW2N5m',
#     'id': '3l9CW99AHtExIRV4hW2N5m',
#     'name': 'Misery Business',
#     'popularity': 73,
#     'uri': 'spotify:track:3l9CW99AHtExIRV4hW2N5m',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/94fd201045f5b682935957a8206075638dc4622d?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5HOTlQx62uQqxRvR1MVIzb',
#      'id': '5HOTlQx62uQqxRvR1MVIzb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735f18910ec86e3ecbbc2fd2cb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025f18910ec86e3ecbbc2fd2cb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515f18910ec86e3ecbbc2fd2cb',
#        'width': 64}],
#      'name': 'Silver Side Up',
#      'release_date': '2001-09-11',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5HOTlQx62uQqxRvR1MVIzb',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6deZN1bslXzeGvOLaLMOIF'},
#        'href': 'https://api.spotify.com/v1/artists/6deZN1bslXzeGvOLaLMOIF',
#        'id': '6deZN1bslXzeGvOLaLMOIF',
#        'name': 'Nickelback',
#        'type': 'artist',
#        'uri': 'spotify:artist:6deZN1bslXzeGvOLaLMOIF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5HOTlQx62uQqxRvR1MVIzb'},
#      'total_tracks': 10},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6deZN1bslXzeGvOLaLMOIF'},
#       'href': 'https://api.spotify.com/v1/artists/6deZN1bslXzeGvOLaLMOIF',
#       'id': '6deZN1bslXzeGvOLaLMOIF',
#       'name': 'Nickelback',
#       'type': 'artist',
#       'uri': 'spotify:artist:6deZN1bslXzeGvOLaLMOIF'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 223826,
#     'external_ids': {'isrc': 'NLA320119533'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0F2nGhgFNlkVHm81zNEvW6'},
#     'href': 'https://api.spotify.com/v1/tracks/0F2nGhgFNlkVHm81zNEvW6',
#     'id': '0gmbgwZ8iqyMPmXefof8Yf',
#     'name': 'How You Remind Me',
#     'popularity': 0,
#     'uri': 'spotify:track:0gmbgwZ8iqyMPmXefof8Yf',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0F2nGhgFNlkVHm81zNEvW6'},
#      'href': 'https://api.spotify.com/v1/tracks/0F2nGhgFNlkVHm81zNEvW6',
#      'id': '0F2nGhgFNlkVHm81zNEvW6',
#      'type': 'track',
#      'uri': 'spotify:track:0F2nGhgFNlkVHm81zNEvW6'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/46d898c23fb28b9f52abf78b794aa500988d2132?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/78guAsers0klWl6RwzgDLd',
#      'id': '78guAsers0klWl6RwzgDLd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a7292b6863258e889b78d787',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a7292b6863258e889b78d787',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a7292b6863258e889b78d787',
#        'width': 64}],
#      'name': 'Audioslave',
#      'release_date': '2002-11-17',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:78guAsers0klWl6RwzgDLd',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ziB7fzrXBoh1HUPS6sVFn'},
#        'href': 'https://api.spotify.com/v1/artists/2ziB7fzrXBoh1HUPS6sVFn',
#        'id': '2ziB7fzrXBoh1HUPS6sVFn',
#        'name': 'Audioslave',
#        'type': 'artist',
#        'uri': 'spotify:artist:2ziB7fzrXBoh1HUPS6sVFn'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/78guAsers0klWl6RwzgDLd'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ziB7fzrXBoh1HUPS6sVFn'},
#       'href': 'https://api.spotify.com/v1/artists/2ziB7fzrXBoh1HUPS6sVFn',
#       'id': '2ziB7fzrXBoh1HUPS6sVFn',
#       'name': 'Audioslave',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ziB7fzrXBoh1HUPS6sVFn'}],
#     'disc_number': 1,
#     'track_number': 5,
#     'duration_ms': 293960,
#     'external_ids': {'isrc': 'USSM10211587'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3YuaBvuZqcwN3CEAyyoaei'},
#     'href': 'https://api.spotify.com/v1/tracks/3YuaBvuZqcwN3CEAyyoaei',
#     'id': '2MrWu3Gt6ucsOHC6eE8oLV',
#     'name': 'Like a Stone',
#     'popularity': 78,
#     'uri': 'spotify:track:2MrWu3Gt6ucsOHC6eE8oLV',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3YuaBvuZqcwN3CEAyyoaei'},
#      'href': 'https://api.spotify.com/v1/tracks/3YuaBvuZqcwN3CEAyyoaei',
#      'id': '3YuaBvuZqcwN3CEAyyoaei',
#      'type': 'track',
#      'uri': 'spotify:track:3YuaBvuZqcwN3CEAyyoaei'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/f91cfdf3dd5f7114cf47f8c8b2567b7a8a76d9ed?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/03akiuheNt5mJqltALnalP',
#      'id': '03akiuheNt5mJqltALnalP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27368f87064692961d17e3f3766',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0268f87064692961d17e3f3766',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485168f87064692961d17e3f3766',
#        'width': 64}],
#      'name': 'Franz Ferdinand',
#      'release_date': '2004-02-16',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:03akiuheNt5mJqltALnalP',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XNa1vTidXlvJ2gHSsRi4A'},
#        'href': 'https://api.spotify.com/v1/artists/0XNa1vTidXlvJ2gHSsRi4A',
#        'id': '0XNa1vTidXlvJ2gHSsRi4A',
#        'name': 'Franz Ferdinand',
#        'type': 'artist',
#        'uri': 'spotify:artist:0XNa1vTidXlvJ2gHSsRi4A'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/03akiuheNt5mJqltALnalP'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XNa1vTidXlvJ2gHSsRi4A'},
#       'href': 'https://api.spotify.com/v1/artists/0XNa1vTidXlvJ2gHSsRi4A',
#       'id': '0XNa1vTidXlvJ2gHSsRi4A',
#       'name': 'Franz Ferdinand',
#       'type': 'artist',
#       'uri': 'spotify:artist:0XNa1vTidXlvJ2gHSsRi4A'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 237026,
#     'external_ids': {'isrc': 'GBCEL0300192'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ancVQ9wEcHVd0RrGICTE4'},
#     'href': 'https://api.spotify.com/v1/tracks/0ancVQ9wEcHVd0RrGICTE4',
#     'id': '20I8RduZC2PWMWTDCZuuAN',
#     'name': 'Take Me Out',
#     'popularity': 0,
#     'uri': 'spotify:track:20I8RduZC2PWMWTDCZuuAN',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0ancVQ9wEcHVd0RrGICTE4'},
#      'href': 'https://api.spotify.com/v1/tracks/0ancVQ9wEcHVd0RrGICTE4',
#      'id': '0ancVQ9wEcHVd0RrGICTE4',
#      'type': 'track',
#      'uri': 'spotify:track:0ancVQ9wEcHVd0RrGICTE4'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/eca519f0a85862d9510d57d59df557081d375e3a?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/48Atx1uS9J4KL5iQt3weoS',
#      'id': '48Atx1uS9J4KL5iQt3weoS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273588ca88c368d5f6eae5cb9b1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02588ca88c368d5f6eae5cb9b1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851588ca88c368d5f6eae5cb9b1',
#        'width': 64}],
#      'name': 'Elephant',
#      'release_date': '2003-04-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:48Atx1uS9J4KL5iQt3weoS',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#        'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#        'id': '4F84IBURUo98rz4r61KF70',
#        'name': 'The White Stripes',
#        'type': 'artist',
#        'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/48Atx1uS9J4KL5iQt3weoS'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#       'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#       'id': '4F84IBURUo98rz4r61KF70',
#       'name': 'The White Stripes',
#       'type': 'artist',
#       'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 231733,
#     'external_ids': {'isrc': 'USVT10300001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7i6r9KotUPQg3ozKKgEPIN'},
#     'href': 'https://api.spotify.com/v1/tracks/7i6r9KotUPQg3ozKKgEPIN',
#     'id': '3dPQuX8Gs42Y7b454ybpMR',
#     'name': 'Seven Nation Army',
#     'popularity': 2,
#     'uri': 'spotify:track:3dPQuX8Gs42Y7b454ybpMR',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7i6r9KotUPQg3ozKKgEPIN'},
#      'href': 'https://api.spotify.com/v1/tracks/7i6r9KotUPQg3ozKKgEPIN',
#      'id': '7i6r9KotUPQg3ozKKgEPIN',
#      'type': 'track',
#      'uri': 'spotify:track:7i6r9KotUPQg3ozKKgEPIN'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/e6d0c0da5d86b2d19ee4456344ac9527a72b2a7d?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0FZK97MXMm5mUQ8mtudjuK',
#      'id': '0FZK97MXMm5mUQ8mtudjuK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27317f77fab7e8f18d5f9fee4a1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0217f77fab7e8f18d5f9fee4a1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485117f77fab7e8f18d5f9fee4a1',
#        'width': 64}],
#      'name': 'The Black Parade',
#      'release_date': '2006-10-23',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0FZK97MXMm5mUQ8mtudjuK',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FBcuc1gsnv6Y1nwFtNRCb'},
#        'href': 'https://api.spotify.com/v1/artists/7FBcuc1gsnv6Y1nwFtNRCb',
#        'id': '7FBcuc1gsnv6Y1nwFtNRCb',
#        'name': 'My Chemical Romance',
#        'type': 'artist',
#        'uri': 'spotify:artist:7FBcuc1gsnv6Y1nwFtNRCb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0FZK97MXMm5mUQ8mtudjuK'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FBcuc1gsnv6Y1nwFtNRCb'},
#       'href': 'https://api.spotify.com/v1/artists/7FBcuc1gsnv6Y1nwFtNRCb',
#       'id': '7FBcuc1gsnv6Y1nwFtNRCb',
#       'name': 'My Chemical Romance',
#       'type': 'artist',
#       'uri': 'spotify:artist:7FBcuc1gsnv6Y1nwFtNRCb'}],
#     'disc_number': 1,
#     'track_number': 11,
#     'duration_ms': 161920,
#     'external_ids': {'isrc': 'USRE10602912'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7j31rVgGX9Q2blT92VBEA0'},
#     'href': 'https://api.spotify.com/v1/tracks/7j31rVgGX9Q2blT92VBEA0',
#     'id': '7j31rVgGX9Q2blT92VBEA0',
#     'name': 'Teenagers',
#     'popularity': 80,
#     'uri': 'spotify:track:7j31rVgGX9Q2blT92VBEA0',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/a6c3822f2022bda6d8067f0e9b62a55368130009?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/38pfSOHvxHqDWwDnjZ25U5',
#      'id': '38pfSOHvxHqDWwDnjZ25U5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d3f7fc260cd67d23844ce2c0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d3f7fc260cd67d23844ce2c0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d3f7fc260cd67d23844ce2c0',
#        'width': 64}],
#      'name': 'Three Days Grace (Expanded Edition)',
#      'release_date': '2003-07-22',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:38pfSOHvxHqDWwDnjZ25U5',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xiIXseIJcq3nG7C8fHeBj'},
#        'href': 'https://api.spotify.com/v1/artists/2xiIXseIJcq3nG7C8fHeBj',
#        'id': '2xiIXseIJcq3nG7C8fHeBj',
#        'name': 'Three Days Grace',
#        'type': 'artist',
#        'uri': 'spotify:artist:2xiIXseIJcq3nG7C8fHeBj'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/38pfSOHvxHqDWwDnjZ25U5'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xiIXseIJcq3nG7C8fHeBj'},
#       'href': 'https://api.spotify.com/v1/artists/2xiIXseIJcq3nG7C8fHeBj',
#       'id': '2xiIXseIJcq3nG7C8fHeBj',
#       'name': 'Three Days Grace',
#       'type': 'artist',
#       'uri': 'spotify:artist:2xiIXseIJcq3nG7C8fHeBj'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 231480,
#     'external_ids': {'isrc': 'USJI10300075'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6rUp7v3l8yC4TKxAAR5Bmx'},
#     'href': 'https://api.spotify.com/v1/tracks/6rUp7v3l8yC4TKxAAR5Bmx',
#     'id': '6rUp7v3l8yC4TKxAAR5Bmx',
#     'name': 'I Hate Everything About You',
#     'popularity': 70,
#     'uri': 'spotify:track:6rUp7v3l8yC4TKxAAR5Bmx',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/da276bb82ad6800f85b825b6f901b29d340f3cdc?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/7eTQgEAeaCqyXRD08qHty9',
#      'id': '7eTQgEAeaCqyXRD08qHty9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f1492c6bd28566e9d956c48b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f1492c6bd28566e9d956c48b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f1492c6bd28566e9d956c48b',
#        'width': 64}],
#      'name': 'Brand New Eyes (Deluxe Edition)',
#      'release_date': '2009-09-28',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:7eTQgEAeaCqyXRD08qHty9',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74XFHRwlV6OrjEM0A2NCMF'},
#        'href': 'https://api.spotify.com/v1/artists/74XFHRwlV6OrjEM0A2NCMF',
#        'id': '74XFHRwlV6OrjEM0A2NCMF',
#        'name': 'Paramore',
#        'type': 'artist',
#        'uri': 'spotify:artist:74XFHRwlV6OrjEM0A2NCMF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7eTQgEAeaCqyXRD08qHty9'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74XFHRwlV6OrjEM0A2NCMF'},
#       'href': 'https://api.spotify.com/v1/artists/74XFHRwlV6OrjEM0A2NCMF',
#       'id': '74XFHRwlV6OrjEM0A2NCMF',
#       'name': 'Paramore',
#       'type': 'artist',
#       'uri': 'spotify:artist:74XFHRwlV6OrjEM0A2NCMF'}],
#     'disc_number': 1,
#     'track_number': 12,
#     'duration_ms': 261959,
#     'external_ids': {'isrc': 'USAT20804057'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6umX518VohIob6IipK3WYM'},
#     'href': 'https://api.spotify.com/v1/tracks/6umX518VohIob6IipK3WYM',
#     'id': '4IDfVjI1TlB1UwlC01T4Bm',
#     'name': 'Decode - Twilight Soundtrack Version',
#     'popularity': 38,
#     'uri': 'spotify:track:4IDfVjI1TlB1UwlC01T4Bm',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6umX518VohIob6IipK3WYM'},
#      'href': 'https://api.spotify.com/v1/tracks/6umX518VohIob6IipK3WYM',
#      'id': '6umX518VohIob6IipK3WYM',
#      'type': 'track',
#      'uri': 'spotify:track:6umX518VohIob6IipK3WYM'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/d536012652d7c99c472fe3811312ce3026f2196b?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/7JCeEZz5cHwIxnu7n0nFxM',
#      'id': '7JCeEZz5cHwIxnu7n0nFxM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273055bc208d4434f9bf2de5774',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02055bc208d4434f9bf2de5774',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851055bc208d4434f9bf2de5774',
#        'width': 64}],
#      'name': 'Toxicity',
#      'release_date': '2001-09-04',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:7JCeEZz5cHwIxnu7n0nFxM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#        'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#        'id': '5eAWCfyUhZtHHtBdNk56l1',
#        'name': 'System Of A Down',
#        'type': 'artist',
#        'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7JCeEZz5cHwIxnu7n0nFxM'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#       'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#       'id': '5eAWCfyUhZtHHtBdNk56l1',
#       'name': 'System Of A Down',
#       'type': 'artist',
#       'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#     'disc_number': 1,
#     'track_number': 6,
#     'duration_ms': 210240,
#     'external_ids': {'isrc': 'USSM10107256'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7kwiwQhWRBSP1PJv4ZFJUK'},
#     'href': 'https://api.spotify.com/v1/tracks/7kwiwQhWRBSP1PJv4ZFJUK',
#     'id': '2DlHlPMa4M17kufBvI2lEN',
#     'name': 'Chop Suey!',
#     'popularity': 0,
#     'uri': 'spotify:track:2DlHlPMa4M17kufBvI2lEN',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7kwiwQhWRBSP1PJv4ZFJUK'},
#      'href': 'https://api.spotify.com/v1/tracks/7kwiwQhWRBSP1PJv4ZFJUK',
#      'id': '7kwiwQhWRBSP1PJv4ZFJUK',
#      'type': 'track',
#      'uri': 'spotify:track:7kwiwQhWRBSP1PJv4ZFJUK'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bb5a97b64d61c8920674717ca753752eee008b95?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2tlTBLz2w52rpGCLBGyGw6',
#      'id': '2tlTBLz2w52rpGCLBGyGw6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736e996745f2c7b8036abef213',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026e996745f2c7b8036abef213',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516e996745f2c7b8036abef213',
#        'width': 64}],
#      'name': 'Minutes to Midnight',
#      'release_date': '2007-05-14',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2tlTBLz2w52rpGCLBGyGw6',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#        'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#        'id': '6XyY86QOPPrYVGvF9ch6wz',
#        'name': 'Linkin Park',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2tlTBLz2w52rpGCLBGyGw6'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#       'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#       'id': '6XyY86QOPPrYVGvF9ch6wz',
#       'name': 'Linkin Park',
#       'type': 'artist',
#       'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#     'disc_number': 1,
#     'track_number': 6,
#     'duration_ms': 205226,
#     'external_ids': {'isrc': 'USWB10700721'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/18lR4BzEs7e3qzc0KVkTpU'},
#     'href': 'https://api.spotify.com/v1/tracks/18lR4BzEs7e3qzc0KVkTpU',
#     'id': '18lR4BzEs7e3qzc0KVkTpU',
#     'name': "What I've Done",
#     'popularity': 82,
#     'uri': 'spotify:track:18lR4BzEs7e3qzc0KVkTpU',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/258775e7324ab09be650b91d322d22948ed9df1a?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'compilation',
#      'href': 'https://api.spotify.com/v1/albums/3id4t9IqRoB1f1smOERtrY',
#      'id': '3id4t9IqRoB1f1smOERtrY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737f213369d5265a60af5f7e82',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027f213369d5265a60af5f7e82',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517f213369d5265a60af5f7e82',
#        'width': 64}],
#      'name': "Greatest Hits: God's Favorite Band",
#      'release_date': '2017-11-17',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3id4t9IqRoB1f1smOERtrY',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#        'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#        'id': '7oPftvlwr6VrsViSDV7fJY',
#        'name': 'Green Day',
#        'type': 'artist',
#        'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3id4t9IqRoB1f1smOERtrY'},
#      'total_tracks': 22},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#       'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#       'id': '7oPftvlwr6VrsViSDV7fJY',
#       'name': 'Green Day',
#       'type': 'artist',
#       'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#     'disc_number': 1,
#     'track_number': 14,
#     'duration_ms': 262333,
#     'external_ids': {'isrc': 'USRE10400985'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5GorCbAP4aL0EJ16frG2hd'},
#     'href': 'https://api.spotify.com/v1/tracks/5GorCbAP4aL0EJ16frG2hd',
#     'id': '5GorCbAP4aL0EJ16frG2hd',
#     'name': 'Boulevard of Broken Dreams',
#     'popularity': 71,
#     'uri': 'spotify:track:5GorCbAP4aL0EJ16frG2hd',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
# ...
#       'href': 'https://api.spotify.com/v1/artists/3MM8mtgFzaEJsqbjZBSsHJ',
#       'id': '3MM8mtgFzaEJsqbjZBSsHJ',
#       'name': 'Bloc Party',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MM8mtgFzaEJsqbjZBSsHJ'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 196613,
#     'external_ids': {'isrc': 'GBDNH0400385'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2YxXuCdbUpil3P7tRjhW1t'},
#     'href': 'https://api.spotify.com/v1/tracks/2YxXuCdbUpil3P7tRjhW1t',
#     'id': '4juzduULFJiZVIcrC1tkxE',
#     'name': 'Banquet',
#     'popularity': 58,
#     'uri': 'spotify:track:4juzduULFJiZVIcrC1tkxE',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2YxXuCdbUpil3P7tRjhW1t'},
#      'href': 'https://api.spotify.com/v1/tracks/2YxXuCdbUpil3P7tRjhW1t',
#      'id': '2YxXuCdbUpil3P7tRjhW1t',
#      'type': 'track',
#      'uri': 'spotify:track:2YxXuCdbUpil3P7tRjhW1t'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/4hBTxv4QRPePXCFcEI7Vjp',
#      'id': '4hBTxv4QRPePXCFcEI7Vjp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730538b48c180256e0bdd8363f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020538b48c180256e0bdd8363f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510538b48c180256e0bdd8363f',
#        'width': 64}],
#      'name': 'blink-182',
#      'release_date': '2003-11-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:4hBTxv4QRPePXCFcEI7Vjp',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FBDaR13swtiWwGhX1WQsP'},
#        'href': 'https://api.spotify.com/v1/artists/6FBDaR13swtiWwGhX1WQsP',
#        'id': '6FBDaR13swtiWwGhX1WQsP',
#        'name': 'blink-182',
#        'type': 'artist',
#        'uri': 'spotify:artist:6FBDaR13swtiWwGhX1WQsP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hBTxv4QRPePXCFcEI7Vjp'},
#      'total_tracks': 16},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FBDaR13swtiWwGhX1WQsP'},
#       'href': 'https://api.spotify.com/v1/artists/6FBDaR13swtiWwGhX1WQsP',
#       'id': '6FBDaR13swtiWwGhX1WQsP',
#       'name': 'blink-182',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FBDaR13swtiWwGhX1WQsP'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 172645,
#     'external_ids': {'isrc': 'USMC10346225'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/26AYR77170U49cMcXB7aRV'},
#     'href': 'https://api.spotify.com/v1/tracks/26AYR77170U49cMcXB7aRV',
#     'id': '26AYR77170U49cMcXB7aRV',
#     'name': 'Feeling This',
#     'popularity': 67,
#     'uri': 'spotify:track:26AYR77170U49cMcXB7aRV',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/03srSIJshSQQOh2vJ3uVZi',
#      'id': '03srSIJshSQQOh2vJ3uVZi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27390cd89ddbbd2034ee1f20b5c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0290cd89ddbbd2034ee1f20b5c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485190cd89ddbbd2034ee1f20b5c',
#        'width': 64}],
#      'name': 'Lullabies To Paralyze',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:03srSIJshSQQOh2vJ3uVZi',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4pejUc4iciQfgdX6OKulQn'},
#        'href': 'https://api.spotify.com/v1/artists/4pejUc4iciQfgdX6OKulQn',
#        'id': '4pejUc4iciQfgdX6OKulQn',
#        'name': 'Queens of the Stone Age',
#        'type': 'artist',
#        'uri': 'spotify:artist:4pejUc4iciQfgdX6OKulQn'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/03srSIJshSQQOh2vJ3uVZi'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4pejUc4iciQfgdX6OKulQn'},
#       'href': 'https://api.spotify.com/v1/artists/4pejUc4iciQfgdX6OKulQn',
#       'id': '4pejUc4iciQfgdX6OKulQn',
#       'name': 'Queens of the Stone Age',
#       'type': 'artist',
#       'uri': 'spotify:artist:4pejUc4iciQfgdX6OKulQn'}],
#     'disc_number': 1,
#     'track_number': 7,
#     'duration_ms': 174026,
#     'external_ids': {'isrc': 'USIR10401154'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1rzYrkxgRuLLJDqWdB32pK'},
#     'href': 'https://api.spotify.com/v1/tracks/1rzYrkxgRuLLJDqWdB32pK',
#     'id': '1rzYrkxgRuLLJDqWdB32pK',
#     'name': 'Little Sister',
#     'popularity': 59,
#     'uri': 'spotify:track:1rzYrkxgRuLLJDqWdB32pK',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0GeWd0yUKXHbCXVag1mJvO',
#      'id': '0GeWd0yUKXHbCXVag1mJvO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732d73b494efcb99356f8c7b28',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022d73b494efcb99356f8c7b28',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512d73b494efcb99356f8c7b28',
#        'width': 64}],
#      'name': 'Mer De Noms',
#      'release_date': '2000-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0GeWd0yUKXHbCXVag1mJvO',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DFhHyjvGYa9wxdHUjtDkc'},
#        'href': 'https://api.spotify.com/v1/artists/4DFhHyjvGYa9wxdHUjtDkc',
#        'id': '4DFhHyjvGYa9wxdHUjtDkc',
#        'name': 'A Perfect Circle',
#        'type': 'artist',
#        'uri': 'spotify:artist:4DFhHyjvGYa9wxdHUjtDkc'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0GeWd0yUKXHbCXVag1mJvO'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DFhHyjvGYa9wxdHUjtDkc'},
#       'href': 'https://api.spotify.com/v1/artists/4DFhHyjvGYa9wxdHUjtDkc',
#       'id': '4DFhHyjvGYa9wxdHUjtDkc',
#       'name': 'A Perfect Circle',
#       'type': 'artist',
#       'uri': 'spotify:artist:4DFhHyjvGYa9wxdHUjtDkc'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 247266,
#     'external_ids': {'isrc': 'USVI20000047'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5KDNFlHAdDJ84fhK27c35X'},
#     'href': 'https://api.spotify.com/v1/tracks/5KDNFlHAdDJ84fhK27c35X',
#     'id': '5KDNFlHAdDJ84fhK27c35X',
#     'name': 'Judith',
#     'popularity': 65,
#     'uri': 'spotify:track:5KDNFlHAdDJ84fhK27c35X',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/4hrZp6mKgz0HG7UpRbNYQx',
#      'id': '4hrZp6mKgz0HG7UpRbNYQx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e24f7aaa97e6311d8fa89e1c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e24f7aaa97e6311d8fa89e1c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e24f7aaa97e6311d8fa89e1c',
#        'width': 64}],
#      'name': 'Machina / The Machines Of God',
#      'release_date': '2000-02-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:4hrZp6mKgz0HG7UpRbNYQx',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Yq4vzPs9VNUrIBG5Jr2i'},
#        'href': 'https://api.spotify.com/v1/artists/40Yq4vzPs9VNUrIBG5Jr2i',
#        'id': '40Yq4vzPs9VNUrIBG5Jr2i',
#        'name': 'The Smashing Pumpkins',
#        'type': 'artist',
#        'uri': 'spotify:artist:40Yq4vzPs9VNUrIBG5Jr2i'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hrZp6mKgz0HG7UpRbNYQx'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Yq4vzPs9VNUrIBG5Jr2i'},
#       'href': 'https://api.spotify.com/v1/artists/40Yq4vzPs9VNUrIBG5Jr2i',
#       'id': '40Yq4vzPs9VNUrIBG5Jr2i',
#       'name': 'The Smashing Pumpkins',
#       'type': 'artist',
#       'uri': 'spotify:artist:40Yq4vzPs9VNUrIBG5Jr2i'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 240733,
#     'external_ids': {'isrc': 'USVI29900302'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4EhbLHYOXzEoPmOfaVoIIW'},
#     'href': 'https://api.spotify.com/v1/tracks/4EhbLHYOXzEoPmOfaVoIIW',
#     'id': '4EhbLHYOXzEoPmOfaVoIIW',
#     'name': 'The Everlasting Gaze',
#     'popularity': 53,
#     'uri': 'spotify:track:4EhbLHYOXzEoPmOfaVoIIW',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/42aff0124e0c22559d523dbd530bfb261a8a0dfa?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5cO7wtkaJCY3SiV6g0MKHE',
#      'id': '5cO7wtkaJCY3SiV6g0MKHE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a3a186d46a33710b64b561ea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a3a186d46a33710b64b561ea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a3a186d46a33710b64b561ea',
#        'width': 64}],
#      'name': 'Take to the Skies',
#      'release_date': '2007-03-18',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5cO7wtkaJCY3SiV6g0MKHE',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31jvzuB4ikftPQZJwrYfCF'},
#        'href': 'https://api.spotify.com/v1/artists/31jvzuB4ikftPQZJwrYfCF',
#        'id': '31jvzuB4ikftPQZJwrYfCF',
#        'name': 'Enter Shikari',
#        'type': 'artist',
#        'uri': 'spotify:artist:31jvzuB4ikftPQZJwrYfCF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5cO7wtkaJCY3SiV6g0MKHE'},
#      'total_tracks': 13},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31jvzuB4ikftPQZJwrYfCF'},
#       'href': 'https://api.spotify.com/v1/artists/31jvzuB4ikftPQZJwrYfCF',
#       'id': '31jvzuB4ikftPQZJwrYfCF',
#       'name': 'Enter Shikari',
#       'type': 'artist',
#       'uri': 'spotify:artist:31jvzuB4ikftPQZJwrYfCF'}],
#     'disc_number': 1,
#     'track_number': 9,
#     'duration_ms': 254666,
#     'external_ids': {'isrc': 'GBNPA0700007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6PwxotrB99xgatKVzibmkz'},
#     'href': 'https://api.spotify.com/v1/tracks/6PwxotrB99xgatKVzibmkz',
#     'id': '6PwxotrB99xgatKVzibmkz',
#     'name': "Sorry You're Not a Winner",
#     'popularity': 55,
#     'uri': 'spotify:track:6PwxotrB99xgatKVzibmkz',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-03T21:49:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/444cf0aa9835c78194df0f4babc157dc03b9e03b?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0BPdEttNgcw9OMljXVAAJP',
#      'id': '0BPdEttNgcw9OMljXVAAJP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb373de9f874e9e6d45349ad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb373de9f874e9e6d45349ad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb373de9f874e9e6d45349ad',
#        'width': 64}],
#      'name': 'Relationship of Command',
#      'release_date': '2013-04-22',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0BPdEttNgcw9OMljXVAAJP',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5E2rtn57BM2WPjwak4kGd5'},
#        'href': 'https://api.spotify.com/v1/artists/5E2rtn57BM2WPjwak4kGd5',
#        'id': '5E2rtn57BM2WPjwak4kGd5',
#        'name': 'At the Drive-In',
#        'type': 'artist',
#        'uri': 'spotify:artist:5E2rtn57BM2WPjwak4kGd5'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BPdEttNgcw9OMljXVAAJP'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5E2rtn57BM2WPjwak4kGd5'},
#       'href': 'https://api.spotify.com/v1/artists/5E2rtn57BM2WPjwak4kGd5',
#       'id': '5E2rtn57BM2WPjwak4kGd5',
#       'name': 'At the Drive-In',
#       'type': 'artist',
#       'uri': 'spotify:artist:5E2rtn57BM2WPjwak4kGd5'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 260293,
#     'external_ids': {'isrc': 'US5260507003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5UTYRC4IQLc7Jxc1sJapMl'},
#     'href': 'https://api.spotify.com/v1/tracks/5UTYRC4IQLc7Jxc1sJapMl',
#     'id': '5UTYRC4IQLc7Jxc1sJapMl',
#     'name': 'One Armed Scissor',
#     'popularity': 42,
#     'uri': 'spotify:track:5UTYRC4IQLc7Jxc1sJapMl',
#     'is_local': False},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 100}

# %%
import pprint

pprint.pprint(playlist_rock)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3oM43CtKnRV/tracks?offset=0&limit=100&market=DE&additional_types=track',
#  'items': [{'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#                                              'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#                                              'id': '6XyY86QOPPrYVGvF9ch6wz',
#                                              'name': 'Linkin Park',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2pKw6GERJVAD61449B1EEM'},
#                                 'href': 'https://api.spotify.com/v1/albums/2pKw6GERJVAD61449B1EEM',
#                                 'id': '2pKw6GERJVAD61449B1EEM',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2736741ca6e9ba6fdc166037321',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e026741ca6e9ba6fdc166037321',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048516741ca6e9ba6fdc166037321',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Hybrid Theory',
#                                 'release_date': '2000',
#                                 'release_date_precision': 'year',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2pKw6GERJVAD61449B1EEM'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#                                    'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#                                    'id': '6XyY86QOPPrYVGvF9ch6wz',
#                                    'name': 'Linkin Park',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#                       'disc_number': 1,
#                       'duration_ms': 216800,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USWB10002407'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3tSmXSxaAnU1EPGKa6NytH'},
#                       'href': 'https://api.spotify.com/v1/tracks/3tSmXSxaAnU1EPGKa6NytH',
#                       'id': '60a0Rd6pjrkxjPbaKzXjfq',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3tSmXSxaAnU1EPGKa6NytH'},
#                                       'href': 'https://api.spotify.com/v1/tracks/3tSmXSxaAnU1EPGKa6NytH',
#                                       'id': '3tSmXSxaAnU1EPGKa6NytH',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:3tSmXSxaAnU1EPGKa6NytH'},
#                       'name': 'In the End',
#                       'popularity': 64,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/b5ee275ca337899f762b1c1883c11e24a04075b0?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 8,
#                       'type': 'track',
#                       'uri': 'spotify:track:60a0Rd6pjrkxjPbaKzXjfq'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#                                              'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#                                              'id': '7oPftvlwr6VrsViSDV7fJY',
#                                              'name': 'Green Day',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5Qhn2FpGWmTjCuntF09j7g'},
#                                 'href': 'https://api.spotify.com/v1/albums/5Qhn2FpGWmTjCuntF09j7g',
#                                 'id': '5Qhn2FpGWmTjCuntF09j7g',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2739079e678be6b947cc2b3b5c6',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e029079e678be6b947cc2b3b5c6',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048519079e678be6b947cc2b3b5c6',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'American Idiot - Deluxe',
#                                 'release_date': '2004-09-21',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5Qhn2FpGWmTjCuntF09j7g'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#                                    'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#                                    'id': '7oPftvlwr6VrsViSDV7fJY',
#                                    'name': 'Green Day',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#                       'disc_number': 1,
#                       'duration_ms': 174320,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USRE10400888'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/45zvStEMsXp8z45OQRhWFJ'},
#                       'href': 'https://api.spotify.com/v1/tracks/45zvStEMsXp8z45OQRhWFJ',
#                       'id': '45zvStEMsXp8z45OQRhWFJ',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'American Idiot',
#                       'popularity': 61,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/dfac967b275f7fe44e71e037f78c0e205515c78b?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:45zvStEMsXp8z45OQRhWFJ'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#                                              'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#                                              'id': '0L8ExT028jH3ddEcZwqJJ5',
#                                              'name': 'Red Hot Chili Peppers',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6deiaArbeoqp1xPEGdEKp1'},
#                                 'href': 'https://api.spotify.com/v1/albums/6deiaArbeoqp1xPEGdEKp1',
#                                 'id': '6deiaArbeoqp1xPEGdEKp1',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273de1af2785a83cc660155a0c4',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02de1af2785a83cc660155a0c4',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851de1af2785a83cc660155a0c4',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'By the Way (Deluxe Edition)',
#                                 'release_date': '2002-07-09',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 18,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6deiaArbeoqp1xPEGdEKp1'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#                                    'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#                                    'id': '0L8ExT028jH3ddEcZwqJJ5',
#                                    'name': 'Red Hot Chili Peppers',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#                       'disc_number': 1,
#                       'duration_ms': 269000,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USWB10201694'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3ZOEytgrvLwQaqXreDs2Jx'},
#                       'href': 'https://api.spotify.com/v1/tracks/3ZOEytgrvLwQaqXreDs2Jx',
#                       'id': '3ZOEytgrvLwQaqXreDs2Jx',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': "Can't Stop",
#                       'popularity': 84,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/1b3bc0aca1746a99cbb8dd07b2325f6499b58a2e?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 7,
#                       'type': 'track',
#                       'uri': 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#                                              'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#                                              'id': '5eAWCfyUhZtHHtBdNk56l1',
#                                              'name': 'System Of A Down',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6jWde94ln40epKIQCd8XUh'},
#                                 'href': 'https://api.spotify.com/v1/albums/6jWde94ln40epKIQCd8XUh',
#                                 'id': '6jWde94ln40epKIQCd8XUh',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27330d45198d0c9e8841f9a9578',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0230d45198d0c9e8841f9a9578',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485130d45198d0c9e8841f9a9578',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Toxicity',
#                                 'release_date': '2001-09-04',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6jWde94ln40epKIQCd8XUh'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#                                    'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#                                    'id': '5eAWCfyUhZtHHtBdNk56l1',
#                                    'name': 'System Of A Down',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#                       'disc_number': 1,
#                       'duration_ms': 218933,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USSM10107262'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0snQkGI5qnAmohLE7jTsTn'},
#                       'href': 'https://api.spotify.com/v1/tracks/0snQkGI5qnAmohLE7jTsTn',
#                       'id': '0snQkGI5qnAmohLE7jTsTn',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Toxicity',
#                       'popularity': 84,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/d9b89161dacbb987b360417346591712c4023abd?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 12,
#                       'type': 'track',
#                       'uri': 'spotify:track:0snQkGI5qnAmohLE7jTsTn'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nGIFgo0shDenQYSE0Sn7c'},
#                                              'href': 'https://api.spotify.com/v1/artists/5nGIFgo0shDenQYSE0Sn7c',
#                                              'id': '5nGIFgo0shDenQYSE0Sn7c',
#                                              'name': 'Evanescence',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5nGIFgo0shDenQYSE0Sn7c'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/02w1xMzzdF2OJxTeh1basm'},
#                                 'href': 'https://api.spotify.com/v1/albums/02w1xMzzdF2OJxTeh1basm',
#                                 'id': '02w1xMzzdF2OJxTeh1basm',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27325f49ab23f0ec6332efef432',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0225f49ab23f0ec6332efef432',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485125f49ab23f0ec6332efef432',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Fallen',
#                                 'release_date': '2003-03-04',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:02w1xMzzdF2OJxTeh1basm'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nGIFgo0shDenQYSE0Sn7c'},
#                                    'href': 'https://api.spotify.com/v1/artists/5nGIFgo0shDenQYSE0Sn7c',
#                                    'id': '5nGIFgo0shDenQYSE0Sn7c',
#                                    'name': 'Evanescence',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5nGIFgo0shDenQYSE0Sn7c'}],
#                       'disc_number': 1,
#                       'duration_ms': 235893,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USWU30200093'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0COqiPhxzoWICwFCS4eZcp'},
#                       'href': 'https://api.spotify.com/v1/tracks/0COqiPhxzoWICwFCS4eZcp',
#                       'id': '0COqiPhxzoWICwFCS4eZcp',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Bring Me To Life',
#                       'popularity': 83,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:0COqiPhxzoWICwFCS4eZcp'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#                                              'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#                                              'id': '2qk9voo8llSGYcZ6xrBzKx',
#                                              'name': 'Kings of Leon',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5CZR6ljD0x9fTiS4mh9wMp'},
#                                 'href': 'https://api.spotify.com/v1/albums/5CZR6ljD0x9fTiS4mh9wMp',
#                                 'id': '5CZR6ljD0x9fTiS4mh9wMp',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2732519d01c0cca06f134eeadd8',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e022519d01c0cca06f134eeadd8',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048512519d01c0cca06f134eeadd8',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Only By The Night',
#                                 'release_date': '2008-09-23',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5CZR6ljD0x9fTiS4mh9wMp'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#                                    'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#                                    'id': '2qk9voo8llSGYcZ6xrBzKx',
#                                    'name': 'Kings of Leon',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#                       'disc_number': 1,
#                       'duration_ms': 203346,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USRC10800300'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0ntQJM78wzOLVeCUAW7Y45'},
#                       'href': 'https://api.spotify.com/v1/tracks/0ntQJM78wzOLVeCUAW7Y45',
#                       'id': '0ntQJM78wzOLVeCUAW7Y45',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Sex on Fire',
#                       'popularity': 84,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/6806855988e246016413cc8a34a2afe862f3988d?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:0ntQJM78wzOLVeCUAW7Y45'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#                                              'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#                                              'id': '12Chz98pHFMPJEknJQMWvI',
#                                              'name': 'Muse',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0eFHYz8NmK75zSplL5qlfM'},
#                                 'href': 'https://api.spotify.com/v1/albums/0eFHYz8NmK75zSplL5qlfM',
#                                 'id': '0eFHYz8NmK75zSplL5qlfM',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273b6d4566db0d12894a1a3b7a2',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02b6d4566db0d12894a1a3b7a2',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851b6d4566db0d12894a1a3b7a2',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'The Resistance',
#                                 'release_date': '2009-09-10',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0eFHYz8NmK75zSplL5qlfM'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#                                    'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#                                    'id': '12Chz98pHFMPJEknJQMWvI',
#                                    'name': 'Muse',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'}],
#                       'disc_number': 1,
#                       'duration_ms': 304840,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBAHT0900320'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4VqPOruhp5EdPBeR92t6lQ'},
#                       'href': 'https://api.spotify.com/v1/tracks/4VqPOruhp5EdPBeR92t6lQ',
#                       'id': '4VqPOruhp5EdPBeR92t6lQ',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Uprising',
#                       'popularity': 75,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/529eb48df232955cdd3b870f21e2bd41f1657fae?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:4VqPOruhp5EdPBeR92t6lQ'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74XFHRwlV6OrjEM0A2NCMF'},
#                                              'href': 'https://api.spotify.com/v1/artists/74XFHRwlV6OrjEM0A2NCMF',
#                                              'id': '74XFHRwlV6OrjEM0A2NCMF',
#                                              'name': 'Paramore',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:74XFHRwlV6OrjEM0A2NCMF'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3UoOO8m0oxxvUHXUKf3qcZ'},
#                                 'href': 'https://api.spotify.com/v1/albums/3UoOO8m0oxxvUHXUKf3qcZ',
#                                 'id': '3UoOO8m0oxxvUHXUKf3qcZ',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27369966efa45b125ed6711b43c',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0269966efa45b125ed6711b43c',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485169966efa45b125ed6711b43c',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Riot!',
#                                 'release_date': '2007-06-11',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 14,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3UoOO8m0oxxvUHXUKf3qcZ'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74XFHRwlV6OrjEM0A2NCMF'},
#                                    'href': 'https://api.spotify.com/v1/artists/74XFHRwlV6OrjEM0A2NCMF',
#                                    'id': '74XFHRwlV6OrjEM0A2NCMF',
#                                    'name': 'Paramore',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:74XFHRwlV6OrjEM0A2NCMF'}],
#                       'disc_number': 1,
#                       'duration_ms': 211520,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USAT20702617'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3l9CW99AHtExIRV4hW2N5m'},
#                       'href': 'https://api.spotify.com/v1/tracks/3l9CW99AHtExIRV4hW2N5m',
#                       'id': '3l9CW99AHtExIRV4hW2N5m',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Misery Business',
#                       'popularity': 73,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/ba87b3463a795afa81ee18d3fbb116bb7793140e?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 4,
#                       'type': 'track',
#                       'uri': 'spotify:track:3l9CW99AHtExIRV4hW2N5m'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6deZN1bslXzeGvOLaLMOIF'},
#                                              'href': 'https://api.spotify.com/v1/artists/6deZN1bslXzeGvOLaLMOIF',
#                                              'id': '6deZN1bslXzeGvOLaLMOIF',
#                                              'name': 'Nickelback',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:6deZN1bslXzeGvOLaLMOIF'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5HOTlQx62uQqxRvR1MVIzb'},
#                                 'href': 'https://api.spotify.com/v1/albums/5HOTlQx62uQqxRvR1MVIzb',
#                                 'id': '5HOTlQx62uQqxRvR1MVIzb',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2735f18910ec86e3ecbbc2fd2cb',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e025f18910ec86e3ecbbc2fd2cb',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048515f18910ec86e3ecbbc2fd2cb',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Silver Side Up',
#                                 'release_date': '2001-09-11',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 10,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5HOTlQx62uQqxRvR1MVIzb'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6deZN1bslXzeGvOLaLMOIF'},
#                                    'href': 'https://api.spotify.com/v1/artists/6deZN1bslXzeGvOLaLMOIF',
#                                    'id': '6deZN1bslXzeGvOLaLMOIF',
#                                    'name': 'Nickelback',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:6deZN1bslXzeGvOLaLMOIF'}],
#                       'disc_number': 1,
#                       'duration_ms': 223826,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'NLA320119533'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0F2nGhgFNlkVHm81zNEvW6'},
#                       'href': 'https://api.spotify.com/v1/tracks/0F2nGhgFNlkVHm81zNEvW6',
#                       'id': '0gmbgwZ8iqyMPmXefof8Yf',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0F2nGhgFNlkVHm81zNEvW6'},
#                                       'href': 'https://api.spotify.com/v1/tracks/0F2nGhgFNlkVHm81zNEvW6',
#                                       'id': '0F2nGhgFNlkVHm81zNEvW6',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:0F2nGhgFNlkVHm81zNEvW6'},
#                       'name': 'How You Remind Me',
#                       'popularity': 0,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/94fd201045f5b682935957a8206075638dc4622d?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:0gmbgwZ8iqyMPmXefof8Yf'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ziB7fzrXBoh1HUPS6sVFn'},
#                                              'href': 'https://api.spotify.com/v1/artists/2ziB7fzrXBoh1HUPS6sVFn',
#                                              'id': '2ziB7fzrXBoh1HUPS6sVFn',
#                                              'name': 'Audioslave',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2ziB7fzrXBoh1HUPS6sVFn'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/78guAsers0klWl6RwzgDLd'},
#                                 'href': 'https://api.spotify.com/v1/albums/78guAsers0klWl6RwzgDLd',
#                                 'id': '78guAsers0klWl6RwzgDLd',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273a7292b6863258e889b78d787',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02a7292b6863258e889b78d787',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851a7292b6863258e889b78d787',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Audioslave',
#                                 'release_date': '2002-11-17',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 14,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:78guAsers0klWl6RwzgDLd'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ziB7fzrXBoh1HUPS6sVFn'},
#                                    'href': 'https://api.spotify.com/v1/artists/2ziB7fzrXBoh1HUPS6sVFn',
#                                    'id': '2ziB7fzrXBoh1HUPS6sVFn',
#                                    'name': 'Audioslave',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2ziB7fzrXBoh1HUPS6sVFn'}],
#                       'disc_number': 1,
#                       'duration_ms': 293960,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USSM10211587'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3YuaBvuZqcwN3CEAyyoaei'},
#                       'href': 'https://api.spotify.com/v1/tracks/3YuaBvuZqcwN3CEAyyoaei',
#                       'id': '2MrWu3Gt6ucsOHC6eE8oLV',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3YuaBvuZqcwN3CEAyyoaei'},
#                                       'href': 'https://api.spotify.com/v1/tracks/3YuaBvuZqcwN3CEAyyoaei',
#                                       'id': '3YuaBvuZqcwN3CEAyyoaei',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:3YuaBvuZqcwN3CEAyyoaei'},
#                       'name': 'Like a Stone',
#                       'popularity': 78,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/46d898c23fb28b9f52abf78b794aa500988d2132?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:2MrWu3Gt6ucsOHC6eE8oLV'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XNa1vTidXlvJ2gHSsRi4A'},
#                                              'href': 'https://api.spotify.com/v1/artists/0XNa1vTidXlvJ2gHSsRi4A',
#                                              'id': '0XNa1vTidXlvJ2gHSsRi4A',
#                                              'name': 'Franz Ferdinand',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0XNa1vTidXlvJ2gHSsRi4A'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/03akiuheNt5mJqltALnalP'},
#                                 'href': 'https://api.spotify.com/v1/albums/03akiuheNt5mJqltALnalP',
#                                 'id': '03akiuheNt5mJqltALnalP',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27368f87064692961d17e3f3766',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0268f87064692961d17e3f3766',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485168f87064692961d17e3f3766',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Franz Ferdinand',
#                                 'release_date': '2004-02-16',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:03akiuheNt5mJqltALnalP'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XNa1vTidXlvJ2gHSsRi4A'},
#                                    'href': 'https://api.spotify.com/v1/artists/0XNa1vTidXlvJ2gHSsRi4A',
#                                    'id': '0XNa1vTidXlvJ2gHSsRi4A',
#                                    'name': 'Franz Ferdinand',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0XNa1vTidXlvJ2gHSsRi4A'}],
#                       'disc_number': 1,
#                       'duration_ms': 237026,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBCEL0300192'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0ancVQ9wEcHVd0RrGICTE4'},
#                       'href': 'https://api.spotify.com/v1/tracks/0ancVQ9wEcHVd0RrGICTE4',
#                       'id': '20I8RduZC2PWMWTDCZuuAN',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0ancVQ9wEcHVd0RrGICTE4'},
#                                       'href': 'https://api.spotify.com/v1/tracks/0ancVQ9wEcHVd0RrGICTE4',
#                                       'id': '0ancVQ9wEcHVd0RrGICTE4',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:0ancVQ9wEcHVd0RrGICTE4'},
#                       'name': 'Take Me Out',
#                       'popularity': 0,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/f91cfdf3dd5f7114cf47f8c8b2567b7a8a76d9ed?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:20I8RduZC2PWMWTDCZuuAN'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#                                              'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#                                              'id': '4F84IBURUo98rz4r61KF70',
#                                              'name': 'The White Stripes',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/48Atx1uS9J4KL5iQt3weoS'},
#                                 'href': 'https://api.spotify.com/v1/albums/48Atx1uS9J4KL5iQt3weoS',
#                                 'id': '48Atx1uS9J4KL5iQt3weoS',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273588ca88c368d5f6eae5cb9b1',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02588ca88c368d5f6eae5cb9b1',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851588ca88c368d5f6eae5cb9b1',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Elephant',
#                                 'release_date': '2003-04-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 14,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:48Atx1uS9J4KL5iQt3weoS'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#                                    'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#                                    'id': '4F84IBURUo98rz4r61KF70',
#                                    'name': 'The White Stripes',
#                                    'type': 'artist',
# ...
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 7,
#                       'type': 'track',
#                       'uri': 'spotify:track:1rzYrkxgRuLLJDqWdB32pK'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DFhHyjvGYa9wxdHUjtDkc'},
#                                              'href': 'https://api.spotify.com/v1/artists/4DFhHyjvGYa9wxdHUjtDkc',
#                                              'id': '4DFhHyjvGYa9wxdHUjtDkc',
#                                              'name': 'A Perfect Circle',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:4DFhHyjvGYa9wxdHUjtDkc'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0GeWd0yUKXHbCXVag1mJvO'},
#                                 'href': 'https://api.spotify.com/v1/albums/0GeWd0yUKXHbCXVag1mJvO',
#                                 'id': '0GeWd0yUKXHbCXVag1mJvO',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2732d73b494efcb99356f8c7b28',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e022d73b494efcb99356f8c7b28',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048512d73b494efcb99356f8c7b28',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Mer De Noms',
#                                 'release_date': '2000-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0GeWd0yUKXHbCXVag1mJvO'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DFhHyjvGYa9wxdHUjtDkc'},
#                                    'href': 'https://api.spotify.com/v1/artists/4DFhHyjvGYa9wxdHUjtDkc',
#                                    'id': '4DFhHyjvGYa9wxdHUjtDkc',
#                                    'name': 'A Perfect Circle',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:4DFhHyjvGYa9wxdHUjtDkc'}],
#                       'disc_number': 1,
#                       'duration_ms': 247266,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USVI20000047'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5KDNFlHAdDJ84fhK27c35X'},
#                       'href': 'https://api.spotify.com/v1/tracks/5KDNFlHAdDJ84fhK27c35X',
#                       'id': '5KDNFlHAdDJ84fhK27c35X',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Judith',
#                       'popularity': 65,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 4,
#                       'type': 'track',
#                       'uri': 'spotify:track:5KDNFlHAdDJ84fhK27c35X'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Yq4vzPs9VNUrIBG5Jr2i'},
#                                              'href': 'https://api.spotify.com/v1/artists/40Yq4vzPs9VNUrIBG5Jr2i',
#                                              'id': '40Yq4vzPs9VNUrIBG5Jr2i',
#                                              'name': 'The Smashing Pumpkins',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:40Yq4vzPs9VNUrIBG5Jr2i'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/4hrZp6mKgz0HG7UpRbNYQx'},
#                                 'href': 'https://api.spotify.com/v1/albums/4hrZp6mKgz0HG7UpRbNYQx',
#                                 'id': '4hrZp6mKgz0HG7UpRbNYQx',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273e24f7aaa97e6311d8fa89e1c',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02e24f7aaa97e6311d8fa89e1c',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851e24f7aaa97e6311d8fa89e1c',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Machina / The Machines Of God',
#                                 'release_date': '2000-02-29',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:4hrZp6mKgz0HG7UpRbNYQx'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/40Yq4vzPs9VNUrIBG5Jr2i'},
#                                    'href': 'https://api.spotify.com/v1/artists/40Yq4vzPs9VNUrIBG5Jr2i',
#                                    'id': '40Yq4vzPs9VNUrIBG5Jr2i',
#                                    'name': 'The Smashing Pumpkins',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:40Yq4vzPs9VNUrIBG5Jr2i'}],
#                       'disc_number': 1,
#                       'duration_ms': 240733,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USVI29900302'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4EhbLHYOXzEoPmOfaVoIIW'},
#                       'href': 'https://api.spotify.com/v1/tracks/4EhbLHYOXzEoPmOfaVoIIW',
#                       'id': '4EhbLHYOXzEoPmOfaVoIIW',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'The Everlasting Gaze',
#                       'popularity': 53,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:4EhbLHYOXzEoPmOfaVoIIW'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31jvzuB4ikftPQZJwrYfCF'},
#                                              'href': 'https://api.spotify.com/v1/artists/31jvzuB4ikftPQZJwrYfCF',
#                                              'id': '31jvzuB4ikftPQZJwrYfCF',
#                                              'name': 'Enter Shikari',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:31jvzuB4ikftPQZJwrYfCF'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5cO7wtkaJCY3SiV6g0MKHE'},
#                                 'href': 'https://api.spotify.com/v1/albums/5cO7wtkaJCY3SiV6g0MKHE',
#                                 'id': '5cO7wtkaJCY3SiV6g0MKHE',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273a3a186d46a33710b64b561ea',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02a3a186d46a33710b64b561ea',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851a3a186d46a33710b64b561ea',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Take to the Skies',
#                                 'release_date': '2007-03-18',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 13,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5cO7wtkaJCY3SiV6g0MKHE'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31jvzuB4ikftPQZJwrYfCF'},
#                                    'href': 'https://api.spotify.com/v1/artists/31jvzuB4ikftPQZJwrYfCF',
#                                    'id': '31jvzuB4ikftPQZJwrYfCF',
#                                    'name': 'Enter Shikari',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:31jvzuB4ikftPQZJwrYfCF'}],
#                       'disc_number': 1,
#                       'duration_ms': 254666,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBNPA0700007'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6PwxotrB99xgatKVzibmkz'},
#                       'href': 'https://api.spotify.com/v1/tracks/6PwxotrB99xgatKVzibmkz',
#                       'id': '6PwxotrB99xgatKVzibmkz',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': "Sorry You're Not a Winner",
#                       'popularity': 55,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/42aff0124e0c22559d523dbd530bfb261a8a0dfa?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 9,
#                       'type': 'track',
#                       'uri': 'spotify:track:6PwxotrB99xgatKVzibmkz'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2024-10-03T21:49:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5E2rtn57BM2WPjwak4kGd5'},
#                                              'href': 'https://api.spotify.com/v1/artists/5E2rtn57BM2WPjwak4kGd5',
#                                              'id': '5E2rtn57BM2WPjwak4kGd5',
#                                              'name': 'At the Drive-In',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5E2rtn57BM2WPjwak4kGd5'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0BPdEttNgcw9OMljXVAAJP'},
#                                 'href': 'https://api.spotify.com/v1/albums/0BPdEttNgcw9OMljXVAAJP',
#                                 'id': '0BPdEttNgcw9OMljXVAAJP',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273eb373de9f874e9e6d45349ad',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02eb373de9f874e9e6d45349ad',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851eb373de9f874e9e6d45349ad',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Relationship of Command',
#                                 'release_date': '2013-04-22',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0BPdEttNgcw9OMljXVAAJP'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5E2rtn57BM2WPjwak4kGd5'},
#                                    'href': 'https://api.spotify.com/v1/artists/5E2rtn57BM2WPjwak4kGd5',
#                                    'id': '5E2rtn57BM2WPjwak4kGd5',
#                                    'name': 'At the Drive-In',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5E2rtn57BM2WPjwak4kGd5'}],
#                       'disc_number': 1,
#                       'duration_ms': 260293,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'US5260507003'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5UTYRC4IQLc7Jxc1sJapMl'},
#                       'href': 'https://api.spotify.com/v1/tracks/5UTYRC4IQLc7Jxc1sJapMl',
#                       'id': '5UTYRC4IQLc7Jxc1sJapMl',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'One Armed Scissor',
#                       'popularity': 42,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/444cf0aa9835c78194df0f4babc157dc03b9e03b?cid=c918e9cb91e6468897ae9e248594eab0',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:5UTYRC4IQLc7Jxc1sJapMl'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 100}

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_rock['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_rock_df = pd.DataFrame(song_features)
# Keep relevant columns
df_rock = playlist_rock_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_rock["names"] = song_names

# Display the resulting DataFrame
display(df_rock)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/484344023.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rock["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.556   0.864    -5.870       0.0584      0.009580
# 1          0.381   0.984    -2.420       0.0638      0.000025
# 2          0.618   0.938    -3.442       0.0456      0.017900
# 3          0.413   0.873    -4.151       0.0536      0.000264
# 4          0.331   0.943    -3.188       0.0698      0.007210
# ..           ...     ...       ...          ...           ...
# 95         0.361   0.962    -2.928       0.0659      0.010300
# 96         0.366   0.894    -4.682       0.0568      0.000034
# 97         0.264   0.936    -5.067       0.0946      0.000101
# 98         0.382   0.954    -6.035       0.3420      0.111000
# 99         0.253   0.931    -4.189       0.1420      0.060300
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.2090    0.400  105.143  60a0Rd6pjrkxjPbaKzXjfq
# 1           0.000069    0.2700    0.810  186.081  45zvStEMsXp8z45OQRhWFJ
# 2           0.000000    0.1670    0.875   91.455  3ZOEytgrvLwQaqXreDs2Jx
# 3           0.002490    0.2040    0.480  116.680  0snQkGI5qnAmohLE7jTsTn
# 4           0.000002    0.2420    0.296   94.612  0COqiPhxzoWICwFCS4eZcp
# ..               ...       ...      ...      ...                     ...
# 95          0.001030    0.2940    0.927  161.292  1rzYrkxgRuLLJDqWdB32pK
# 96          0.170000    0.2670    0.304   82.305  5KDNFlHAdDJ84fhK27c35X
# 97          0.594000    0.1990    0.351  146.837  4EhbLHYOXzEoPmOfaVoIIW
# 98          0.000342    0.0559    0.360  128.702  6PwxotrB99xgatKVzibmkz
# 99          0.000031    0.6390    0.252  162.382  5UTYRC4IQLc7Jxc1sJapMl
#
#     duration_ms                      names
# 0        216880                 In the End
# 1        174320             American Idiot
# 2        269000                 Can't Stop
# 3        218933                   Toxicity
# 4        235893           Bring Me To Life
# ..          ...                        ...
# 95       174027              Little Sister
# 96       247267                     Judith
# 97       240733       The Everlasting Gaze
# 98       254667  Sorry You're Not a Winner
# 99       260293          One Armed Scissor
#
# [100 rows x 12 columns]

# %%
playlist_motivation = sp.user_playlist_tracks("spotify", "2fmxVDpboTzLaLAfj5ZaQW",market="DE")
playlist_motivation
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2fmxVDpboTzLaLAfj5ZaQW/tracks?offset=0&limit=100&market=DE&additional_types=track',
#  'items': [{'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/33pt9HBdGlAbRGBHQgsZsU',
#      'id': '33pt9HBdGlAbRGBHQgsZsU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735675e83f707f1d7271e5cf8a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025675e83f707f1d7271e5cf8a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515675e83f707f1d7271e5cf8a',
#        'width': 64}],
#      'name': 'Evolve',
#      'release_date': '2017-06-23',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:33pt9HBdGlAbRGBHQgsZsU',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/33pt9HBdGlAbRGBHQgsZsU'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 201240,
#     'external_ids': {'isrc': 'USUM71703515'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Qn5zhYkTa37e91HC1D7lb'},
#     'href': 'https://api.spotify.com/v1/tracks/6Qn5zhYkTa37e91HC1D7lb',
#     'id': '6Qn5zhYkTa37e91HC1D7lb',
#     'name': 'Whatever It Takes',
#     'popularity': 82,
#     'uri': 'spotify:track:6Qn5zhYkTa37e91HC1D7lb',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/466ad3f7e7b495b95cc49fdf7eef90fde9ee7cc8?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/7JOCOjZTcLysDMkZGWlcIj',
#      'id': '7JOCOjZTcLysDMkZGWlcIj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732e3049fef96abebf336b7366',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022e3049fef96abebf336b7366',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512e3049fef96abebf336b7366',
#        'width': 64}],
#      'name': '#3 Deluxe Version',
#      'release_date': '2012-09-10',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:7JOCOjZTcLysDMkZGWlcIj',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#        'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#        'id': '3AQRLZ9PuTAozP28Skbq8V',
#        'name': 'The Script',
#        'type': 'artist',
#        'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7JOCOjZTcLysDMkZGWlcIj'},
#      'total_tracks': 17},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#       'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#       'id': '3AQRLZ9PuTAozP28Skbq8V',
#       'name': 'The Script',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/085pc2PYOi8bGKj0PNjekA'},
#       'href': 'https://api.spotify.com/v1/artists/085pc2PYOi8bGKj0PNjekA',
#       'id': '085pc2PYOi8bGKj0PNjekA',
#       'name': 'will.i.am',
#       'type': 'artist',
#       'uri': 'spotify:artist:085pc2PYOi8bGKj0PNjekA'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 202533,
#     'external_ids': {'isrc': 'GBARL1201055'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7wMq5n8mYSKlQIGECKUgTX'},
#     'href': 'https://api.spotify.com/v1/tracks/7wMq5n8mYSKlQIGECKUgTX',
#     'id': '7wMq5n8mYSKlQIGECKUgTX',
#     'name': 'Hall of Fame (feat. will.i.am)',
#     'popularity': 82,
#     'uri': 'spotify:track:7wMq5n8mYSKlQIGECKUgTX',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0h2knr6qpiAq0tV5ri5JMF',
#      'id': '0h2knr6qpiAq0tV5ri5JMF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730ae4f4d42e4a09f3a29f64ad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020ae4f4d42e4a09f3a29f64ad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510ae4f4d42e4a09f3a29f64ad',
#        'width': 64}],
#      'name': 'The Days / Nights',
#      'release_date': '2014-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0h2knr6qpiAq0tV5ri5JMF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vCWHaC5f2uS3yhpwWbIA6'},
#        'href': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6',
#        'id': '1vCWHaC5f2uS3yhpwWbIA6',
#        'name': 'Avicii',
#        'type': 'artist',
#        'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0h2knr6qpiAq0tV5ri5JMF'},
#      'total_tracks': 4},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vCWHaC5f2uS3yhpwWbIA6'},
#       'href': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6',
#       'id': '1vCWHaC5f2uS3yhpwWbIA6',
#       'name': 'Avicii',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 176658,
#     'external_ids': {'isrc': 'CH3131340464'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ct6r3EGTcMLPtrXHDvVjc'},
#     'href': 'https://api.spotify.com/v1/tracks/0ct6r3EGTcMLPtrXHDvVjc',
#     'id': '0ct6r3EGTcMLPtrXHDvVjc',
#     'name': 'The Nights',
#     'popularity': 83,
#     'uri': 'spotify:track:0ct6r3EGTcMLPtrXHDvVjc',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/ac0923af6dcd3e8bab2e8e051b7d6c3772376796?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/3qWCIK0fqmaaSTLoqoWsaz',
#      'id': '3qWCIK0fqmaaSTLoqoWsaz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf5cab56aa53dd6334d01bc1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf5cab56aa53dd6334d01bc1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf5cab56aa53dd6334d01bc1',
#        'width': 64}],
#      'name': 'Unstoppable (R3HAB Remix)',
#      'release_date': '2022-07-08',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3qWCIK0fqmaaSTLoqoWsaz',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5WUlDfRSoLAfcVSX1WnrxN'},
#        'href': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN',
#        'id': '5WUlDfRSoLAfcVSX1WnrxN',
#        'name': 'Sia',
#        'type': 'artist',
#        'uri': 'spotify:artist:5WUlDfRSoLAfcVSX1WnrxN'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#        'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#        'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#        'name': 'R3HAB',
#        'type': 'artist',
#        'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3qWCIK0fqmaaSTLoqoWsaz'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5WUlDfRSoLAfcVSX1WnrxN'},
#       'href': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN',
#       'id': '5WUlDfRSoLAfcVSX1WnrxN',
#       'name': 'Sia',
#       'type': 'artist',
#       'uri': 'spotify:artist:5WUlDfRSoLAfcVSX1WnrxN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#       'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#       'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#       'name': 'R3HAB',
#       'type': 'artist',
#       'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 162352,
#     'external_ids': {'isrc': 'USRC12202160'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0F3v8p8ZnEGtZDxNcJ5Klq'},
#     'href': 'https://api.spotify.com/v1/tracks/0F3v8p8ZnEGtZDxNcJ5Klq',
#     'id': '0F3v8p8ZnEGtZDxNcJ5Klq',
#     'name': 'Unstoppable - R3HAB Remix',
#     'popularity': 65,
#     'uri': 'spotify:track:0F3v8p8ZnEGtZDxNcJ5Klq',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/18e4f3d4f452748874afb69d77c9657f41121e6e?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/6qmAyfyVZn5ctUnKEsVt2y',
#      'id': '6qmAyfyVZn5ctUnKEsVt2y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d42abd78a85a749915f0c40b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d42abd78a85a749915f0c40b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d42abd78a85a749915f0c40b',
#        'width': 64}],
#      'name': 'Oh My Love',
#      'release_date': '2024-09-12',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6qmAyfyVZn5ctUnKEsVt2y',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oBcbbUQy8Md3FYXifyPTF'},
#        'href': 'https://api.spotify.com/v1/artists/2oBcbbUQy8Md3FYXifyPTF',
#        'id': '2oBcbbUQy8Md3FYXifyPTF',
#        'name': 'ConKi',
#        'type': 'artist',
#        'uri': 'spotify:artist:2oBcbbUQy8Md3FYXifyPTF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6qmAyfyVZn5ctUnKEsVt2y'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oBcbbUQy8Md3FYXifyPTF'},
#       'href': 'https://api.spotify.com/v1/artists/2oBcbbUQy8Md3FYXifyPTF',
#       'id': '2oBcbbUQy8Md3FYXifyPTF',
#       'name': 'ConKi',
#       'type': 'artist',
#       'uri': 'spotify:artist:2oBcbbUQy8Md3FYXifyPTF'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 164516,
#     'external_ids': {'isrc': 'TCAIN2410625'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2UijQcg9x42vsbXYh0PzPO'},
#     'href': 'https://api.spotify.com/v1/tracks/2UijQcg9x42vsbXYh0PzPO',
#     'id': '2UijQcg9x42vsbXYh0PzPO',
#     'name': 'Oh My Love',
#     'popularity': 61,
#     'uri': 'spotify:track:2UijQcg9x42vsbXYh0PzPO',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/33pt9HBdGlAbRGBHQgsZsU',
#      'id': '33pt9HBdGlAbRGBHQgsZsU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735675e83f707f1d7271e5cf8a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025675e83f707f1d7271e5cf8a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515675e83f707f1d7271e5cf8a',
#        'width': 64}],
#      'name': 'Evolve',
#      'release_date': '2017-06-23',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:33pt9HBdGlAbRGBHQgsZsU',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/33pt9HBdGlAbRGBHQgsZsU'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 204346,
#     'external_ids': {'isrc': 'USUM71700626'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0pqnGHJpmpxLKifKRmU6WP'},
#     'href': 'https://api.spotify.com/v1/tracks/0pqnGHJpmpxLKifKRmU6WP',
#     'id': '0pqnGHJpmpxLKifKRmU6WP',
#     'name': 'Believer',
#     'popularity': 86,
#     'uri': 'spotify:track:0pqnGHJpmpxLKifKRmU6WP',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/3RKhRsifs4RWrqvWV1YpPY',
#      'id': '3RKhRsifs4RWrqvWV1YpPY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739cfe80c0c05ce104f7bab18e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029cfe80c0c05ce104f7bab18e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519cfe80c0c05ce104f7bab18e',
#        'width': 64}],
#      'name': "Don't You Worry Child",
#      'release_date': '2012-09-14',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3RKhRsifs4RWrqvWV1YpPY',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1h6Cn3P4NGzXbaXidqURXs'},
#        'href': 'https://api.spotify.com/v1/artists/1h6Cn3P4NGzXbaXidqURXs',
#        'id': '1h6Cn3P4NGzXbaXidqURXs',
#        'name': 'Swedish House Mafia',
#        'type': 'artist',
#        'uri': 'spotify:artist:1h6Cn3P4NGzXbaXidqURXs'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2auikkNYqigWStoHWK1Grq'},
#        'href': 'https://api.spotify.com/v1/artists/2auikkNYqigWStoHWK1Grq',
#        'id': '2auikkNYqigWStoHWK1Grq',
#        'name': 'John Martin',
#        'type': 'artist',
#        'uri': 'spotify:artist:2auikkNYqigWStoHWK1Grq'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3RKhRsifs4RWrqvWV1YpPY'},
#      'total_tracks': 4},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1h6Cn3P4NGzXbaXidqURXs'},
#       'href': 'https://api.spotify.com/v1/artists/1h6Cn3P4NGzXbaXidqURXs',
#       'id': '1h6Cn3P4NGzXbaXidqURXs',
#       'name': 'Swedish House Mafia',
#       'type': 'artist',
#       'uri': 'spotify:artist:1h6Cn3P4NGzXbaXidqURXs'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2auikkNYqigWStoHWK1Grq'},
#       'href': 'https://api.spotify.com/v1/artists/2auikkNYqigWStoHWK1Grq',
#       'id': '2auikkNYqigWStoHWK1Grq',
#       'name': 'John Martin',
#       'type': 'artist',
#       'uri': 'spotify:artist:2auikkNYqigWStoHWK1Grq'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 212862,
#     'external_ids': {'isrc': 'GBAAA1200728'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2V65y3PX4DkRhy1djlxd9p'},
#     'href': 'https://api.spotify.com/v1/tracks/2V65y3PX4DkRhy1djlxd9p',
#     'id': '2V65y3PX4DkRhy1djlxd9p',
#     'name': "Don't You Worry Child - Radio Edit",
#     'popularity': 79,
#     'uri': 'spotify:track:2V65y3PX4DkRhy1djlxd9p',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/fb9f4a9b0887326776b4fb7c6d331acd167a7778?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1CEODgTmTwLyabvwd7HBty',
#      'id': '1CEODgTmTwLyabvwd7HBty',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e21cc1db05580b6f2d2a3b6e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e21cc1db05580b6f2d2a3b6e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e21cc1db05580b6f2d2a3b6e',
#        'width': 64}],
#      'name': 'Viva La Vida or Death and All His Friends',
#      'release_date': '2008-05-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1CEODgTmTwLyabvwd7HBty',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#        'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#        'id': '4gzpq5DPGxSnKTe4SA8HAU',
#        'name': 'Coldplay',
#        'type': 'artist',
#        'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1CEODgTmTwLyabvwd7HBty'},
#      'total_tracks': 10},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#       'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#       'id': '4gzpq5DPGxSnKTe4SA8HAU',
#       'name': 'Coldplay',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#     'disc_number': 1,
#     'track_number': 7,
#     'duration_ms': 242373,
#     'external_ids': {'isrc': 'GBAYE0800265'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1mea3bSkSGXuIRvnydlB5b'},
#     'href': 'https://api.spotify.com/v1/tracks/1mea3bSkSGXuIRvnydlB5b',
#     'id': '3Fcfwhm8oRrBvBZ8KGhtea',
#     'name': 'Viva La Vida',
#     'popularity': 86,
#     'uri': 'spotify:track:3Fcfwhm8oRrBvBZ8KGhtea',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1mea3bSkSGXuIRvnydlB5b'},
#      'href': 'https://api.spotify.com/v1/tracks/1mea3bSkSGXuIRvnydlB5b',
#      'id': '1mea3bSkSGXuIRvnydlB5b',
#      'type': 'track',
#      'uri': 'spotify:track:1mea3bSkSGXuIRvnydlB5b'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/c63915b1d3d5ae13082d18dfbc70a49b9032be23?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/49rPIZxBEwNFxZSdhcjiMr',
#      'id': '49rPIZxBEwNFxZSdhcjiMr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27309c4ea3b61b06d5b8ffaf690',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0209c4ea3b61b06d5b8ffaf690',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485109c4ea3b61b06d5b8ffaf690',
#        'width': 64}],
#      'name': 'Sleep',
#      'release_date': '2023-06-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:49rPIZxBEwNFxZSdhcjiMr',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oBcbbUQy8Md3FYXifyPTF'},
#        'href': 'https://api.spotify.com/v1/artists/2oBcbbUQy8Md3FYXifyPTF',
#        'id': '2oBcbbUQy8Md3FYXifyPTF',
#        'name': 'ConKi',
#        'type': 'artist',
#        'uri': 'spotify:artist:2oBcbbUQy8Md3FYXifyPTF'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1EtBmvqGOtWnjDgCUFQRqI'},
#        'href': 'https://api.spotify.com/v1/artists/1EtBmvqGOtWnjDgCUFQRqI',
#        'id': '1EtBmvqGOtWnjDgCUFQRqI',
#        'name': 'Rolipso',
#        'type': 'artist',
#        'uri': 'spotify:artist:1EtBmvqGOtWnjDgCUFQRqI'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6m4TPomVwYgFtvzRDjaaF5'},
#        'href': 'https://api.spotify.com/v1/artists/6m4TPomVwYgFtvzRDjaaF5',
#        'id': '6m4TPomVwYgFtvzRDjaaF5',
#        'name': 'Runforrest',
#        'type': 'artist',
#        'uri': 'spotify:artist:6m4TPomVwYgFtvzRDjaaF5'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/49rPIZxBEwNFxZSdhcjiMr'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oBcbbUQy8Md3FYXifyPTF'},
#       'href': 'https://api.spotify.com/v1/artists/2oBcbbUQy8Md3FYXifyPTF',
#       'id': '2oBcbbUQy8Md3FYXifyPTF',
#       'name': 'ConKi',
#       'type': 'artist',
#       'uri': 'spotify:artist:2oBcbbUQy8Md3FYXifyPTF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1EtBmvqGOtWnjDgCUFQRqI'},
#       'href': 'https://api.spotify.com/v1/artists/1EtBmvqGOtWnjDgCUFQRqI',
#       'id': '1EtBmvqGOtWnjDgCUFQRqI',
#       'name': 'Rolipso',
#       'type': 'artist',
#       'uri': 'spotify:artist:1EtBmvqGOtWnjDgCUFQRqI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6m4TPomVwYgFtvzRDjaaF5'},
#       'href': 'https://api.spotify.com/v1/artists/6m4TPomVwYgFtvzRDjaaF5',
#       'id': '6m4TPomVwYgFtvzRDjaaF5',
#       'name': 'Runforrest',
#       'type': 'artist',
#       'uri': 'spotify:artist:6m4TPomVwYgFtvzRDjaaF5'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 178235,
#     'external_ids': {'isrc': 'TCAGX2371907'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0rMuFOja3DhVSuXQeae25C'},
#     'href': 'https://api.spotify.com/v1/tracks/0rMuFOja3DhVSuXQeae25C',
#     'id': '0rMuFOja3DhVSuXQeae25C',
#     'name': 'Sleep',
#     'popularity': 62,
#     'uri': 'spotify:track:0rMuFOja3DhVSuXQeae25C',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/6c3e9bbcebdbfa7875c6a56c2bb4da2a870c250b?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/4bTjdxhRRUiWfwj200f9Kl',
#      'id': '4bTjdxhRRUiWfwj200f9Kl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735c8cfe4b2c4aa89c9c92108e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025c8cfe4b2c4aa89c9c92108e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515c8cfe4b2c4aa89c9c92108e',
#        'width': 64}],
#      'name': 'Nothing but the Beat (Ultimate Edition)',
#      'release_date': '2012-12-07',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:4bTjdxhRRUiWfwj200f9Kl',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#        'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#        'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#        'name': 'David Guetta',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4bTjdxhRRUiWfwj200f9Kl'},
#      'total_tracks': 29},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#       'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#       'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#       'name': 'David Guetta',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5WUlDfRSoLAfcVSX1WnrxN'},
#       'href': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN',
#       'id': '5WUlDfRSoLAfcVSX1WnrxN',
#       'name': 'Sia',
#       'type': 'artist',
#       'uri': 'spotify:artist:5WUlDfRSoLAfcVSX1WnrxN'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 245040,
#     'external_ids': {'isrc': 'GB28K1100036'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0TDLuuLlV54CkRRUOahJb4'},
#     'href': 'https://api.spotify.com/v1/tracks/0TDLuuLlV54CkRRUOahJb4',
#     'id': '0TDLuuLlV54CkRRUOahJb4',
#     'name': 'Titanium (feat. Sia)',
#     'popularity': 81,
#     'uri': 'spotify:track:0TDLuuLlV54CkRRUOahJb4',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/47BiFcV59TQi2s9SkBo2pb',
#      'id': '47BiFcV59TQi2s9SkBo2pb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c08d5fa5c0f1a834acef5100',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c08d5fa5c0f1a834acef5100',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c08d5fa5c0f1a834acef5100',
#        'width': 64}],
#      'name': 'Recovery',
#      'release_date': '2010-06-18',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:47BiFcV59TQi2s9SkBo2pb',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/47BiFcV59TQi2s9SkBo2pb'},
#      'total_tracks': 17},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'track_number': 7,
#     'duration_ms': 248133,
#     'external_ids': {'isrc': 'USUM71011769'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7Ie9W94M7OjPoZVV216Xus'},
#     'href': 'https://api.spotify.com/v1/tracks/7Ie9W94M7OjPoZVV216Xus',
#     'id': '7Ie9W94M7OjPoZVV216Xus',
#     'name': 'Not Afraid',
#     'popularity': 78,
#     'uri': 'spotify:track:7Ie9W94M7OjPoZVV216Xus',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2H6i2CrWgXE1HookLu8Au0',
#      'id': '2H6i2CrWgXE1HookLu8Au0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e14f11f796cef9f9a82691a7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e14f11f796cef9f9a82691a7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e14f11f796cef9f9a82691a7',
#        'width': 64}],
#      'name': 'True',
#      'release_date': '2013-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2H6i2CrWgXE1HookLu8Au0',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vCWHaC5f2uS3yhpwWbIA6'},
#        'href': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6',
#        'id': '1vCWHaC5f2uS3yhpwWbIA6',
#        'name': 'Avicii',
#        'type': 'artist',
#        'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2H6i2CrWgXE1HookLu8Au0'},
#      'total_tracks': 10},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vCWHaC5f2uS3yhpwWbIA6'},
#       'href': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6',
#       'id': '1vCWHaC5f2uS3yhpwWbIA6',
#       'name': 'Avicii',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 247426,
#     'external_ids': {'isrc': 'SEUM71301326'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0nrRP2bk19rLc0orkWPQk2'},
#     'href': 'https://api.spotify.com/v1/tracks/0nrRP2bk19rLc0orkWPQk2',
#     'id': '0nrRP2bk19rLc0orkWPQk2',
#     'name': 'Wake Me Up',
#     'popularity': 84,
#     'uri': 'spotify:track:0nrRP2bk19rLc0orkWPQk2',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/f4f547be3e5a2b06aa3b044500114760bd042531?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/0N0hk3tH9gOUDX0NkHIbNl',
#      'id': '0N0hk3tH9gOUDX0NkHIbNl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27392c9923ac254c9f4facab92a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0292c9923ac254c9f4facab92a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485192c9923ac254c9f4facab92a',
#        'width': 64}],
#      'name': 'Above the Clouds',
#      'release_date': '2023-03-16',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0N0hk3tH9gOUDX0NkHIbNl',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oBcbbUQy8Md3FYXifyPTF'},
#        'href': 'https://api.spotify.com/v1/artists/2oBcbbUQy8Md3FYXifyPTF',
#        'id': '2oBcbbUQy8Md3FYXifyPTF',
#        'name': 'ConKi',
#        'type': 'artist',
#        'uri': 'spotify:artist:2oBcbbUQy8Md3FYXifyPTF'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1gGoEoMd01jlEPtxTJo3jQ'},
#        'href': 'https://api.spotify.com/v1/artists/1gGoEoMd01jlEPtxTJo3jQ',
#        'id': '1gGoEoMd01jlEPtxTJo3jQ',
#        'name': 'K!llx',
#        'type': 'artist',
#        'uri': 'spotify:artist:1gGoEoMd01jlEPtxTJo3jQ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4gkZO2kbnE03K8xGmZ2DJu'},
#        'href': 'https://api.spotify.com/v1/artists/4gkZO2kbnE03K8xGmZ2DJu',
#        'id': '4gkZO2kbnE03K8xGmZ2DJu',
#        'name': 'Crooked Bangs',
#        'type': 'artist',
#        'uri': 'spotify:artist:4gkZO2kbnE03K8xGmZ2DJu'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0N0hk3tH9gOUDX0NkHIbNl'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oBcbbUQy8Md3FYXifyPTF'},
#       'href': 'https://api.spotify.com/v1/artists/2oBcbbUQy8Md3FYXifyPTF',
#       'id': '2oBcbbUQy8Md3FYXifyPTF',
#       'name': 'ConKi',
#       'type': 'artist',
#       'uri': 'spotify:artist:2oBcbbUQy8Md3FYXifyPTF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1gGoEoMd01jlEPtxTJo3jQ'},
#       'href': 'https://api.spotify.com/v1/artists/1gGoEoMd01jlEPtxTJo3jQ',
#       'id': '1gGoEoMd01jlEPtxTJo3jQ',
#       'name': 'K!llx',
#       'type': 'artist',
#       'uri': 'spotify:artist:1gGoEoMd01jlEPtxTJo3jQ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4gkZO2kbnE03K8xGmZ2DJu'},
#       'href': 'https://api.spotify.com/v1/artists/4gkZO2kbnE03K8xGmZ2DJu',
#       'id': '4gkZO2kbnE03K8xGmZ2DJu',
#       'name': 'Crooked Bangs',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gkZO2kbnE03K8xGmZ2DJu'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 157302,
#     'external_ids': {'isrc': 'TCAGS2357073'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7F96KtKIOWDuK7ElvMLlne'},
#     'href': 'https://api.spotify.com/v1/tracks/7F96KtKIOWDuK7ElvMLlne',
#     'id': '7F96KtKIOWDuK7ElvMLlne',
#     'name': 'Above the Clouds',
#     'popularity': 56,
#     'uri': 'spotify:track:7F96KtKIOWDuK7ElvMLlne',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/644d4ce6d4a3afce512d54904ce5872ccfb94493?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/30gnisiaho0Y6KRWJ7gIaA',
#      'id': '30gnisiaho0Y6KRWJ7gIaA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cb5ec46d6f1d2cf8d36d3663',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cb5ec46d6f1d2cf8d36d3663',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cb5ec46d6f1d2cf8d36d3663',
#        'width': 64}],
#      'name': 'Legends Never Die',
#      'release_date': '2017-09-15',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:30gnisiaho0Y6KRWJ7gIaA',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/47mIJdHORyRerp4os813jD'},
#        'href': 'https://api.spotify.com/v1/artists/47mIJdHORyRerp4os813jD',
#        'id': '47mIJdHORyRerp4os813jD',
#        'name': 'League of Legends',
#        'type': 'artist',
#        'uri': 'spotify:artist:47mIJdHORyRerp4os813jD'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6yhD1KjhLxIETFF7vIRf8B'},
#        'href': 'https://api.spotify.com/v1/artists/6yhD1KjhLxIETFF7vIRf8B',
#        'id': '6yhD1KjhLxIETFF7vIRf8B',
#        'name': 'Against The Current',
#        'type': 'artist',
#        'uri': 'spotify:artist:6yhD1KjhLxIETFF7vIRf8B'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/30gnisiaho0Y6KRWJ7gIaA'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/47mIJdHORyRerp4os813jD'},
#       'href': 'https://api.spotify.com/v1/artists/47mIJdHORyRerp4os813jD',
#       'id': '47mIJdHORyRerp4os813jD',
#       'name': 'League of Legends',
#       'type': 'artist',
#       'uri': 'spotify:artist:47mIJdHORyRerp4os813jD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6yhD1KjhLxIETFF7vIRf8B'},
#       'href': 'https://api.spotify.com/v1/artists/6yhD1KjhLxIETFF7vIRf8B',
#       'id': '6yhD1KjhLxIETFF7vIRf8B',
#       'name': 'Against The Current',
#       'type': 'artist',
#       'uri': 'spotify:artist:6yhD1KjhLxIETFF7vIRf8B'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 235000,
#     'external_ids': {'isrc': 'QMAF31500062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1FpVJ7HpZInE2GvhVE2TwT'},
#     'href': 'https://api.spotify.com/v1/tracks/1FpVJ7HpZInE2GvhVE2TwT',
#     'id': '1FpVJ7HpZInE2GvhVE2TwT',
#     'name': 'Legends Never Die',
#     'popularity': 74,
#     'uri': 'spotify:track:1FpVJ7HpZInE2GvhVE2TwT',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/03bbf447d8f0101cff90c78b3ab0c4757c3bf27b?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/2DoFm78vsYw31kJRzvIP4l',
#      'id': '2DoFm78vsYw31kJRzvIP4l',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d914470ab899815f103f5cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d914470ab899815f103f5cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d914470ab899815f103f5cc',
#        'width': 64}],
#      'name': 'Whatever',
#      'release_date': '2024-01-19',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2DoFm78vsYw31kJRzvIP4l',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#        'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#        'id': '23fqKkggKUBHNkbKtXEls4',
#        'name': 'Kygo',
#        'type': 'artist',
#        'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4npEfmQ6YuiwW1GpUmaq3F'},
#        'href': 'https://api.spotify.com/v1/artists/4npEfmQ6YuiwW1GpUmaq3F',
#        'id': '4npEfmQ6YuiwW1GpUmaq3F',
#        'name': 'Ava Max',
#        'type': 'artist',
#        'uri': 'spotify:artist:4npEfmQ6YuiwW1GpUmaq3F'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2DoFm78vsYw31kJRzvIP4l'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#       'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#       'id': '23fqKkggKUBHNkbKtXEls4',
#       'name': 'Kygo',
#       'type': 'artist',
#       'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4npEfmQ6YuiwW1GpUmaq3F'},
#       'href': 'https://api.spotify.com/v1/artists/4npEfmQ6YuiwW1GpUmaq3F',
#       'id': '4npEfmQ6YuiwW1GpUmaq3F',
#       'name': 'Ava Max',
#       'type': 'artist',
#       'uri': 'spotify:artist:4npEfmQ6YuiwW1GpUmaq3F'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 178273,
#     'external_ids': {'isrc': 'USRC12302637'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0LMwmV37RCmBO2so0szAFs'},
#     'href': 'https://api.spotify.com/v1/tracks/0LMwmV37RCmBO2so0szAFs',
#     'id': '0LMwmV37RCmBO2so0szAFs',
#     'name': 'Whatever',
#     'popularity': 79,
#     'uri': 'spotify:track:0LMwmV37RCmBO2so0szAFs',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/fa13db3d66f6daf051e9a3996090f7740532b9e8?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3xFSl9lIRaYXIYkIn3OIl9',
#      'id': '3xFSl9lIRaYXIYkIn3OIl9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735d199c9f6e6562aafa5aa357',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025d199c9f6e6562aafa5aa357',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515d199c9f6e6562aafa5aa357',
#        'width': 64}],
#      'name': '1000 Forms Of Fear',
#      'release_date': '2014-07-04',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3xFSl9lIRaYXIYkIn3OIl9',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5WUlDfRSoLAfcVSX1WnrxN'},
#        'href': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN',
#        'id': '5WUlDfRSoLAfcVSX1WnrxN',
#        'name': 'Sia',
#        'type': 'artist',
#        'uri': 'spotify:artist:5WUlDfRSoLAfcVSX1WnrxN'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3xFSl9lIRaYXIYkIn3OIl9'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5WUlDfRSoLAfcVSX1WnrxN'},
#       'href': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN',
#       'id': '5WUlDfRSoLAfcVSX1WnrxN',
#       'name': 'Sia',
#       'type': 'artist',
#       'uri': 'spotify:artist:5WUlDfRSoLAfcVSX1WnrxN'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 216120,
#     'external_ids': {'isrc': 'USRC11400498'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4VrWlk8IQxevMvERoX08iC'},
#     'href': 'https://api.spotify.com/v1/tracks/4VrWlk8IQxevMvERoX08iC',
#     'id': '4VrWlk8IQxevMvERoX08iC',
#     'name': 'Chandelier',
#     'popularity': 81,
#     'uri': 'spotify:track:4VrWlk8IQxevMvERoX08iC',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/920ce84f8d72c5549ad5da00546317f59cf4ff18?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/55jVI9kGeE9GL2hmtr0pel',
#      'id': '55jVI9kGeE9GL2hmtr0pel',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ad794a50c8be7c2475e7678b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ad794a50c8be7c2475e7678b',
# ...
#      'type': 'album',
#      'album_type': 'compilation',
#      'href': 'https://api.spotify.com/v1/albums/6Vl1FiigNmVpKDMXpRVUCA',
#      'id': '6Vl1FiigNmVpKDMXpRVUCA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273240501e829a9a109600cedd2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02240501e829a9a109600cedd2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851240501e829a9a109600cedd2',
#        'width': 64}],
#      'name': 'CREED: Original Motion Picture Soundtrack',
#      'release_date': '2015-11-20',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6Vl1FiigNmVpKDMXpRVUCA',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Vl1FiigNmVpKDMXpRVUCA'},
#      'total_tracks': 18},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#       'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#       'id': '1RyvyyTE3xzB2ZywiAwp0i',
#       'name': 'Future',
#       'type': 'artist',
#       'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 239800,
#     'external_ids': {'isrc': 'USAT21503872'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Arjo1XR9qXsLstvU9fFV3'},
#     'href': 'https://api.spotify.com/v1/tracks/4Arjo1XR9qXsLstvU9fFV3',
#     'id': '4oBX7V6xzWYAkf0fw9V8Ln',
#     'name': 'Last Breath',
#     'popularity': 60,
#     'uri': 'spotify:track:4oBX7V6xzWYAkf0fw9V8Ln',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4Arjo1XR9qXsLstvU9fFV3'},
#      'href': 'https://api.spotify.com/v1/tracks/4Arjo1XR9qXsLstvU9fFV3',
#      'id': '4Arjo1XR9qXsLstvU9fFV3',
#      'type': 'track',
#      'uri': 'spotify:track:4Arjo1XR9qXsLstvU9fFV3'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/13afa0b03a24383e684af788736189336d72f5b9?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/63sE70VvXeP2BzQwKlnF9i',
#      'id': '63sE70VvXeP2BzQwKlnF9i',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733b24c0fa28c69082b2cd691b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023b24c0fa28c69082b2cd691b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513b24c0fa28c69082b2cd691b',
#        'width': 64}],
#      'name': "It's a Shame",
#      'release_date': '2024-07-25',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:63sE70VvXeP2BzQwKlnF9i',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zvz5hBfgDUVELgOESPh2w'},
#        'href': 'https://api.spotify.com/v1/artists/5zvz5hBfgDUVELgOESPh2w',
#        'id': '5zvz5hBfgDUVELgOESPh2w',
#        'name': 'TUDOR',
#        'type': 'artist',
#        'uri': 'spotify:artist:5zvz5hBfgDUVELgOESPh2w'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0MWLVPNoBVvkwtfJiBGlm5'},
#        'href': 'https://api.spotify.com/v1/artists/0MWLVPNoBVvkwtfJiBGlm5',
#        'id': '0MWLVPNoBVvkwtfJiBGlm5',
#        'name': 'muuno',
#        'type': 'artist',
#        'uri': 'spotify:artist:0MWLVPNoBVvkwtfJiBGlm5'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3JmD9HEyTy3vtITvwUFK9K'},
#        'href': 'https://api.spotify.com/v1/artists/3JmD9HEyTy3vtITvwUFK9K',
#        'id': '3JmD9HEyTy3vtITvwUFK9K',
#        'name': 'Sam Welch',
#        'type': 'artist',
#        'uri': 'spotify:artist:3JmD9HEyTy3vtITvwUFK9K'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/63sE70VvXeP2BzQwKlnF9i'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zvz5hBfgDUVELgOESPh2w'},
#       'href': 'https://api.spotify.com/v1/artists/5zvz5hBfgDUVELgOESPh2w',
#       'id': '5zvz5hBfgDUVELgOESPh2w',
#       'name': 'TUDOR',
#       'type': 'artist',
#       'uri': 'spotify:artist:5zvz5hBfgDUVELgOESPh2w'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0MWLVPNoBVvkwtfJiBGlm5'},
#       'href': 'https://api.spotify.com/v1/artists/0MWLVPNoBVvkwtfJiBGlm5',
#       'id': '0MWLVPNoBVvkwtfJiBGlm5',
#       'name': 'muuno',
#       'type': 'artist',
#       'uri': 'spotify:artist:0MWLVPNoBVvkwtfJiBGlm5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3JmD9HEyTy3vtITvwUFK9K'},
#       'href': 'https://api.spotify.com/v1/artists/3JmD9HEyTy3vtITvwUFK9K',
#       'id': '3JmD9HEyTy3vtITvwUFK9K',
#       'name': 'Sam Welch',
#       'type': 'artist',
#       'uri': 'spotify:artist:3JmD9HEyTy3vtITvwUFK9K'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 168000,
#     'external_ids': {'isrc': 'TCAII2469807'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2DBz27islCy7DhbycAQFJM'},
#     'href': 'https://api.spotify.com/v1/tracks/2DBz27islCy7DhbycAQFJM',
#     'id': '2DBz27islCy7DhbycAQFJM',
#     'name': "It's a Shame",
#     'popularity': 51,
#     'uri': 'spotify:track:2DBz27islCy7DhbycAQFJM',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/4068da63f2894e027be64e53ffec8745f82b4945?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/5mQ40yy9zpVtfoHMqkK6ML',
#      'id': '5mQ40yy9zpVtfoHMqkK6ML',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273186fcf8af2ba7e46b065f58b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02186fcf8af2ba7e46b065f58b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851186fcf8af2ba7e46b065f58b',
#        'width': 64}],
#      'name': 'Rockstar',
#      'release_date': '2024-08-09',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5mQ40yy9zpVtfoHMqkK6ML',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OE3dz6RhP1rdri5pcQY0c'},
#        'href': 'https://api.spotify.com/v1/artists/3OE3dz6RhP1rdri5pcQY0c',
#        'id': '3OE3dz6RhP1rdri5pcQY0c',
#        'name': 'Carl Clarks',
#        'type': 'artist',
#        'uri': 'spotify:artist:3OE3dz6RhP1rdri5pcQY0c'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5mQ40yy9zpVtfoHMqkK6ML'},
#      'total_tracks': 2},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OE3dz6RhP1rdri5pcQY0c'},
#       'href': 'https://api.spotify.com/v1/artists/3OE3dz6RhP1rdri5pcQY0c',
#       'id': '3OE3dz6RhP1rdri5pcQY0c',
#       'name': 'Carl Clarks',
#       'type': 'artist',
#       'uri': 'spotify:artist:3OE3dz6RhP1rdri5pcQY0c'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 209454,
#     'external_ids': {'isrc': 'DEA312401132'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/460tyHiP1cF7VQqNsVQjwe'},
#     'href': 'https://api.spotify.com/v1/tracks/460tyHiP1cF7VQqNsVQjwe',
#     'id': '460tyHiP1cF7VQqNsVQjwe',
#     'name': 'Rockstar',
#     'popularity': 43,
#     'uri': 'spotify:track:460tyHiP1cF7VQqNsVQjwe',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/d6b8b5c65c25c1d5f063dcbe6485d63c12bd276f?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/75R8Pj83IC1FpjexkJWidU',
#      'id': '75R8Pj83IC1FpjexkJWidU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273111b7e7abcc2fffc28965e53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02111b7e7abcc2fffc28965e53',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851111b7e7abcc2fffc28965e53',
#        'width': 64}],
#      'name': 'Always Remember',
#      'release_date': '2023-10-12',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:75R8Pj83IC1FpjexkJWidU',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6sxcddx1xFwv0MblwbXNVq'},
#        'href': 'https://api.spotify.com/v1/artists/6sxcddx1xFwv0MblwbXNVq',
#        'id': '6sxcddx1xFwv0MblwbXNVq',
#        'name': 'jeonghyeon',
#        'type': 'artist',
#        'uri': 'spotify:artist:6sxcddx1xFwv0MblwbXNVq'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nL523vzwv24ad0oFf2VZ2'},
#        'href': 'https://api.spotify.com/v1/artists/7nL523vzwv24ad0oFf2VZ2',
#        'id': '7nL523vzwv24ad0oFf2VZ2',
#        'name': 'Able Faces',
#        'type': 'artist',
#        'uri': 'spotify:artist:7nL523vzwv24ad0oFf2VZ2'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/75R8Pj83IC1FpjexkJWidU'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6sxcddx1xFwv0MblwbXNVq'},
#       'href': 'https://api.spotify.com/v1/artists/6sxcddx1xFwv0MblwbXNVq',
#       'id': '6sxcddx1xFwv0MblwbXNVq',
#       'name': 'jeonghyeon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6sxcddx1xFwv0MblwbXNVq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nL523vzwv24ad0oFf2VZ2'},
#       'href': 'https://api.spotify.com/v1/artists/7nL523vzwv24ad0oFf2VZ2',
#       'id': '7nL523vzwv24ad0oFf2VZ2',
#       'name': 'Able Faces',
#       'type': 'artist',
#       'uri': 'spotify:artist:7nL523vzwv24ad0oFf2VZ2'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 176640,
#     'external_ids': {'isrc': 'TCAHH2311022'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2gZ7eMtPgsaIJstAYPgYVT'},
#     'href': 'https://api.spotify.com/v1/tracks/2gZ7eMtPgsaIJstAYPgYVT',
#     'id': '2gZ7eMtPgsaIJstAYPgYVT',
#     'name': 'Always Remember',
#     'popularity': 48,
#     'uri': 'spotify:track:2gZ7eMtPgsaIJstAYPgYVT',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-10-04T18:31:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hotamazingnetwork'},
#     'href': 'https://api.spotify.com/v1/users/hotamazingnetwork',
#     'id': 'hotamazingnetwork',
#     'type': 'user',
#     'uri': 'spotify:user:hotamazingnetwork'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/3473f6e00f0a24e8189949dbdc418ca89bd8f9c5?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/6SBBMq5ma87HuFxkje7HLs',
#      'id': '6SBBMq5ma87HuFxkje7HLs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731a393d5f471bf8c210dfd763',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021a393d5f471bf8c210dfd763',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511a393d5f471bf8c210dfd763',
#        'width': 64}],
#      'name': 'Mesmerized',
#      'release_date': '2024-05-30',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6SBBMq5ma87HuFxkje7HLs',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23ShYrOhu7gvdxz5NcIQx5'},
#        'href': 'https://api.spotify.com/v1/artists/23ShYrOhu7gvdxz5NcIQx5',
#        'id': '23ShYrOhu7gvdxz5NcIQx5',
#        'name': 'INViDA',
#        'type': 'artist',
#        'uri': 'spotify:artist:23ShYrOhu7gvdxz5NcIQx5'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/40SW02sSkgw10VTYc6UT9H'},
#        'href': 'https://api.spotify.com/v1/artists/40SW02sSkgw10VTYc6UT9H',
#        'id': '40SW02sSkgw10VTYc6UT9H',
#        'name': 'Alvin Anthony',
#        'type': 'artist',
#        'uri': 'spotify:artist:40SW02sSkgw10VTYc6UT9H'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/22bKgyDEmDgPhvSBYklJBe'},
#        'href': 'https://api.spotify.com/v1/artists/22bKgyDEmDgPhvSBYklJBe',
#        'id': '22bKgyDEmDgPhvSBYklJBe',
#        'name': 'Luxtides',
#        'type': 'artist',
#        'uri': 'spotify:artist:22bKgyDEmDgPhvSBYklJBe'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6SBBMq5ma87HuFxkje7HLs'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23ShYrOhu7gvdxz5NcIQx5'},
#       'href': 'https://api.spotify.com/v1/artists/23ShYrOhu7gvdxz5NcIQx5',
#       'id': '23ShYrOhu7gvdxz5NcIQx5',
#       'name': 'INViDA',
#       'type': 'artist',
#       'uri': 'spotify:artist:23ShYrOhu7gvdxz5NcIQx5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/40SW02sSkgw10VTYc6UT9H'},
#       'href': 'https://api.spotify.com/v1/artists/40SW02sSkgw10VTYc6UT9H',
#       'id': '40SW02sSkgw10VTYc6UT9H',
#       'name': 'Alvin Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:40SW02sSkgw10VTYc6UT9H'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/22bKgyDEmDgPhvSBYklJBe'},
#       'href': 'https://api.spotify.com/v1/artists/22bKgyDEmDgPhvSBYklJBe',
#       'id': '22bKgyDEmDgPhvSBYklJBe',
#       'name': 'Luxtides',
#       'type': 'artist',
#       'uri': 'spotify:artist:22bKgyDEmDgPhvSBYklJBe'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 130000,
#     'external_ids': {'isrc': 'TCAIE2429679'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4nmDwwaz4eV09GAZPgoZPo'},
#     'href': 'https://api.spotify.com/v1/tracks/4nmDwwaz4eV09GAZPgoZPo',
#     'id': '4nmDwwaz4eV09GAZPgoZPo',
#     'name': 'Mesmerized',
#     'popularity': 48,
#     'uri': 'spotify:track:4nmDwwaz4eV09GAZPgoZPo',
#     'is_local': False},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/2fmxVDpboTzLaLAfj5ZaQW/tracks?offset=100&limit=100&market=DE&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 106}

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_motivation['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_motivation_df = pd.DataFrame(song_features)
# Keep relevant columns
df_motivation = playlist_motivation_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_motivation["names"] = song_names

# Display the resulting DataFrame
display(df_motivation)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/3527156631.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_motivation["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.672   0.655    -5.021       0.0310      0.036200
# 1          0.421   0.873    -4.343       0.0564      0.065400
# 2          0.527   0.835    -5.298       0.0433      0.016600
# 3          0.678   0.744    -4.058       0.2340      0.495000
# 4          0.635   0.809    -5.642       0.0421      0.468000
# ..           ...     ...       ...          ...           ...
# 95         0.675   0.758    -4.589       0.0368      0.431000
# 96         0.742   0.772    -6.275       0.0523      0.009450
# 97         0.745   0.625    -8.971       0.0342      0.038400
# 98         0.669   0.907    -3.654       0.0372      0.107000
# 99         0.612   0.937    -6.234       0.0341      0.000831
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.1170   0.5550  134.948  6Qn5zhYkTa37e91HC1D7lb
# 1           0.000000    0.1230   0.6290   84.786  7wMq5n8mYSKlQIGECKUgTX
# 2           0.000000    0.2490   0.6540  125.983  0ct6r3EGTcMLPtrXHDvVjc
# 3           0.000023    0.0631   0.4330  101.987  0F3v8p8ZnEGtZDxNcJ5Klq
# 4           0.000407    0.1000   0.0889  123.978  2UijQcg9x42vsbXYh0PzPO
# ..               ...       ...      ...      ...                     ...
# 95          0.001770    0.3770   0.1520   89.982  4oBX7V6xzWYAkf0fw9V8Ln
# 96          0.000187    0.3270   0.0966  124.978  2DBz27islCy7DhbycAQFJM
# 97          0.000000    0.1460   0.4000  109.976  460tyHiP1cF7VQqNsVQjwe
# 98          0.000694    0.1720   0.7010  125.017  2gZ7eMtPgsaIJstAYPgYVT
# 99          0.002950    0.1690   0.2590  132.075  4nmDwwaz4eV09GAZPgoZPo
#
#     duration_ms                           names
# 0        201240               Whatever It Takes
# 1        202533  Hall of Fame (feat. will.i.am)
# 2        176658                      The Nights
# 3        162353       Unstoppable - R3HAB Remix
# 4        164516                      Oh My Love
# ..          ...                             ...
# 95       239800                     Last Breath
# 96       168000                    It's a Shame
# 97       209455                        Rockstar
# 98       176640                 Always Remember
# 99       130000                      Mesmerized
#
# [100 rows x 12 columns]

# %%
playlist_pop = sp.user_playlist_tracks("spotify", "6mtYuOxzl58vSGnEDtZ9uB",market="DE")
playlist_pop
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6mtYuOxzl58vSGnEDtZ9uB/tracks?offset=0&limit=100&market=DE&additional_types=track',
#  'items': [{'added_at': '2017-05-05T17:50:40Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3OZgEywV4krCZ814pTJWr7',
#      'id': '3OZgEywV4krCZ814pTJWr7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735f9393fda71e7df39b34defd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025f9393fda71e7df39b34defd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515f9393fda71e7df39b34defd',
#        'width': 64}],
#      'name': 'Dangerous Woman',
#      'release_date': '2016-05-20',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3OZgEywV4krCZ814pTJWr7',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#        'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#        'id': '66CXWjxzNUsdJxJ2JdwvnR',
#        'name': 'Ariana Grande',
#        'type': 'artist',
#        'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3OZgEywV4krCZ814pTJWr7'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 244453,
#     'external_ids': {'isrc': 'USUM71601827'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2meEiZKWkiN28gITzFwQo5'},
#     'href': 'https://api.spotify.com/v1/tracks/2meEiZKWkiN28gITzFwQo5',
#     'id': '76FZM38RC8XaAjJ77CVTNe',
#     'name': 'Into You',
#     'popularity': 21,
#     'uri': 'spotify:track:76FZM38RC8XaAjJ77CVTNe',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2meEiZKWkiN28gITzFwQo5'},
#      'href': 'https://api.spotify.com/v1/tracks/2meEiZKWkiN28gITzFwQo5',
#      'id': '2meEiZKWkiN28gITzFwQo5',
#      'type': 'track',
#      'uri': 'spotify:track:2meEiZKWkiN28gITzFwQo5'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-03T19:09:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/2ZmXUoLcHfK4Y7WctcYk60',
#      'id': '2ZmXUoLcHfK4Y7WctcYk60',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27369e5c7973254136e3228fa34',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0269e5c7973254136e3228fa34',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485169e5c7973254136e3228fa34',
#        'width': 64}],
#      'name': 'Glad You Came',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2ZmXUoLcHfK4Y7WctcYk60',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NhdGz9EDv2FeUw6udu2g1'},
#        'href': 'https://api.spotify.com/v1/artists/2NhdGz9EDv2FeUw6udu2g1',
#        'id': '2NhdGz9EDv2FeUw6udu2g1',
#        'name': 'The Wanted',
#        'type': 'artist',
#        'uri': 'spotify:artist:2NhdGz9EDv2FeUw6udu2g1'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ZmXUoLcHfK4Y7WctcYk60'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NhdGz9EDv2FeUw6udu2g1'},
#       'href': 'https://api.spotify.com/v1/artists/2NhdGz9EDv2FeUw6udu2g1',
#       'id': '2NhdGz9EDv2FeUw6udu2g1',
#       'name': 'The Wanted',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NhdGz9EDv2FeUw6udu2g1'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 198466,
#     'external_ids': {'isrc': 'GBUM71107952'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1OXfWI3FQMdsKKC6lkvzSx'},
#     'href': 'https://api.spotify.com/v1/tracks/1OXfWI3FQMdsKKC6lkvzSx',
#     'id': '5yDL13y5giogKs2fSNf7sj',
#     'name': 'Glad You Came',
#     'popularity': 4,
#     'uri': 'spotify:track:5yDL13y5giogKs2fSNf7sj',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1OXfWI3FQMdsKKC6lkvzSx'},
#      'href': 'https://api.spotify.com/v1/tracks/1OXfWI3FQMdsKKC6lkvzSx',
#      'id': '1OXfWI3FQMdsKKC6lkvzSx',
#      'type': 'track',
#      'uri': 'spotify:track:1OXfWI3FQMdsKKC6lkvzSx'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-04-24T10:58:22Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/5184d19d1b7fcc3e7c067e38af45a7cc80851440?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/7I0tjwFtxUwBC1vgyeMAax',
#      'id': '7I0tjwFtxUwBC1vgyeMAax',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f429549123dbe8552764ba1d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f429549123dbe8552764ba1d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f429549123dbe8552764ba1d',
#        'width': 64}],
#      'name': 'Flowers',
#      'release_date': '2023-01-13',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:7I0tjwFtxUwBC1vgyeMAax',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#        'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#        'id': '5YGY8feqx7naU7z4HrwZM6',
#        'name': 'Miley Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#       'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#       'id': '5YGY8feqx7naU7z4HrwZM6',
#       'name': 'Miley Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 200454,
#     'external_ids': {'isrc': 'USSM12209777'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn'},
#     'href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#     'id': '7DSAEUvxU8FajXtRloy8M0',
#     'name': 'Flowers',
#     'popularity': 29,
#     'uri': 'spotify:track:7DSAEUvxU8FajXtRloy8M0',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn'},
#      'href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#      'id': '0yLdNVWF3Srea0uzk55zFn',
#      'type': 'track',
#      'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-03T19:13:11Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/e187153d84f4b0876b2d1218ae890f8817b4c66f?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'compilation',
#      'href': 'https://api.spotify.com/v1/albums/2tUn9E3nHXhUIJ47yv6ePD',
#      'id': '2tUn9E3nHXhUIJ47yv6ePD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ece7e052f39ec51fac31aa39',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ece7e052f39ec51fac31aa39',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ece7e052f39ec51fac31aa39',
#        'width': 64}],
#      'name': 'Greatest Hits...So Far!!!',
#      'release_date': '2010-11-12',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2tUn9E3nHXhUIJ47yv6ePD',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1KCSPY1glIKqW2TotWuXOR'},
#        'href': 'https://api.spotify.com/v1/artists/1KCSPY1glIKqW2TotWuXOR',
#        'id': '1KCSPY1glIKqW2TotWuXOR',
#        'name': 'P!nk',
#        'type': 'artist',
#        'uri': 'spotify:artist:1KCSPY1glIKqW2TotWuXOR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2tUn9E3nHXhUIJ47yv6ePD'},
#      'total_tracks': 18},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1KCSPY1glIKqW2TotWuXOR'},
#       'href': 'https://api.spotify.com/v1/artists/1KCSPY1glIKqW2TotWuXOR',
#       'id': '1KCSPY1glIKqW2TotWuXOR',
#       'name': 'P!nk',
#       'type': 'artist',
#       'uri': 'spotify:artist:1KCSPY1glIKqW2TotWuXOR'}],
#     'disc_number': 1,
#     'track_number': 8,
#     'duration_ms': 207893,
#     'external_ids': {'isrc': 'USLF20600021'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4pSPMXaCjbaV3VSzZQYC7H'},
#     'href': 'https://api.spotify.com/v1/tracks/4pSPMXaCjbaV3VSzZQYC7H',
#     'id': '2hns6Dv29Yrg68AVTJiAyA',
#     'name': 'Who Knew - Edit',
#     'popularity': 5,
#     'uri': 'spotify:track:2hns6Dv29Yrg68AVTJiAyA',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4pSPMXaCjbaV3VSzZQYC7H'},
#      'href': 'https://api.spotify.com/v1/tracks/4pSPMXaCjbaV3VSzZQYC7H',
#      'id': '4pSPMXaCjbaV3VSzZQYC7H',
#      'type': 'track',
#      'uri': 'spotify:track:4pSPMXaCjbaV3VSzZQYC7H'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-12T14:27:56Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/ca7bdcb691fb64a5af8a3253b89356390664fcf1?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/3UOV8XvCwMKaATRNXrYCjN',
#      'id': '3UOV8XvCwMKaATRNXrYCjN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27322fd802bc61db666c7c81aa8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0222fd802bc61db666c7c81aa8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485122fd802bc61db666c7c81aa8',
#        'width': 64}],
#      'name': 'greedy',
#      'release_date': '2023-09-15',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3UOV8XvCwMKaATRNXrYCjN',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#        'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#        'id': '45dkTj5sMRSjrmBSBeiHym',
#        'name': 'Tate McRae',
#        'type': 'artist',
#        'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#       'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#       'id': '45dkTj5sMRSjrmBSBeiHym',
#       'name': 'Tate McRae',
#       'type': 'artist',
#       'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 131872,
#     'external_ids': {'isrc': 'USRC12301932'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3rUGC1vUpkDG9CZFHMur1t'},
#     'href': 'https://api.spotify.com/v1/tracks/3rUGC1vUpkDG9CZFHMur1t',
#     'id': '3rUGC1vUpkDG9CZFHMur1t',
#     'name': 'greedy',
#     'popularity': 87,
#     'uri': 'spotify:track:3rUGC1vUpkDG9CZFHMur1t',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-03T19:16:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/3bf2d48a92c9a21ddb14d8aae379488ff0604aff?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5lkNnHVlnCCCV304t89wOH',
#      'id': '5lkNnHVlnCCCV304t89wOH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737947bf3e8af32378de181b41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027947bf3e8af32378de181b41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517947bf3e8af32378de181b41',
#        'width': 64}],
#      'name': 'My House',
#      'release_date': '2015-04-07',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5lkNnHVlnCCCV304t89wOH',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#        'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#        'id': '0jnsk9HBra6NMjO2oANoPY',
#        'name': 'Flo Rida',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5lkNnHVlnCCCV304t89wOH'},
#      'total_tracks': 7},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#       'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#       'id': '0jnsk9HBra6NMjO2oANoPY',
#       'name': 'Flo Rida',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 192190,
#     'external_ids': {'isrc': 'USAT21500384'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Knv6wdA0luoMUuuoYi2i1'},
#     'href': 'https://api.spotify.com/v1/tracks/6Knv6wdA0luoMUuuoYi2i1',
#     'id': '6Knv6wdA0luoMUuuoYi2i1',
#     'name': 'My House',
#     'popularity': 75,
#     'uri': 'spotify:track:6Knv6wdA0luoMUuuoYi2i1',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-04T20:44:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2IKALqf7an1mDR7eGupCGr',
#      'id': '2IKALqf7an1mDR7eGupCGr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27347ae10230299bc80c9e22a89',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0247ae10230299bc80c9e22a89',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485147ae10230299bc80c9e22a89',
#        'width': 64}],
#      'name': 'One Of The Boys',
#      'release_date': '2008-06-17',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2IKALqf7an1mDR7eGupCGr',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2IKALqf7an1mDR7eGupCGr'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'disc_number': 1,
#     'track_number': 7,
#     'duration_ms': 220226,
#     'external_ids': {'isrc': 'USCA20802544'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2AZXe8nq18mPITmPy5KJwQ'},
#     'href': 'https://api.spotify.com/v1/tracks/2AZXe8nq18mPITmPy5KJwQ',
#     'id': '0iGckQFyv6svOfAbAY9aWJ',
#     'name': 'Hot N Cold',
#     'popularity': 31,
#     'uri': 'spotify:track:0iGckQFyv6svOfAbAY9aWJ',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2AZXe8nq18mPITmPy5KJwQ'},
#      'href': 'https://api.spotify.com/v1/tracks/2AZXe8nq18mPITmPy5KJwQ',
#      'id': '2AZXe8nq18mPITmPy5KJwQ',
#      'type': 'track',
#      'uri': 'spotify:track:2AZXe8nq18mPITmPy5KJwQ'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-05-14T09:13:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5dGWwsZ9iB2Xc3UKR0gif2',
#      'id': '5dGWwsZ9iB2Xc3UKR0gif2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e6f407c7f3a0ec98845e4431',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e6f407c7f3a0ec98845e4431',
#        'width': 64}],
#      'name': 'Justice',
#      'release_date': '2021-03-19',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5dGWwsZ9iB2Xc3UKR0gif2',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dGWwsZ9iB2Xc3UKR0gif2'},
#      'total_tracks': 16},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#       'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#       'id': '20wkVLutqVOYrc0kxFs7rA',
#       'name': 'Daniel Caesar',
#       'type': 'artist',
#       'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#       'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#       'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#       'name': 'Giveon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#     'disc_number': 1,
#     'track_number': 12,
#     'duration_ms': 198081,
#     'external_ids': {'isrc': 'USUM72102636'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4iJyoBOLtHqaGxP12qzhQI'},
#     'href': 'https://api.spotify.com/v1/tracks/4iJyoBOLtHqaGxP12qzhQI',
#     'id': '4iJyoBOLtHqaGxP12qzhQI',
#     'name': 'Peaches (feat. Daniel Caesar & Giveon)',
#     'popularity': 79,
#     'uri': 'spotify:track:4iJyoBOLtHqaGxP12qzhQI',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-12T14:31:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/64LU4c1nfjz1t4VnGhagcg',
#      'id': '64LU4c1nfjz1t4VnGhagcg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273904445d70d04eb24d6bb79ac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02904445d70d04eb24d6bb79ac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851904445d70d04eb24d6bb79ac',
#        'width': 64}],
#      'name': "1989 (Taylor's Version)",
#      'release_date': '2023-10-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:64LU4c1nfjz1t4VnGhagcg',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/64LU4c1nfjz1t4VnGhagcg'},
#      'total_tracks': 21},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'disc_number': 1,
#     'track_number': 9,
#     'duration_ms': 220433,
#     'external_ids': {'isrc': 'USUG12103658'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1K39ty6o1sHwwlZwO6a7wK'},
#     'href': 'https://api.spotify.com/v1/tracks/1K39ty6o1sHwwlZwO6a7wK',
#     'id': '1K39ty6o1sHwwlZwO6a7wK',
#     'name': "Wildest Dreams (Taylor's Version)",
#     'popularity': 75,
#     'uri': 'spotify:track:1K39ty6o1sHwwlZwO6a7wK',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-04-24T10:58:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/c43dd07043b29e800c1a65b3a0102861fa3cf418?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/2pqdSWeJVsXAhHFuVLzuA8',
#      'id': '2pqdSWeJVsXAhHFuVLzuA8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b46f74097655d7f353caab14',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b46f74097655d7f353caab14',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b46f74097655d7f353caab14',
#        'width': 64}],
#      'name': 'As It Was',
#      'release_date': '2022-03-31',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2pqdSWeJVsXAhHFuVLzuA8',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#        'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#        'id': '6KImCVD70vtIoJWnq6nGn3',
#        'name': 'Harry Styles',
#        'type': 'artist',
#        'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2pqdSWeJVsXAhHFuVLzuA8'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#       'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#       'id': '6KImCVD70vtIoJWnq6nGn3',
#       'name': 'Harry Styles',
#       'type': 'artist',
#       'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 167303,
#     'external_ids': {'isrc': 'USSM12200612'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4LRPiXqCikLlN15c3yImP7'},
#     'href': 'https://api.spotify.com/v1/tracks/4LRPiXqCikLlN15c3yImP7',
#     'id': '4Dvkj6JhhA12EX05fT7y2e',
#     'name': 'As It Was',
#     'popularity': 29,
#     'uri': 'spotify:track:4Dvkj6JhhA12EX05fT7y2e',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4LRPiXqCikLlN15c3yImP7'},
#      'href': 'https://api.spotify.com/v1/tracks/4LRPiXqCikLlN15c3yImP7',
#      'id': '4LRPiXqCikLlN15c3yImP7',
#      'type': 'track',
#      'uri': 'spotify:track:4LRPiXqCikLlN15c3yImP7'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-06-25T13:16:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/44a403f99aefaa4c055d257f9fd09e413a9c16e9?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2Z9WUERfMjOgQ6ze9TcGbF',
#      'id': '2Z9WUERfMjOgQ6ze9TcGbF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731c3e0a58f3ee28af2922e351',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021c3e0a58f3ee28af2922e351',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511c3e0a58f3ee28af2922e351',
#        'width': 64}],
#      'name': 'Little Voice',
#      'release_date': '2007-07-03',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2Z9WUERfMjOgQ6ze9TcGbF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Sqr0DXoaYABbjBo9HaMkM'},
#        'href': 'https://api.spotify.com/v1/artists/2Sqr0DXoaYABbjBo9HaMkM',
#        'id': '2Sqr0DXoaYABbjBo9HaMkM',
#        'name': 'Sara Bareilles',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Sqr0DXoaYABbjBo9HaMkM'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Z9WUERfMjOgQ6ze9TcGbF'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Sqr0DXoaYABbjBo9HaMkM'},
#       'href': 'https://api.spotify.com/v1/artists/2Sqr0DXoaYABbjBo9HaMkM',
#       'id': '2Sqr0DXoaYABbjBo9HaMkM',
#       'name': 'Sara Bareilles',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Sqr0DXoaYABbjBo9HaMkM'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 258826,
#     'external_ids': {'isrc': 'USSM10700066'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4E6cwWJWZw2zWf7VFbH7wf'},
#     'href': 'https://api.spotify.com/v1/tracks/4E6cwWJWZw2zWf7VFbH7wf',
#     'id': '4E6cwWJWZw2zWf7VFbH7wf',
#     'name': 'Love Song',
#     'popularity': 73,
#     'uri': 'spotify:track:4E6cwWJWZw2zWf7VFbH7wf',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-04T20:44:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3acnMNG6Um5zdLJgUOAKz8',
#      'id': '3acnMNG6Um5zdLJgUOAKz8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d41d1ad03557a33548cd8941',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d41d1ad03557a33548cd8941',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d41d1ad03557a33548cd8941',
#        'width': 64}],
#      'name': 'When the Sun Goes Down (Deluxe Edition)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3acnMNG6Um5zdLJgUOAKz8',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dJeKm76NjfXBNTpHmOhfO'},
#        'href': 'https://api.spotify.com/v1/artists/6dJeKm76NjfXBNTpHmOhfO',
#        'id': '6dJeKm76NjfXBNTpHmOhfO',
#        'name': 'Selena Gomez & The Scene',
#        'type': 'artist',
#        'uri': 'spotify:artist:6dJeKm76NjfXBNTpHmOhfO'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3acnMNG6Um5zdLJgUOAKz8'},
#      'total_tracks': 20},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dJeKm76NjfXBNTpHmOhfO'},
#       'href': 'https://api.spotify.com/v1/artists/6dJeKm76NjfXBNTpHmOhfO',
#       'id': '6dJeKm76NjfXBNTpHmOhfO',
#       'name': 'Selena Gomez & The Scene',
#       'type': 'artist',
#       'uri': 'spotify:artist:6dJeKm76NjfXBNTpHmOhfO'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 188066,
#     'external_ids': {'isrc': 'USHR11132668'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3veFQzlEOTpcGGIbYPKdYq'},
#     'href': 'https://api.spotify.com/v1/tracks/3veFQzlEOTpcGGIbYPKdYq',
#     'id': '0laYHRpNTS6i8FXdupHkJ4',
#     'name': 'Love You Like A Love Song',
#     'popularity': 4,
#     'uri': 'spotify:track:0laYHRpNTS6i8FXdupHkJ4',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3veFQzlEOTpcGGIbYPKdYq'},
#      'href': 'https://api.spotify.com/v1/tracks/3veFQzlEOTpcGGIbYPKdYq',
#      'id': '3veFQzlEOTpcGGIbYPKdYq',
#      'type': 'track',
#      'uri': 'spotify:track:3veFQzlEOTpcGGIbYPKdYq'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-10-30T19:25:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/0af9ac246a60236b73e34854631a6c3de5cca602?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5Nwsra93UQYJ6xxcjcE10x',
#      'id': '5Nwsra93UQYJ6xxcjcE10x',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273633a2d775747bccfbcb17a45',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02633a2d775747bccfbcb17a45',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851633a2d775747bccfbcb17a45',
#        'width': 64}],
#      'name': 'Nine Track Mind',
#      'release_date': '2016-01-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5Nwsra93UQYJ6xxcjcE10x',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VuMaDnrHyPL1p4EHjYLi7'},
#        'href': 'https://api.spotify.com/v1/artists/6VuMaDnrHyPL1p4EHjYLi7',
#        'id': '6VuMaDnrHyPL1p4EHjYLi7',
#        'name': 'Charlie Puth',
#        'type': 'artist',
#        'uri': 'spotify:artist:6VuMaDnrHyPL1p4EHjYLi7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Nwsra93UQYJ6xxcjcE10x'},
#      'total_tracks': 13},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VuMaDnrHyPL1p4EHjYLi7'},
#       'href': 'https://api.spotify.com/v1/artists/6VuMaDnrHyPL1p4EHjYLi7',
#       'id': '6VuMaDnrHyPL1p4EHjYLi7',
#       'name': 'Charlie Puth',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VuMaDnrHyPL1p4EHjYLi7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#       'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#       'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#       'name': 'Selena Gomez',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#     'disc_number': 1,
#     'track_number': 5,
#     'duration_ms': 217706,
#     'external_ids': {'isrc': 'USAT21502909'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/06KyNuuMOX1ROXRhj787tj'},
#     'href': 'https://api.spotify.com/v1/tracks/06KyNuuMOX1ROXRhj787tj',
#     'id': '06KyNuuMOX1ROXRhj787tj',
#     'name': "We Don't Talk Anymore (feat. Selena Gomez)",
#     'popularity': 77,
#     'uri': 'spotify:track:06KyNuuMOX1ROXRhj787tj',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-04T20:44:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5maeycU97NHBgwRr2h2A4O',
#      'id': '5maeycU97NHBgwRr2h2A4O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a47c0e156ea3cebe37fdcab8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a47c0e156ea3cebe37fdcab8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a47c0e156ea3cebe37fdcab8',
#        'width': 64}],
#      'name': 'Born This Way (Special Edition)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5maeycU97NHBgwRr2h2A4O',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5maeycU97NHBgwRr2h2A4O'},
#      'total_tracks': 22},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 260252,
#     'external_ids': {'isrc': 'USUM71100638'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6r2BECwMgEoRb5yLfp0Hca'},
#     'href': 'https://api.spotify.com/v1/tracks/6r2BECwMgEoRb5yLfp0Hca',
#     'id': '30XU4suKzCeoCK9YFzdufg',
#     'name': 'Born This Way',
#     'popularity': 66,
#     'uri': 'spotify:track:30XU4suKzCeoCK9YFzdufg',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6r2BECwMgEoRb5yLfp0Hca'},
#      'href': 'https://api.spotify.com/v1/tracks/6r2BECwMgEoRb5yLfp0Hca',
#      'id': '6r2BECwMgEoRb5yLfp0Hca',
#      'type': 'track',
#      'uri': 'spotify:track:6r2BECwMgEoRb5yLfp0Hca'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-01-08T18:52:13Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/49dfe4ea78c5d3c5d2923d4a34c50fc4709855cb?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1nrVofqDRs7cpWXJ49qTnP',
#      'id': '1nrVofqDRs7cpWXJ49qTnP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730c471c36970b9406233842a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020c471c36970b9406233842a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510c471c36970b9406233842a5',
#        'width': 64}],
#      'name': 'SOS',
#      'release_date': '2022-12-08',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1nrVofqDRs7cpWXJ49qTnP',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#        'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#        'id': '7tYKF4w9nC0nq9CsPZTHyP',
#        'name': 'SZA',
#        'type': 'artist',
#        'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#      'total_tracks': 23},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#       'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#       'id': '7tYKF4w9nC0nq9CsPZTHyP',
#       'name': 'SZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 153946,
#     'external_ids': {'isrc': 'USRC12204584'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL'},
#     'href': 'https://api.spotify.com/v1/tracks/1Qrg8KqiBpW07V7PNxwwwL',
#     'id': '3OHfY25tqY28d16oZczHc8',
#     'name': 'Kill Bill',
#     'popularity': 86,
#     'uri': 'spotify:track:3OHfY25tqY28d16oZczHc8',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL'},
#      'href': 'https://api.spotify.com/v1/tracks/1Qrg8KqiBpW07V7PNxwwwL',
#      'id': '1Qrg8KqiBpW07V7PNxwwwL',
#      'type': 'track',
#      'uri': 'spotify:track:1Qrg8KqiBpW07V7PNxwwwL'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-02-08T15:09:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/2B9amdrHDIKOoEiPUfZGtb',
#      'id': '2B9amdrHDIKOoEiPUfZGtb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736b0b6e20fdb1ee07de7e92d6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026b0b6e20fdb1ee07de7e92d6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516b0b6e20fdb1ee07de7e92d6',
#        'width': 64}],
#      'name': 'yes, and?',
#      'release_date': '2024-01-12',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2B9amdrHDIKOoEiPUfZGtb',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#        'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#        'id': '66CXWjxzNUsdJxJ2JdwvnR',
#        'name': 'Ariana Grande',
#        'type': 'artist',
#        'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2B9amdrHDIKOoEiPUfZGtb'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 214994,
#     'external_ids': {'isrc': 'USUM72400048'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7gaA3wERFkFkgivjwbSvkG'},
#     'href': 'https://api.spotify.com/v1/tracks/7gaA3wERFkFkgivjwbSvkG',
#     'id': '7gaA3wERFkFkgivjwbSvkG',
#     'name': 'yes, and?',
#     'popularity': 74,
#     'uri': 'spotify:track:7gaA3wERFkFkgivjwbSvkG',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-04T20:44:20Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/237e17c6319aa02a1fde3ebcd89c5e5e3e03dbf8?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0gT5HL6RnvHBxJ2gY7lidR',
#      'id': '0gT5HL6RnvHBxJ2gY7lidR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273861f0d79ff28c0206bb34474',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02861f0d79ff28c0206bb34474',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851861f0d79ff28c0206bb34474',
#        'width': 64}],
#      'name': 'Warrior (Deluxe Version)',
#      'release_date': '2012-11-30',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0gT5HL6RnvHBxJ2gY7lidR',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LqNN22kT3074XbTVUrhzX'},
#        'href': 'https://api.spotify.com/v1/artists/6LqNN22kT3074XbTVUrhzX',
#        'id': '6LqNN22kT3074XbTVUrhzX',
#        'name': 'Kesha',
#        'type': 'artist',
#        'uri': 'spotify:artist:6LqNN22kT3074XbTVUrhzX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0gT5HL6RnvHBxJ2gY7lidR'},
#      'total_tracks': 16},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LqNN22kT3074XbTVUrhzX'},
#       'href': 'https://api.spotify.com/v1/artists/6LqNN22kT3074XbTVUrhzX',
#       'id': '6LqNN22kT3074XbTVUrhzX',
#       'name': 'Kesha',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LqNN22kT3074XbTVUrhzX'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 211920,
#     'external_ids': {'isrc': 'USRC11201008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6mnjcTmK8TewHfyOp3fC9C'},
#     'href': 'https://api.spotify.com/v1/tracks/6mnjcTmK8TewHfyOp3fC9C',
#     'id': '7EQGXaVSyEDsCWKmUcfpLk',
#     'name': 'Die Young',
#     'popularity': 5,
#     'uri': 'spotify:track:7EQGXaVSyEDsCWKmUcfpLk',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6mnjcTmK8TewHfyOp3fC9C'},
#      'href': 'https://api.spotify.com/v1/tracks/6mnjcTmK8TewHfyOp3fC9C',
#      'id': '6mnjcTmK8TewHfyOp3fC9C',
#      'type': 'track',
#      'uri': 'spotify:track:6mnjcTmK8TewHfyOp3fC9C'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-10-26T12:11:55Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/b571ceecaadc03941bdf4e683ea26e4e6d3f7c17?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3cQO7jp5S9qLBoIVtbkSM1',
#      'id': '3cQO7jp5S9qLBoIVtbkSM1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732df0d98a423025032d0db1f7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022df0d98a423025032d0db1f7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512df0d98a423025032d0db1f7',
#        'width': 64}],
#      'name': 'Blurryface',
#      'release_date': '2015-05-15',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3cQO7jp5S9qLBoIVtbkSM1',
# ...
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4N8pKPxsms7V8aXVjhIHcH'},
#      'total_tracks': 6},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5isusIcuKBmXxSja93hu7x'},
#       'href': 'https://api.spotify.com/v1/artists/5isusIcuKBmXxSja93hu7x',
#       'id': '5isusIcuKBmXxSja93hu7x',
#       'name': 'Robbie Tripp',
#       'type': 'artist',
#       'uri': 'spotify:artist:5isusIcuKBmXxSja93hu7x'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 114365,
#     'external_ids': {'isrc': 'QZNMV2454656'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6KhCaFJ1qqXG20uVg70YAQ'},
#     'href': 'https://api.spotify.com/v1/tracks/6KhCaFJ1qqXG20uVg70YAQ',
#     'id': '6KhCaFJ1qqXG20uVg70YAQ',
#     'name': 'PAUL WALKER',
#     'popularity': 27,
#     'uri': 'spotify:track:6KhCaFJ1qqXG20uVg70YAQ',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-05T01:14:24Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/916d773784dcfeaf0a3f47b0c6b58101615a5700?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/3zZSz5VOYSu0jE4MkPCOvN',
#      'id': '3zZSz5VOYSu0jE4MkPCOvN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a4fe49eb27e8152710e7a590',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a4fe49eb27e8152710e7a590',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a4fe49eb27e8152710e7a590',
#        'width': 64}],
#      'name': 'Girl on Fire (Remixes) - EP',
#      'release_date': '2012-11-18',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3zZSz5VOYSu0jE4MkPCOvN',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3DiDSECUqqY1AuBP8qtaIa'},
#        'href': 'https://api.spotify.com/v1/artists/3DiDSECUqqY1AuBP8qtaIa',
#        'id': '3DiDSECUqqY1AuBP8qtaIa',
#        'name': 'Alicia Keys',
#        'type': 'artist',
#        'uri': 'spotify:artist:3DiDSECUqqY1AuBP8qtaIa'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3zZSz5VOYSu0jE4MkPCOvN'},
#      'total_tracks': 4},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3DiDSECUqqY1AuBP8qtaIa'},
#       'href': 'https://api.spotify.com/v1/artists/3DiDSECUqqY1AuBP8qtaIa',
#       'id': '3DiDSECUqqY1AuBP8qtaIa',
#       'name': 'Alicia Keys',
#       'type': 'artist',
#       'uri': 'spotify:artist:3DiDSECUqqY1AuBP8qtaIa'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 224920,
#     'external_ids': {'isrc': 'USRC11201015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4esOae7i4rqTbAu9o5Pxco'},
#     'href': 'https://api.spotify.com/v1/tracks/4esOae7i4rqTbAu9o5Pxco',
#     'id': '4esOae7i4rqTbAu9o5Pxco',
#     'name': 'Girl on Fire',
#     'popularity': 74,
#     'uri': 'spotify:track:4esOae7i4rqTbAu9o5Pxco',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-13T12:56:48Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3ga4adzUpLaS2LDcoqfs2r',
#      'id': '3ga4adzUpLaS2LDcoqfs2r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739900b995cd1a81c35c574ab0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029900b995cd1a81c35c574ab0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519900b995cd1a81c35c574ab0',
#        'width': 64}],
#      'name': 'Who You Are (Platinum Edition)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3ga4adzUpLaS2LDcoqfs2r',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gsggkzM5R49q6jpPvazou'},
#        'href': 'https://api.spotify.com/v1/artists/2gsggkzM5R49q6jpPvazou',
#        'id': '2gsggkzM5R49q6jpPvazou',
#        'name': 'Jessie J',
#        'type': 'artist',
#        'uri': 'spotify:artist:2gsggkzM5R49q6jpPvazou'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3ga4adzUpLaS2LDcoqfs2r'},
#      'total_tracks': 16},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gsggkzM5R49q6jpPvazou'},
#       'href': 'https://api.spotify.com/v1/artists/2gsggkzM5R49q6jpPvazou',
#       'id': '2gsggkzM5R49q6jpPvazou',
#       'name': 'Jessie J',
#       'type': 'artist',
#       'uri': 'spotify:artist:2gsggkzM5R49q6jpPvazou'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ndkK3dpZLKtBklKjxNQwT'},
#       'href': 'https://api.spotify.com/v1/artists/5ndkK3dpZLKtBklKjxNQwT',
#       'id': '5ndkK3dpZLKtBklKjxNQwT',
#       'name': 'B.o.B',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ndkK3dpZLKtBklKjxNQwT'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 223053,
#     'external_ids': {'isrc': 'USUM71029357'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5mvKuE9Lf9ARVXVXA32kK9'},
#     'href': 'https://api.spotify.com/v1/tracks/5mvKuE9Lf9ARVXVXA32kK9',
#     'id': '2fTsFCKRFQ5M0igJgabnLA',
#     'name': 'Price Tag',
#     'popularity': 60,
#     'uri': 'spotify:track:2fTsFCKRFQ5M0igJgabnLA',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5mvKuE9Lf9ARVXVXA32kK9'},
#      'href': 'https://api.spotify.com/v1/tracks/5mvKuE9Lf9ARVXVXA32kK9',
#      'id': '5mvKuE9Lf9ARVXVXA32kK9',
#      'type': 'track',
#      'uri': 'spotify:track:5mvKuE9Lf9ARVXVXA32kK9'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-06-06T20:26:20Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/5221be592c832e14506f6304ff1deb6c52ae3fee?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1uyf3l2d4XYwiEqAb7t7fX',
#      'id': '1uyf3l2d4XYwiEqAb7t7fX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f6b55ca93bd33211227b502b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f6b55ca93bd33211227b502b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f6b55ca93bd33211227b502b',
#        'width': 64}],
#      'name': 'Doo-Wops & Hooligans',
#      'release_date': '2010-05-11',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1uyf3l2d4XYwiEqAb7t7fX',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1uyf3l2d4XYwiEqAb7t7fX'},
#      'total_tracks': 10},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 222091,
#     'external_ids': {'isrc': 'USAT21001883'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2tJulUYLDKOg9XrtVkMgcJ'},
#     'href': 'https://api.spotify.com/v1/tracks/2tJulUYLDKOg9XrtVkMgcJ',
#     'id': '4lLtanYk6tkMvooU0tWzG8',
#     'name': 'Grenade',
#     'popularity': 76,
#     'uri': 'spotify:track:4lLtanYk6tkMvooU0tWzG8',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2tJulUYLDKOg9XrtVkMgcJ'},
#      'href': 'https://api.spotify.com/v1/tracks/2tJulUYLDKOg9XrtVkMgcJ',
#      'id': '2tJulUYLDKOg9XrtVkMgcJ',
#      'type': 'track',
#      'uri': 'spotify:track:2tJulUYLDKOg9XrtVkMgcJ'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-09-19T16:08:10Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/74a14b8bc5d019c40321871ad15e024576d6dbfc?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2gRm1k9fVkhTfZDHvBI2sR',
#      'id': '2gRm1k9fVkhTfZDHvBI2sR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732341c852b4db72824c0e3185',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022341c852b4db72824c0e3185',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512341c852b4db72824c0e3185',
#        'width': 64}],
#      'name': 'Chris Brown',
#      'release_date': '2005-11-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2gRm1k9fVkhTfZDHvBI2sR',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#        'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#        'id': '7bXgB6jMjp9ATFy66eO08Z',
#        'name': 'Chris Brown',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2gRm1k9fVkhTfZDHvBI2sR'},
#      'total_tracks': 16},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#       'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#       'id': '7bXgB6jMjp9ATFy66eO08Z',
#       'name': 'Chris Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Uh8uJyN9g7oFjDK16nJgb'},
#       'href': 'https://api.spotify.com/v1/artists/6Uh8uJyN9g7oFjDK16nJgb',
#       'id': '6Uh8uJyN9g7oFjDK16nJgb',
#       'name': 'Juelz Santana',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Uh8uJyN9g7oFjDK16nJgb'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 229866,
#     'external_ids': {'isrc': 'USJI10500482'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6SPD3JwwRejBhCDiQAQ4he'},
#     'href': 'https://api.spotify.com/v1/tracks/6SPD3JwwRejBhCDiQAQ4he',
#     'id': '7xYnUQigPoIDAMPVK79NEq',
#     'name': 'Run It!',
#     'popularity': 0,
#     'uri': 'spotify:track:7xYnUQigPoIDAMPVK79NEq',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6SPD3JwwRejBhCDiQAQ4he'},
#      'href': 'https://api.spotify.com/v1/tracks/6SPD3JwwRejBhCDiQAQ4he',
#      'id': '6SPD3JwwRejBhCDiQAQ4he',
#      'type': 'track',
#      'uri': 'spotify:track:6SPD3JwwRejBhCDiQAQ4he'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2024-09-11T20:10:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maka_97'},
#     'href': 'https://api.spotify.com/v1/users/maka_97',
#     'id': 'maka_97',
#     'type': 'user',
#     'uri': 'spotify:user:maka_97'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/75e04ff0ccd2f2de413dbffb844bf29597fad1c0?cid=c918e9cb91e6468897ae9e248594eab0',
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/1GiqrzaIxZO3MRVZmyhkYc',
#      'id': '1GiqrzaIxZO3MRVZmyhkYc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733fcc7ee1ca4a5754a65fd28f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023fcc7ee1ca4a5754a65fd28f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513fcc7ee1ca4a5754a65fd28f',
#        'width': 64}],
#      'name': 'Mo Money (feat. Jadakiss)',
#      'release_date': '2023-10-06',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1GiqrzaIxZO3MRVZmyhkYc',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rPgMyrhTQgfLkTQF4JRtk'},
#        'href': 'https://api.spotify.com/v1/artists/6rPgMyrhTQgfLkTQF4JRtk',
#        'id': '6rPgMyrhTQgfLkTQF4JRtk',
#        'name': 'Justina Valentine',
#        'type': 'artist',
#        'uri': 'spotify:artist:6rPgMyrhTQgfLkTQF4JRtk'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5pnbUBPifNnlusY8kTBivi'},
#        'href': 'https://api.spotify.com/v1/artists/5pnbUBPifNnlusY8kTBivi',
#        'id': '5pnbUBPifNnlusY8kTBivi',
#        'name': 'Jadakiss',
#        'type': 'artist',
#        'uri': 'spotify:artist:5pnbUBPifNnlusY8kTBivi'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1GiqrzaIxZO3MRVZmyhkYc'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rPgMyrhTQgfLkTQF4JRtk'},
#       'href': 'https://api.spotify.com/v1/artists/6rPgMyrhTQgfLkTQF4JRtk',
#       'id': '6rPgMyrhTQgfLkTQF4JRtk',
#       'name': 'Justina Valentine',
#       'type': 'artist',
#       'uri': 'spotify:artist:6rPgMyrhTQgfLkTQF4JRtk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5pnbUBPifNnlusY8kTBivi'},
#       'href': 'https://api.spotify.com/v1/artists/5pnbUBPifNnlusY8kTBivi',
#       'id': '5pnbUBPifNnlusY8kTBivi',
#       'name': 'Jadakiss',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pnbUBPifNnlusY8kTBivi'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 186514,
#     'external_ids': {'isrc': 'USLD91751434'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/10resTtKxVLJNT0KnY4NFP'},
#     'href': 'https://api.spotify.com/v1/tracks/10resTtKxVLJNT0KnY4NFP',
#     'id': '10resTtKxVLJNT0KnY4NFP',
#     'name': 'Mo Money (feat. Jadakiss)',
#     'popularity': 42,
#     'uri': 'spotify:track:10resTtKxVLJNT0KnY4NFP',
#     'is_local': False},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/6mtYuOxzl58vSGnEDtZ9uB/tracks?offset=100&limit=100&market=DE&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 265}

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_pop['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_pop_df = pd.DataFrame(song_features)
# Keep relevant columns
df_pop = playlist_pop_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_pop["names"] = song_names

# Display the resulting DataFrame
display(df_pop)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/2304912813.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pop["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.623   0.734    -5.948       0.1070       0.01620
# 1          0.722   0.851    -3.873       0.0639       0.03190
# 2          0.706   0.691    -4.775       0.0633       0.05840
# 3          0.688   0.734    -4.569       0.0274       0.00462
# 4          0.749   0.729    -3.190       0.0321       0.26100
# ..           ...     ...       ...          ...           ...
# 95         0.482   0.706    -5.762       0.0607       0.13500
# 96         0.636   0.831    -3.945       0.1820       0.02940
# 97         0.704   0.558    -7.273       0.0542       0.14800
# 98         0.846   0.482    -6.721       0.1290       0.02460
# 99         0.571   0.746    -6.844       0.2990       0.11600
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000002    0.1450    0.370  107.853  76FZM38RC8XaAjJ77CVTNe
# 1           0.000000    0.1080    0.452  126.885  5yDL13y5giogKs2fSNf7sj
# 2           0.000070    0.0232    0.632  118.048  7DSAEUvxU8FajXtRloy8M0
# 3           0.000000    0.0756    0.460  140.004  2hns6Dv29Yrg68AVTJiAyA
# 4           0.000000    0.1130    0.816  111.004  3rUGC1vUpkDG9CZFHMur1t
# ..               ...       ...      ...      ...                     ...
# 95          0.001060    0.1050    0.144   92.513  4esOae7i4rqTbAu9o5Pxco
# 96          0.000004    0.2720    0.668  175.015  2fTsFCKRFQ5M0igJgabnLA
# 97          0.000000    0.1070    0.245  110.444  4lLtanYk6tkMvooU0tWzG8
# 98          0.000000    0.3930    0.212  100.969  7xYnUQigPoIDAMPVK79NEq
# 99          0.000000    0.6870    0.208  174.915  10resTtKxVLJNT0KnY4NFP
#
#     duration_ms                      names
# 0        244453                   Into You
# 1        197936              Glad You Came
# 2        200600                    Flowers
# 3        208493            Who Knew - Edit
# 4        131872                     greedy
# ..          ...                        ...
# 95       224920               Girl on Fire
# 96       223053                  Price Tag
# 97       222091                    Grenade
# 98       229867                    Run It!
# 99       186514  Mo Money (feat. Jadakiss)
#
# [100 rows x 12 columns]

# %%
playlist_great = sp.user_playlist_tracks("spotify", "3Q1DIJ51dJpUO6RhnIHdVx",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_great['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_great_df = pd.DataFrame(song_features)
# Keep relevant columns
df_great = playlist_great_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_great["names"] = song_names

# Display the resulting DataFrame
display(df_great)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/435938288.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_great["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.206   0.810    -6.492       0.0423      0.000059
# 1          0.508   0.720    -5.908       0.0628      0.272000
# 2          0.551   0.914    -4.063       0.0465      0.026300
# 3          0.567   0.490   -10.867       0.0414      0.790000
# 4          0.473   0.652   -10.171       0.0305      0.013200
# ..           ...     ...       ...          ...           ...
# 95         0.723   0.722   -13.763       0.0428      0.018400
# 96         0.622   0.865    -6.369       0.0531      0.016700
# 97         0.720   0.751    -4.485       0.0461      0.011300
# 98         0.816   0.508    -6.839       0.0643      0.078200
# 99         0.438   0.672    -4.706       0.0429      0.005500
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.064400    0.0855    0.155  163.552  2j7z87EnqB1NFQts2db0VR
# 1           0.000000    0.0563    0.472   79.983  2MfOcbtgz2yTsiznFmVZUN
# 2           0.000013    0.3470    0.543  119.994  0v1XpBHnsbkCn7iJ9Ucr1l
# 3           0.000014    0.0919    0.847  134.923  69RH84na5iUNwrwxpgjC5j
# 4           0.000011    0.1400    0.401  140.117  0wokCRaKD0zPNhMRXAgVsr
# ..               ...       ...      ...      ...                     ...
# 95          0.010600    0.0665    0.917   95.262  3CAWvns1fmJrNMPk4prasj
# 96          0.000023    0.0692    0.870  149.706  0PXw9NKvolWTo7U9JkNzmc
# 97          0.000000    0.3530    0.599  128.017  1r299qCKBLgUS9XJ9m1kEx
# 98          0.532000    0.0745    0.665  136.442  6COoRaCNma7V9sBf81y9EK
# 99          0.000000    0.0583    0.457  185.934  0zv9bOC2NSMd3Fw2HgM5Xn
#
#     duration_ms                                              names
# 0        268200                                       Don't Change
# 1        261640                                               Halo
# 2        224493                                       It's My Life
# 3        153333                              Where Did Our Love Go
# 4        340200                                     Ordinary World
# ..          ...                                                ...
# 95       251467                                          Rev It Up
# 96       227800  The Heat Is On - From "Beverly Hills Cop" Soun...
# 97       202640                                  Moves Like Jagger
# 98       202427                                   I Send A Message
# 99       227320                               Whataya Want from Me
#
# [100 rows x 12 columns]

# %%
playlist_all = sp.user_playlist_tracks("spotify", "0hdV9EPeOoLPLZ896PtxTf",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_all['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_all_df = pd.DataFrame(song_features)
# Keep relevant columns
df_all = playlist_all_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_all["names"] = song_names

# Display the resulting DataFrame
display(df_all)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/3722898300.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.513   0.868    -5.061       0.0410       0.01850
# 1          0.646   0.359   -10.388       0.1550       0.24700
# 2          0.825   0.652    -3.183       0.0802       0.58100
# 3          0.694   0.770    -5.335       0.1490       0.17600
# 4          0.730   0.769    -5.114       0.0298       0.13800
# ..           ...     ...       ...          ...           ...
# 95         0.581   0.963    -4.087       0.0981       0.02950
# 96         0.711   0.906    -2.671       0.0284       0.00952
# 97         0.666   0.830    -5.715       0.0751       0.01230
# 98         0.842   0.488    -7.856       0.0844       0.21800
# 99         0.704   0.558    -7.273       0.0542       0.14800
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.1210    0.367   92.009  1VU8t2MpJRLG5iFEIxqq7z
# 1           0.914000    0.0872    0.154  119.885  4YRvb9B8cgvhst11qk8CKn
# 2           0.000000    0.0931    0.931   95.977  7qiZfU4dY1lWllzX7mPBI3
# 3           0.000011    0.1180    0.163  125.905  0E9ZjEAyAwOXZ7wJC0PD33
# 4           0.000000    0.0473    0.507  104.948  4OSBTYWVwsQhGLF9NHvIbR
# ..               ...       ...      ...      ...                     ...
# 95          0.000000    0.1390    0.788  129.992  3cHyrEgdyYRjgJKSOiOtcS
# 96          0.000016    0.1530    0.824  125.916  12zpU2S4lMdrK9dvsOoL1m
# 97          0.000000    0.1910    0.702  113.030  6JV2JOEocMgcZxYSZelKcc
# 98          0.007180    0.0877    0.647  126.019  2dQzfKRaMKUCQgMpOtpLTh
# 99          0.000000    0.1070    0.245  110.444  4lLtanYk6tkMvooU0tWzG8
#
#     duration_ms                                              names
# 0        230467                                Geboren um zu leben
# 1        360147                                         Sonnentanz
# 2        233713                                       Shape of You
# 3        184560                                         In My Mind
# 4        228093                                Rolling in the Deep
# ..          ...                                                ...
# 95       204160                                             Timber
# 96       157153                       I Love It (feat. Charli XCX)
# 97       236002  CAN'T STOP THE FEELING! (from DreamWorks Anima...
# 98       164955                           Bella Ciao - HUGEL Remix
# 99       222091                                            Grenade
#
# [100 rows x 12 columns]

# %%
playlist_creed = sp.user_playlist_tracks("spotify", "0OOq0aLWcdpwiTcFBXKzAL",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_creed['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_creed_df = pd.DataFrame(song_features)
# Keep relevant columns
df_creed = playlist_creed_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_creed["names"] = song_names

# Display the resulting DataFrame
display(df_creed)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/2710275187.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_creed["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.702   0.499    -9.883       0.0713      0.565000
# 1          0.873   0.812    -5.550       0.1250      0.016500
# 2          0.675   0.758    -4.589       0.0368      0.431000
# 3          0.672   0.573    -7.708       0.2770      0.000268
# 4          0.840   0.744    -4.751       0.1130      0.018100
# 5          0.834   0.922    -3.916       0.1590      0.010400
# 6          0.604   0.743    -4.555       0.0717      0.072400
# 7          0.617   0.986    -1.844       0.4840      0.004800
# 8          0.599   0.755    -7.273       0.2600      0.137000
# 9          0.472   0.836    -5.408       0.4420      0.167000
# 10         0.645   0.677    -6.579       0.0424      0.029300
# 11         0.892   0.483    -7.413       0.0879      0.041000
# 12         0.589   0.465    -7.029       0.4990      0.271000
# 13         0.711   0.617    -6.211       0.1450      0.114000
# 14         0.853   0.797    -5.387       0.2130      0.089400
# 15         0.490   0.484    -9.410       0.1980      0.150000
# 16         0.596   0.450   -10.257       0.3470      0.250000
# 17         0.495   0.495    -7.764       0.3730      0.122000
# 18         0.764   0.573    -7.856       0.0549      0.030600
# 19         0.716   0.665    -6.862       0.1610      0.077300
# 20         0.670   0.445    -8.311       0.0284      0.590000
# 21         0.584   0.529    -9.762       0.3330      0.056600
# 22         0.290   0.327    -8.113       0.0324      0.859000
# 23         0.702   0.499    -9.883       0.0713      0.565000
# 24         0.670   0.956    -4.381       0.1600      0.177000
# 25         0.939   0.486    -3.488       0.2070      0.172000
# 26         0.434   0.695    -7.464       0.4850      0.016800
# 27         0.819   0.856    -3.449       0.1700      0.264000
# 28         0.286   0.426   -11.843       0.0464      0.252000
# 29         0.853   0.791    -5.105       0.2860      0.003660
# 30         0.715   0.702    -7.710       0.0439      0.000324
# 31         0.700   0.735    -2.356       0.0576      0.009070
# 32         0.698   0.707    -3.778       0.1140      0.284000
# 33         0.772   0.879    -3.423       0.0395      0.021900
# 34         0.780   0.852    -1.333       0.1760      0.025800
# 35         0.545   0.975    -3.193       0.4540      0.170000
# 36         0.522   0.592    -2.982       0.0344      0.034800
# 37         0.786   0.820    -5.093       0.2320      0.222000
# 38         0.520   0.338   -12.001       0.0904      0.738000
# 39         0.140   0.195   -16.307       0.0344      0.526000
# 40         0.435   0.395   -14.091       0.0618      0.736000
# 41         0.307   0.503   -13.071       0.1040      0.270000
# 42         0.647   0.609    -5.020       0.1600      0.287000
# 43         0.388   0.558    -7.476       0.0707      0.471000
# 44         0.913   0.797    -4.260       0.0763      0.037300
# 45         0.561   0.779    -5.107       0.0531      0.086200
# 46         0.216   0.395    -8.486       0.0344      0.838000
# 47         0.675   0.810    -7.863       0.2410      0.055300
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000006    0.2330   0.4000  110.006  6G45nT1iMlP1HdJ0MCTuDU
# 1           0.000787    0.1130   0.4990  138.028  1kn9JsBWIw6qREhDWw0lKb
# 2           0.001770    0.3770   0.1520   89.982  4oBX7V6xzWYAkf0fw9V8Ln
# 3           0.000000    0.1090   0.6930  179.953  5vZDl7Jr6GmtJjnziKSBqN
# 4           0.000000    0.6290   0.1710   83.737  2tUL6dZf1mywCj5WvCPZw6
# 5           0.000003    0.1400   0.8680  149.977  6gJ1T7THE0Pxk5VpTovwJH
# 6           0.000000    0.3310   0.1290  124.196  3yz5heVHn1jYrGwZkbdg54
# 7           0.000831    0.5590   0.6020  150.040  4Ja9nYFkfPS7D9qiZFMUrH
# 8           0.000000    0.2000   0.4210   94.345  7BG1Wlc6CjHuwvUg0XzGNw
# 9           0.000000    0.0979   0.4440  195.565  5Mkbqot9JUaN5XhRgqITME
# 10          0.000484    0.1140   0.3370  117.925  3ZQpXYZZFRQyRgopMptRje
# 11          0.000000    0.0389   0.9150   98.043  72Cn4VmfpwAZk3NHVEplYx
# 12          0.000000    0.1110   0.4140   94.047  25aUa8vgKi4NqwxQ4cfcrD
# 13          0.000000    0.0920   0.5270   88.945  6UAAyb8l3kLwwxvIrXOGRp
# 14          0.000000    0.1580   0.5750  149.940  7m3Cr9XyaYyW0toevY8dur
# 15          0.000016    0.1550   0.0895  142.987  5TYevEkYmkzTf5Qum7Gsdw
# 16          0.000015    0.1150   0.3830   80.261  7KjGW8d7sKtQe9x2WGlnsD
# 17          0.000012    0.0957   0.7420   78.539  499Em55SsNJE2jG4Lk58iO
# 18          0.000000    0.3600   0.2380  150.006  20IRcGD2o073obIyPJQxIl
# 19          0.000000    0.2160   0.6480  112.233  22hdnPB5hmyzOJLQQrcDSS
# 20          0.000277    0.0912   0.3450  103.045  2iPnYQRutwTQopudwgkIfm
# 21          0.000000    0.3170   0.3460   83.716  5CRnOqHHcREG9NPtq7xHge
# 22          0.000000    0.1090   0.1560   81.565  11xvUC6z70mrZvQAOLx33H
# 23          0.000006    0.2330   0.4000  110.006  3l0A1CoWWjSKipvS6Yzu5Y
# 24          0.000036    0.7260   0.3370  173.966  1iP5UMdOsGz6EdltGbbcb7
# 25          0.000000    0.2640   0.5170   97.582  1iQ5E4z6CJ38dIzvMI9Wdo
# 26          0.000000    0.8340   0.1600  167.309  57hCSu4zMTdnSum7NBL1Ye
# 27          0.000000    0.0744   0.4330  110.006  4khXn5hwGSpI7iPvtxSr40
# 28          0.005870    0.0459   0.0579  114.540  5ytCOdv25AKBSYZTHqeijO
# 29          0.000000    0.3540   0.3360  140.007  1iFN9GbSzkj2nRNxz5NxbK
# 30          0.000000    0.1300   0.2860  109.957  3lMxvnPMQRiQDXp6KAQiDE
# 31          0.000000    0.7640   0.3490  124.058  79PaeaCZXyeu2C5XeSBzIv
# 32          0.000000    0.1770   0.4130  155.009  74wpYGsVh2J13iAmmg1Uln
# 33          0.000000    0.1480   0.4310  139.972  3ddFdBlBbu15hcJmEK0tLd
# 34          0.000003    0.1830   0.5230  141.030  16Of5hPEODN84py9a7lCUl
# 35          0.000000    0.1450   0.6090  123.906  23dwrzeJtEEGl2U4CPWSor
# 36          0.000000    0.3650   0.2560  135.880  5kUMB8d7Xa6X7VNe8qTY9k
# 37          0.000000    0.5750   0.4900  119.982  22nyEAEM29tcBRhukR089b
# 38          0.290000    0.1110   0.0702  149.892  0haX1okP3ZHnhWPzDAUipW
# 39          0.869000    0.0813   0.0380   94.317  1Ps1H1hS80nWmx1U5jvhH4
# 40          0.263000    0.0906   0.3130   81.928  3zvaqAx3kylRmr6UexKeu7
# 41          0.002840    0.0802   0.0950  134.758  7ckSHKZnX72c6IQnKGJNpi
# 42          0.000282    0.8370   0.2910  163.957  3e9R23BvUPW7gbPfboiDIx
# 43          0.155000    0.1350   0.1620  163.911  701RVIizxCUMCO92CfcPby
# 44          0.000066    0.5650   0.4040  120.024  5lJxsHYZS7ZPv41fpykFzX
# 45          0.000000    0.0780   0.2350   81.965  0At2qAoaVjIwWNAqrscXli
# 46          0.024500    0.0995   0.1340   71.502  63Ml8YT7zsBURne0fFsdv4
# 47          0.007950    0.3440   0.4810   85.034  1hKQtfw99LLivX3vH1adZJ
#
#     duration_ms                                              names
# 0        222507  Blood, Sweat & Tears (with Bas & Black Sherif ...
# 1        167000                                             Ma Boy
# 2        239800                                        Last Breath
# 3        194463                                              Check
# 4        204347                         No Friends In The Industry
# 5        250537  We Can Hit (Round 1) (with Crime Mob & Slim Jx...
# 6        175161                                     Sinner & Saint
# 7        173600                   Take A Sip - Dodge & Fuski Remix
# 8        125886  Anthem (with Big Sean & EST Gee) - Soundtrack ...
# 9         95903      Adonis Interlude (The Montage) (with J. Cole)
# 10       193285                          Greater (with Ari Lennox)
# 11       150535                    Ogogoro (with Bas & Ayra Starr)
# 12       127200                          Just Face It (with Blxst)
# 13       164494  Headhunters (with WESTSIDE BOOGIE & Cozz feat....
# 14       233899    Jack (with EARTHGANG feat. Buddy & Ant Clemons)
# 15       312168         Hate Me Now (with Arin Ray, Mereba & Omen)
# 16       202695       Talk To Me (with Omen, Ari Lennox & OG DAYV)
# 17       208733                        Lay Up (with SiR feat. Syd)
# 18       179625            Long The Way (with Morray & jetsonmade)
# 19       172626  In The Room (with JID, Tierra Whack & BJ The C...
# 20       173840                             Shadows (with Kehlani)
# 21       253597  Burn Bridges (with Lute, Cozz, REASON & Arin Ray)
# 22       182341                 Heavy Is The Head (with Baby Rose)
# 23       222507  Blood, Sweat & Tears (with Bas & Black Sherif ...
# 24       221067                       The Fire (feat. John Legend)
# 25       206547                                        The Watcher
# 26       318840                      Lord Knows (feat. Tory Lanez)
# 27       205091                                Don't Waste My Time
# 28       294925                     Lord Knows / Fighting Stronger
# 29       260516  Kill 'Em With Success (with Eearz, ScHoolboy Q...
# 30       215933                                         Intolerant
# 31       262885                  Fate (with Young Thug & Swae Lee)
# 32       247688        The Mantra (with Pharrell & Kendrick Lamar)
# 33       257252      Watching Me (with Rae Sremmurd & Kodak Black)
# 34       390999  F.I.G.H.T. (with Eearz, Gucci Mane, YG, Troubl...
# 35       131674  Runnin (with A$AP Rocky, A$AP Ferg & Nicki Minaj)
# 36       210564                  Love Me Like That (Champion Love)
# 37       220996                                               Icon
# 38        97160                                   I Will Go to War
# 39       328547                                     It's Your Time
# 40       130467                                           Ice Cold
# 41       304587            Runnin (feat. A$AP Rocky & Jacob Banks)
# 42       121171           Amen (Pre Fight Prayer) (with Lil Wayne)
# 43       125082  Ice Cold (Final Round) (with Vince Staples & L...
# 44       195000                                     Work Ya Muscle
# 45       256064                                           Boo'd Up
# 46       199960                                           Shed You
# 47       186618               Take A Sip - Tha Boogie Bandit Remix

# %%
playlist_crossfit = sp.user_playlist_tracks("spotify", "2tgHGy6VpMrrOt1hZANdMV",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_crossfit['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_crossfit_df = pd.DataFrame(song_features)
# Keep relevant columns
df_crossfit = playlist_crossfit_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_crossfit["names"] = song_names

# Display the resulting DataFrame
display(df_crossfit)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/380910750.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_crossfit["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.692   0.780    -6.353       0.0496       0.00412
# 1          0.577   0.981    -4.119       0.0497       0.02400
# 2          0.592   0.772    -6.225       0.1110       0.00829
# 3          0.848   0.629    -6.198       0.0424       0.01600
# 4          0.575   0.940    -6.268       0.0369       0.00173
# ..           ...     ...       ...          ...           ...
# 95         0.715   0.914    -3.870       0.2140       0.02540
# 96         0.653   0.893    -3.869       0.0347       0.00269
# 97         0.608   0.722    -5.550       0.1070       0.00791
# 98         0.707   0.936    -4.955       0.0505       0.00275
# 99         0.552   0.915    -4.421       0.0616       0.13900
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.001270    0.3140   0.4460  122.001  3dHxz2xClaQdyh8KuZIwrr
# 1           0.000597    0.0650   0.4260  160.007  6rN2xoEkfOeYFfMGVCV6Vv
# 2           0.000002    0.1940   0.1680  174.043  1S86edXaWV2NyMs0czlQqj
# 3           0.180000    0.0490   0.5860  130.017  0agQ9vIV7NP4dntGKLcCXO
# 4           0.728000    0.3250   0.1540  130.011  6Yimrlg9ndHZUy1hGm6uQ9
# ..               ...       ...      ...      ...                     ...
# 95          0.000000    0.0961   0.5650  125.826  3hENlPbIlUZXQ3MiosF87Q
# 96          0.000622    0.6190   0.5660  127.974  5o2clcNEa8fPKEbURHqHoV
# 97          0.000028    0.3150   0.1210  128.009  22SXyL6pUjwIvGWvgGjLov
# 98          0.818000    0.2390   0.0371  126.022  62fEHY4gVP9nelMQTvf3Be
# 99          0.949000    0.1460   0.1260  160.020  56gJHV1MkyHIS4eDFbzoVa
#
#     duration_ms                                          names
# 0        224262                                   I Wanna Know
# 1        195375                                    Wild & Free
# 2        212080                                Break The Alarm
# 3        153519                                Somebody (2024)
# 4        134846                                           Wild
# ..          ...                                            ...
# 95       179048                                 Cutting Shapes
# 96       296107  Blame (feat. John Newman) - Jacob Plant Remix
# 97       252933       Can't Feel My Face - Martin Garrix Remix
# 98       320517                                             M1
# 99       236351                                        Waiting
#
# [100 rows x 12 columns]

# %%
playlist_german = sp.user_playlist_tracks("spotify", "0KwsbLDSEy7A5P9xHn1qGu",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_german['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_german_df = pd.DataFrame(song_features)
# Keep relevant columns
df_german = playlist_german_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_german["names"] = song_names

# Display the resulting DataFrame
display(df_german)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/3516699473.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_german["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.676   0.937    -7.756       0.0754        0.2640
# 1          0.510   0.917    -4.806       0.0854        0.0054
# 2          0.505   0.833    -7.815       0.3500        0.1030
# 3          0.637   0.969    -4.534       0.0418        0.0154
# 4          0.483   0.911    -4.645       0.0486        0.0218
# ..           ...     ...       ...          ...           ...
# 68         0.930   0.607   -10.389       0.0457        0.0526
# 69         0.645   0.722    -4.574       0.0291        0.3200
# 70         0.656   0.807    -6.148       0.0300        0.3040
# 71         0.537   0.756    -8.783       0.0599        0.0837
# 72         0.537   0.786    -9.333       0.1130        0.2880
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.742000    0.6980    0.655  120.161  3svmi1v7HMlyYb7Pnossz6
# 1           0.000133    0.3960    0.313   75.098  3gVhsZtseYtY1fMuyYq06F
# 2           0.053900    0.6120    0.138  164.934  5E3BK90EQQxmrDz3zLG2l9
# 3           0.000048    0.0455    0.467  139.965  6ba5jsjL6Ed8FZICtXEB3f
# 4           0.000008    0.1940    0.944  184.882  4hYinIaRxdaoEFSQni6K6I
# ..               ...       ...      ...      ...                     ...
# 68          0.000005    0.0390    0.950  118.242  3TBRJsLCcwroEkA3tD4u2N
# 69          0.000000    0.1710    0.407   92.014  2ZoO0uLQRp2WhTlyIH8PJf
# 70          0.000000    0.2530    0.907  129.736  6QfxUvYrvQey2KwK4r4Rao
# 71          0.000248    0.0879    0.617  179.996  1Z6JcXlTUaPSmiVkN2530P
# 72          0.877000    0.1270    0.315  174.987  08tcRsFVnWVHm4fpYe7q02
#
#     duration_ms                names
# 0        109049        Fahrradsattel
# 1        272440                Sonne
# 2        120840        Schmetterling
# 3        226507         Doktorspiele
# 4        236200         Nur ein Wort
# ..          ...                  ...
# 68       232588        Der Kommissar
# 69       227520               Lieder
# 70       203840  Nacht voll Schatten
# 71       191000            Wellblech
# 72       170769   Nimm mir die Angst
#
# [73 rows x 12 columns]

# %%
playlist_schlager = sp.user_playlist_tracks("spotify", "5lS5fb5u4xAL0qhcuJRVpm",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_schlager['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_schlager_df = pd.DataFrame(song_features)
# Keep relevant columns
df_schlager = playlist_schlager_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_schlager["names"] = song_names

# Display the resulting DataFrame
display(df_schlager)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/1502838282.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_schlager["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.687   0.693    -4.856       0.0569        0.0124
# 1          0.675   0.966    -2.940       0.0313        0.3700
# 2          0.732   0.827    -4.934       0.0355        0.1720
# 3          0.699   0.813    -4.717       0.0968        0.5870
# 4          0.727   0.826    -5.505       0.0347        0.1800
# ..           ...     ...       ...          ...           ...
# 91         0.727   0.534    -8.101       0.0289        0.3670
# 92         0.615   0.812    -4.052       0.0773        0.0620
# 93         0.828   0.850    -5.849       0.1800        0.0541
# 94         0.599   0.992    -3.506       0.0969        0.0128
# 95         0.796   0.828    -4.007       0.0544        0.1570
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000054    0.1080    0.442  128.030  5mWceciQV51RPCBQCLAm3U
# 1           0.056500    0.0242    0.897  120.023  5nu6DLPJ91h2lSKQuPDzYd
# 2           0.000000    0.3520    0.774  129.993  4FZmjzFP31JGVPnpWanMEo
# 3           0.000000    0.1100    0.636  119.981  3PeZRzO7dHCWFCOCv6HoGe
# 4           0.000000    0.0655    0.929  132.948  2Nv773K16hckJrb3Ir7wOu
# ..               ...       ...      ...      ...                     ...
# 91          0.000048    0.1520    0.889  137.037  4fzDuDVOiOTg56O1BjtDVM
# 92          0.000000    0.2260    0.375  127.968  06sSAsjNx4eJawyXY3SXgB
# 93          0.000061    0.1940    0.822  124.006  3sxpjRUXC3MPhPuOCRkxAC
# 94          0.000000    0.3830    0.372  138.105  3DQ4U7YOBorXDyaGraMBE7
# 95          0.000004    0.0373    0.899   97.994  2HzCMR260KYuHo8vdWSUSN
#
#     duration_ms                             names
# 0        205653                         Herzbeben
# 1        255720        1000 Träume weit (Tornero)
# 2        188027              Idiot - Version 2011
# 3        217847                        Achterbahn
# 4        222333                          Wahnsinn
# ..          ...                               ...
# 91       193402                      Die Schenste
# 92       203000  Vamos a Marte (feat. Luis Fonsi)
# 93       197366                             Ibiza
# 94       241800         Kölsche Jung - Party Edit
# 95       170771                       Ich Sax Dir
#
# [96 rows x 12 columns]

# %%
playlist_80s = sp.user_playlist_tracks("spotify", "37i9dQZF1DX4UtSsGT1Sbe",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_80s['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_80s_df = pd.DataFrame(song_features)
# Keep relevant columns
df_80s = playlist_80s_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_80s["names"] = song_names

# Display the resulting DataFrame
display(df_80s)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/950459842.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_80s["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.527   0.942    -5.640       0.0366       0.01150
# 1          0.640   0.852    -8.119       0.0345       0.02430
# 2          0.660   0.629   -12.359       0.0387       0.43200
# 3          0.685   0.584   -10.616       0.0276       0.29000
# 4          0.573   0.902    -7.638       0.0540       0.01800
# ..           ...     ...       ...          ...           ...
# 95         0.664   0.613    -7.560       0.0273       0.00294
# 96         0.418   0.452   -13.099       0.0355       0.63800
# 97         0.529   0.932    -7.501       0.0488       0.00251
# 98         0.408   0.480   -11.017       0.0266       0.15500
# 99         0.526   0.978    -5.436       0.1080       0.00122
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.1880    0.495  148.723  7FwBtcecmlpc1sLySPXeGE
# 1           0.000002    0.0497    0.793  122.902  37Q5anxoGWYdRsyeXkkNoI
# 2           0.000073    0.1720    0.324  111.926  2v7ywbUzCgcVohHaKUcacV
# 3           0.010000    0.1240    0.940  134.546  5vmRQ3zELMLUQPo2FLQ76x
# 4           0.001250    0.0928    0.876   84.412  2WfaOiMkCvy7F5fcp2zZ8L
# ..               ...       ...      ...      ...                     ...
# 95          0.000129    0.1750    0.193   96.600  1GjbTNFImFrjFsNdleDe78
# 96          0.000252    0.0959    0.168  175.124  54b8qPFqYqIndfdxiLApea
# 97          0.001090    0.1360    0.571  138.158  71SvEDmsOwIWw1IozsZoMA
# 98          0.000018    0.0877    0.190  156.344  5WwqdeavrQrbeAMDxGawse
# 99          0.000048    0.0744    0.451  141.167  05RgAMGypEvqhNs5hPCbMS
#
#     duration_ms                       names
# 0        241307         Dancing In the Dark
# 1        246520  Heaven Is A Place On Earth
# 2        340867               Like a Prayer
# 3        302413               Smalltown Boy
# 4        225280                  Take on Me
# ..          ...                         ...
# 95       184587         Never Tear Us Apart
# 96       218733                       Alone
# 97       201693         Any Way You Want It
# 98       294773    Can't Fight This Feeling
# 99       210227      Panama - 2015 Remaster
#
# [100 rows x 12 columns]

# %%
playlist_90s = sp.user_playlist_tracks("spotify", "37i9dQZF1DXbTxeAdrVG2l",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_90s['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_90s_df = pd.DataFrame(song_features)
# Keep relevant columns
df_90s = playlist_90s_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_90s["names"] = song_names

# Display the resulting DataFrame
display(df_90s)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/2055389410.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_90s["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.704   0.636    -6.029       0.0252       0.03440
# 1          0.713   0.678    -3.525       0.1020       0.27300
# 2          0.865   0.665    -6.289       0.0730       0.04530
# 3          0.439   0.434   -14.918       0.0265       0.07830
# 4          0.520   0.709    -7.125       0.0352       0.24700
# ..           ...     ...       ...          ...           ...
# 95         0.395   0.843    -4.476       0.0374       0.00483
# 96         0.859   0.905    -5.539       0.1290       0.20500
# 97         0.777   0.601    -5.931       0.1260       0.04060
# 98         0.383   0.662    -5.162       0.0333       0.16500
# 99         0.897   0.611   -10.489       0.2110       0.02910
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.3500    0.890  111.845  7aQjPecQdIuNd1sz3KCDhD
# 1           0.000000    0.1490    0.734  138.009  7H6ev70Weq6DdpZyyTmUXk
# 2           0.000000    0.2240    0.331  111.113  1ofhfV90EnYhEr7Un2fWiv
# 3           0.000052    0.1400    0.204   94.843  0gEyKnHvgkrkBM6fbeHdwK
# 4           0.000018    0.1800    0.536   76.039  6urCAbunOQI4bLhmGpX7iS
# ..               ...       ...      ...      ...                     ...
# 95          0.000000    0.0404    0.481  112.423  0nnwn7LWHCAu09jfuH1xTA
# 96          0.008370    0.3220    0.731   89.946  3wuCCNCnBhJlwkIJTBZFiv
# 97          0.002010    0.0348    0.680   97.911  3XKIUb7HzIF1Vu9usunMzc
# 98          0.000000    0.2480    0.138  121.154  225xvV8r1yKMHErSWivnow
# 99          0.186000    0.0894    0.769  102.304  1oTHteQbmJw15rPxPVXUTv
#
#     duration_ms                                              names
# 0        193953                                           Lovefool
# 1        271333                                        Say My Name
# 2        268827                                            Changes
# 3        274707                                             Linger
# 4        263560                                        Don't Speak
# ..          ...                                                ...
# 95       212067                                              Slide
# 96       284160                           They Don't Care About Us
# 97       261973                Maria Maria (feat. The Product G&B)
# 98       298760  I Don't Want to Miss a Thing - From "Armageddo...
# 99       208267                                Insane in the Brain
#
# [100 rows x 12 columns]

# %%
playlist_00s = sp.user_playlist_tracks("spotify", "37i9dQZF1DX4o1oenSJRJd",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_00s['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_00s_df = pd.DataFrame(song_features)
# Keep relevant columns
df_00s = playlist_00s_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_00s["names"] = song_names

# Display the resulting DataFrame
display(df_00s)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/952687612.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_00s["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.352   0.911    -5.230       0.0747       0.00121
# 1          0.434   0.422   -13.964       0.0375       0.13400
# 2          0.662   0.741    -5.406       0.0334       0.00165
# 3          0.894   0.791    -4.699       0.1120       0.01830
# 4          0.730   0.849    -5.281       0.0299       0.00234
# ..           ...     ...       ...          ...           ...
# 95         0.652   0.609    -7.519       0.0370       0.26300
# 96         0.632   0.924    -1.802       0.2900       0.28100
# 97         0.556   0.913    -2.360       0.0437       0.01930
# 98         0.791   0.733    -5.215       0.0520       0.14700
# 99         0.712   0.772    -3.024       0.3460       0.05210
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.0995    0.236  148.033  003vvx7Niy0yvhvHt4a68B
# 1           0.000021    0.0861    0.377  123.201  3FAclTFfvUuQYnEsptbK8w
# 2           0.030300    0.1140    0.404  131.000  3xrn9i8zhNZsTtcoWgQEAd
# 3           0.000000    0.0388    0.583  105.018  5rb9QrpfcKFHM1EUbSIurX
# 4           0.000026    0.3120    0.887  117.308  4tKGFmENO69tZR9ahgZu48
# ..               ...       ...      ...      ...                     ...
# 95          0.001010    0.2330    0.482   95.986  0KQx6HOpJueiSkztcS0r7D
# 96          0.000000    0.2630    0.441   86.844  7LR85XLWw2yXqKBSI5brbG
# 97          0.000009    0.3460    0.730   96.184  10Nmj3JCNoMeBQ87uw5j8k
# 98          0.000381    0.0713    0.761  114.980  7jk7gqyEonmVVYahZN5zhW
# 99          0.000004    0.0368    0.848   84.722  3G0yz3DZn3lfraledmBCT0
#
#     duration_ms                     names
# 0        222973            Mr. Brightside
# 1        241293             Back To Black
# 2        188960         Since U Been Gone
# 3        250373                     Yeah!
# 4        230013  Murder On The Dancefloor
# ..          ...                       ...
# 95       210200                   Fallin'
# 96       267520             Run This Town
# 97       282160           Dani California
# 98       192360                    Circus
# 99       249480                  P.I.M.P.
#
# [100 rows x 12 columns]

# %%
playlist_10s = sp.user_playlist_tracks("spotify", "37i9dQZF1DX5Ejj0EkURtP",market="DE")

# %%
list_of_songs = []
song_names = []

# Loop through the list of tracks
for item in playlist_10s['items']:
    track = item['track']
    list_of_songs.append(track["id"]) 
    song_names.append(track["name"])

# Fetch audio features for the collected track IDs
song_features = sp.audio_features(list_of_songs)
# Convert the features to a DataFrame
playlist_10s_df = pd.DataFrame(song_features)
# Keep relevant columns
df_10s = playlist_10s_df[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]
# Add song names to the DataFrame
df_10s["names"] = song_names

# Display the resulting DataFrame
display(df_10s)
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15306/2722821163.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10s["names"] = song_names
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.686   0.702    -5.325       0.0455       0.00637
# 1          0.755   0.837    -2.718       0.1420       0.09910
# 2          0.612   0.807    -2.810       0.0336       0.04950
# 3          0.558   0.559    -9.222       0.0959       0.37100
# 4          0.628   0.593    -5.036       0.0323       0.09300
# ..           ...     ...       ...          ...           ...
# 95         0.781   0.445    -6.061       0.0295       0.47400
# 96         0.516   0.595    -4.630       0.0313       0.02750
# 97         0.732   0.396    -9.348       0.0286       0.08410
# 98         0.782   0.685    -6.237       0.0309       0.16600
# 99         0.694   0.712    -3.923       0.0460       0.13200
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000045     0.204    0.290  129.948  12KUFSHFgT0XCoiSlvdQi4
# 1           0.000000     0.289    0.714  120.028  0HPD5WQqrq7wPWR7P7Dw1i
# 2           0.017700     0.101    0.398  124.053  2QjOHCTQ1Jl3zawyYOpxh6
# 3           0.000007     0.109    0.620   78.558  7KA4W4McWYRpgf0fWsJZWB
# 4           0.000002     0.096    0.104  125.025  7xoUc6faLbCqZO6fQEYprd
# ..               ...       ...      ...      ...                     ...
# 95          0.000000     0.184    0.591   78.998  34gCuhDGsG4bRPIf9bb02f
# 96          0.000000     0.109    0.222  119.972  5Ohxk2dO5COHF1krpoPigN
# 97          0.000036     0.105    0.548   90.024  6i0V12jOa3mr6uu4WYhUBr
# 98          0.000012     0.160    0.603  118.020  7vFoFDWqTX0mHzLfrF1Cfy
# 99          0.000000     0.211    0.799   98.023  1rIKgCH4H52lrvDcz50hS8
#
#     duration_ms                                         names
# 0        214840                                    Break Free
# 1        199693                                       TiK ToK
# 2        240400                               Sweater Weather
# 3        180387              See You Again (feat. Kali Uchis)
# 4        197267                                 One Last Time
# ..          ...                                           ...
# 95       281560                             Thinking out Loud
# 96       340707                             Sign of the Times
# 97       195920                                      Heathens
# 98       180566  Cheerleader (Felix Jaehn Remix) - Radio Edit
# 99       201122                                     Lush Life
#
# [100 rows x 12 columns]

# %%
# List of DataFrames to concatenate
dfs = [df_all, df_great, df_pop, df_motivation, df_rock, df_creed, df_crossfit, df_german, df_schlager, df_80s, df_90s, df_00s, df_10s]
merged_df = pd.concat(dfs, ignore_index=True)

# Display
display(merged_df)
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.513   0.868    -5.061       0.0410        0.0185
# 1            0.646   0.359   -10.388       0.1550        0.2470
# 2            0.825   0.652    -3.183       0.0802        0.5810
# 3            0.694   0.770    -5.335       0.1490        0.1760
# 4            0.730   0.769    -5.114       0.0298        0.1380
# ...            ...     ...       ...          ...           ...
# 1212         0.781   0.445    -6.061       0.0295        0.4740
# 1213         0.516   0.595    -4.630       0.0313        0.0275
# 1214         0.732   0.396    -9.348       0.0286        0.0841
# 1215         0.782   0.685    -6.237       0.0309        0.1660
# 1216         0.694   0.712    -3.923       0.0460        0.1320
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000    0.1210    0.367   92.009  1VU8t2MpJRLG5iFEIxqq7z
# 1             0.914000    0.0872    0.154  119.885  4YRvb9B8cgvhst11qk8CKn
# 2             0.000000    0.0931    0.931   95.977  7qiZfU4dY1lWllzX7mPBI3
# 3             0.000011    0.1180    0.163  125.905  0E9ZjEAyAwOXZ7wJC0PD33
# 4             0.000000    0.0473    0.507  104.948  4OSBTYWVwsQhGLF9NHvIbR
# ...                ...       ...      ...      ...                     ...
# 1212          0.000000    0.1840    0.591   78.998  34gCuhDGsG4bRPIf9bb02f
# 1213          0.000000    0.1090    0.222  119.972  5Ohxk2dO5COHF1krpoPigN
# 1214          0.000036    0.1050    0.548   90.024  6i0V12jOa3mr6uu4WYhUBr
# 1215          0.000012    0.1600    0.603  118.020  7vFoFDWqTX0mHzLfrF1Cfy
# 1216          0.000000    0.2110    0.799   98.023  1rIKgCH4H52lrvDcz50hS8
#
#       duration_ms                                         names
# 0          230467                           Geboren um zu leben
# 1          360147                                    Sonnentanz
# 2          233713                                  Shape of You
# 3          184560                                    In My Mind
# 4          228093                           Rolling in the Deep
# ...           ...                                           ...
# 1212       281560                             Thinking out Loud
# 1213       340707                             Sign of the Times
# 1214       195920                                      Heathens
# 1215       180566  Cheerleader (Felix Jaehn Remix) - Radio Edit
# 1216       201122                                     Lush Life
#
# [1217 rows x 12 columns]

# %%
# Save the merged DataFrame to a CSV file
merged_df.to_csv('playlist.csv', index=False)

# %%
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.513   0.868    -5.061       0.0410       0.01850
# 1          0.646   0.359   -10.388       0.1550       0.24700
# 2          0.825   0.652    -3.183       0.0802       0.58100
# 3          0.694   0.770    -5.335       0.1490       0.17600
# 4          0.730   0.769    -5.114       0.0298       0.13800
# ..           ...     ...       ...          ...           ...
# 95         0.581   0.963    -4.087       0.0981       0.02950
# 96         0.711   0.906    -2.671       0.0284       0.00952
# 97         0.666   0.830    -5.715       0.0751       0.01230
# 98         0.842   0.488    -7.856       0.0844       0.21800
# 99         0.704   0.558    -7.273       0.0542       0.14800
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.1210    0.367   92.009  1VU8t2MpJRLG5iFEIxqq7z
# 1           0.914000    0.0872    0.154  119.885  4YRvb9B8cgvhst11qk8CKn
# 2           0.000000    0.0931    0.931   95.977  7qiZfU4dY1lWllzX7mPBI3
# 3           0.000011    0.1180    0.163  125.905  0E9ZjEAyAwOXZ7wJC0PD33
# 4           0.000000    0.0473    0.507  104.948  4OSBTYWVwsQhGLF9NHvIbR
# ..               ...       ...      ...      ...                     ...
# 95          0.000000    0.1390    0.788  129.992  3cHyrEgdyYRjgJKSOiOtcS
# 96          0.000016    0.1530    0.824  125.916  12zpU2S4lMdrK9dvsOoL1m
# 97          0.000000    0.1910    0.702  113.030  6JV2JOEocMgcZxYSZelKcc
# 98          0.007180    0.0877    0.647  126.019  2dQzfKRaMKUCQgMpOtpLTh
# 99          0.000000    0.1070    0.245  110.444  4lLtanYk6tkMvooU0tWzG8
#
#     duration_ms                                              names
# 0        230467                                Geboren um zu leben
# 1        360147                                         Sonnentanz
# 2        233713                                       Shape of You
# 3        184560                                         In My Mind
# 4        228093                                Rolling in the Deep
# ..          ...                                                ...
# 95       204160                                             Timber
# 96       157153                       I Love It (feat. Charli XCX)
# 97       236002  CAN'T STOP THE FEELING! (from DreamWorks Anima...
# 98       164955                           Bella Ciao - HUGEL Remix
# 99       222091                                            Grenade
#
# [100 rows x 12 columns]
