# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('../data/playlist.csv')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1217 entries, 0 to 1216
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      1217 non-null   float64
#  1   energy            1217 non-null   float64
#  2   loudness          1217 non-null   float64
#  3   speechiness       1217 non-null   float64
#  4   acousticness      1217 non-null   float64
#  5   instrumentalness  1217 non-null   float64
#  6   liveness          1217 non-null   float64
#  7   valence           1217 non-null   float64
#  8   tempo             1217 non-null   float64
#  9   id                1217 non-null   object
#  10  duration_ms       1217 non-null   int64
#  11  names             1217 non-null   object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 114.2+ KB
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.513   0.868    -5.061       0.0410        0.0185
# 1            0.646   0.359   -10.388       0.1550        0.2470
# 2            0.825   0.652    -3.183       0.0802        0.5810
# 3            0.694   0.770    -5.335       0.1490        0.1760
# 4            0.730   0.769    -5.114       0.0298        0.1380
# ...            ...     ...       ...          ...           ...
# 1212         0.781   0.445    -6.061       0.0295        0.4740
# 1213         0.516   0.595    -4.630       0.0313        0.0275
# 1214         0.732   0.396    -9.348       0.0286        0.0841
# 1215         0.782   0.685    -6.237       0.0309        0.1660
# 1216         0.694   0.712    -3.923       0.0460        0.1320
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000    0.1210    0.367   92.009  1VU8t2MpJRLG5iFEIxqq7z
# 1             0.914000    0.0872    0.154  119.885  4YRvb9B8cgvhst11qk8CKn
# 2             0.000000    0.0931    0.931   95.977  7qiZfU4dY1lWllzX7mPBI3
# 3             0.000011    0.1180    0.163  125.905  0E9ZjEAyAwOXZ7wJC0PD33
# 4             0.000000    0.0473    0.507  104.948  4OSBTYWVwsQhGLF9NHvIbR
# ...                ...       ...      ...      ...                     ...
# 1212          0.000000    0.1840    0.591   78.998  34gCuhDGsG4bRPIf9bb02f
# 1213          0.000000    0.1090    0.222  119.972  5Ohxk2dO5COHF1krpoPigN
# 1214          0.000036    0.1050    0.548   90.024  6i0V12jOa3mr6uu4WYhUBr
# 1215          0.000012    0.1600    0.603  118.020  7vFoFDWqTX0mHzLfrF1Cfy
# 1216          0.000000    0.2110    0.799   98.023  1rIKgCH4H52lrvDcz50hS8
#
#       duration_ms                                         names
# 0          230467                           Geboren um zu leben
# 1          360147                                    Sonnentanz
# 2          233713                                  Shape of You
# 3          184560                                    In My Mind
# 4          228093                           Rolling in the Deep
# ...           ...                                           ...
# 1212       281560                             Thinking out Loud
# 1213       340707                             Sign of the Times
# 1214       195920                                      Heathens
# 1215       180566  Cheerleader (Felix Jaehn Remix) - Radio Edit
# 1216       201122                                     Lush Life
#
# [1217 rows x 12 columns]

# %%
# Select relevant acoustic features for clustering
features = ["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "duration_ms"]

# Scale the features
scaler = StandardScaler()
X = scaler.fit_transform(df[features])
X
# Out:
# array([[-0.81274261,  0.74119329,  0.39393673, ..., -0.74532936,
#         -1.25824041,  0.12086739],
#        [ 0.1111962 , -2.30489875, -1.59264786, ..., -1.60638606,
#         -0.14117642,  2.62843753],
#        [ 1.3546928 , -0.55145088,  1.09429451, ...,  1.53465177,
#         -1.0992323 ,  0.18363399],
#        ...,
#        [ 0.70863032, -2.08347359, -1.2048033 , ..., -0.01363329,
#         -1.33778453, -0.54715409],
#        [ 1.05597574, -0.35396357, -0.04462596, ...,  0.2087053 ,
#         -0.21591183, -0.84404823],
#        [ 0.4446478 , -0.19238305,  0.81832818, ...,  1.00103916,
#         -1.01724375, -0.4465651 ]])

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans
# Set number of clusters
kmeans = KMeans(n_clusters=3, random_state=7)
# Fit the model
kmeans.fit(X)
# Predict cluster labels
pred = kmeans.predict(X)

# Visualize the clusters
plt.scatter(X[:, 0], X[:, 1], c=pred, alpha=0.5)
plt.title('K-Means Clustering')
plt.show()

# %%
# Calculate Silhouette Score to evaluate the quality of clustering
from sklearn.metrics import silhouette_score
print("K-Means Silhouette Score: {}".format(silhouette_score(X, pred, metric='euclidean')))
# Out:
# K-Means Silhouette Score: 0.13697345854297996

# %% [markdown]
# Since the K-Means Silhoutte score is 0.137 and thus really low and indicating that the clustering may not be very effective at grouping the songs into well-defined clusters.

# %%
from yellowbrick.cluster import KElbowVisualizer

# Use KElbowVisualizer to find the optimal number of clusters for KMeans
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,20))
visualizer.fit(X)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ## Agglomerative Clustering

# %%
from sklearn import cluster

# Agglomerative Clustering with 'ward' linkage
agglomerative = cluster.AgglomerativeClustering(n_clusters=3, linkage='ward')
pred = agglomerative.fit_predict(X)

# Visualize the clusters
plt.scatter(X[:, 0], X[:, 1], c=pred, alpha=0.5)
plt.title('Agglomerative Clustering')
plt.show()

# %%
# Calculate Silhouette Score
print("Agglomerative Clustering Silhouette Score: {}".format(silhouette_score(X, pred, metric='euclidean')))
# Out:
# Agglomerative Clustering Silhouette Score: 0.25203026452954236

# %% [markdown]
# Agglomerative Clustering Silhouette Score of 0.252 is a slight improvement on the k-means result.

# %%
# Try different linkage methods for Agglomerative Clustering
linkages = ['ward', 'single', 'complete', 'average']

for linkage in linkages:
    agglomerative = cluster.AgglomerativeClustering(n_clusters=3, linkage=linkage)
    pred = agglomerative.fit_predict(X)
    score = silhouette_score(X, pred, metric='euclidean')
    print(f"Linkage: {linkage}, Silhouette Score: {score}")
# Out:
# Linkage: ward, Silhouette Score: 0.25203026452954236
# Linkage: single, Silhouette Score: 0.45701724757733464
# Linkage: complete, Silhouette Score: 0.15880624243472122
# Linkage: average, Silhouette Score: 0.4332168938963849

# %% [markdown]
# With a linkage = single, the silhouette score performs the best at 0.
# but single is not appropriate
# so, we take 2nd best silhouette score of 0.4332168938963849 for average

# %%
agglomerative = cluster.AgglomerativeClustering(n_clusters=3, linkage='average')
pred = agglomerative.fit_predict(X)

# Visualize the clusters
plt.scatter(X[:, 0], X[:, 1], c=pred, alpha=0.5)
plt.title('Agglomerative Clustering')
plt.show()

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from yellowbrick.cluster import KElbowVisualizer

# Elbow Method for finding the optimal number of clusters
model = cluster.AgglomerativeClustering(linkage='average')
visualizer = KElbowVisualizer(model, k=(2,20))
visualizer.fit(X)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# Use 4 clusters as indicated by the Elbow Method
agglomerative = cluster.AgglomerativeClustering(n_clusters=5, linkage='average')
pred_5 = agglomerative.fit_predict(X)

# Visualize the clustering results
plt.scatter(X[:, 0], X[:, 1], c=pred_5, alpha=0.5)
plt.title('Agglomerative Clustering with 4 Clusters')
plt.show()

# %%
# Calculate the Silhouette Score for 5 clusters
sil_score_5 = silhouette_score(X, pred_5, metric='euclidean')
print(f"Silhouette Score for Agglomerative Clustering with 15 Clusters: {sil_score_5}")
# Out:
# Silhouette Score for Agglomerative Clustering with 15 Clusters: 0.3264895535839765

# %% [markdown]
# ideal clustering = 3, linkage = average with 0.4332 as Silhouette Score

# %%
display(pred)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
unique = np.unique(pred)
unique
# Out:
# array([0, 1, 2])

# %%
df
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.513   0.868    -5.061       0.0410        0.0185
# 1            0.646   0.359   -10.388       0.1550        0.2470
# 2            0.825   0.652    -3.183       0.0802        0.5810
# 3            0.694   0.770    -5.335       0.1490        0.1760
# 4            0.730   0.769    -5.114       0.0298        0.1380
# ...            ...     ...       ...          ...           ...
# 1212         0.781   0.445    -6.061       0.0295        0.4740
# 1213         0.516   0.595    -4.630       0.0313        0.0275
# 1214         0.732   0.396    -9.348       0.0286        0.0841
# 1215         0.782   0.685    -6.237       0.0309        0.1660
# 1216         0.694   0.712    -3.923       0.0460        0.1320
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000    0.1210    0.367   92.009  1VU8t2MpJRLG5iFEIxqq7z
# 1             0.914000    0.0872    0.154  119.885  4YRvb9B8cgvhst11qk8CKn
# 2             0.000000    0.0931    0.931   95.977  7qiZfU4dY1lWllzX7mPBI3
# 3             0.000011    0.1180    0.163  125.905  0E9ZjEAyAwOXZ7wJC0PD33
# 4             0.000000    0.0473    0.507  104.948  4OSBTYWVwsQhGLF9NHvIbR
# ...                ...       ...      ...      ...                     ...
# 1212          0.000000    0.1840    0.591   78.998  34gCuhDGsG4bRPIf9bb02f
# 1213          0.000000    0.1090    0.222  119.972  5Ohxk2dO5COHF1krpoPigN
# 1214          0.000036    0.1050    0.548   90.024  6i0V12jOa3mr6uu4WYhUBr
# 1215          0.000012    0.1600    0.603  118.020  7vFoFDWqTX0mHzLfrF1Cfy
# 1216          0.000000    0.2110    0.799   98.023  1rIKgCH4H52lrvDcz50hS8
#
#       duration_ms                                         names
# 0          230467                           Geboren um zu leben
# 1          360147                                    Sonnentanz
# 2          233713                                  Shape of You
# 3          184560                                    In My Mind
# 4          228093                           Rolling in the Deep
# ...           ...                                           ...
# 1212       281560                             Thinking out Loud
# 1213       340707                             Sign of the Times
# 1214       195920                                      Heathens
# 1215       180566  Cheerleader (Felix Jaehn Remix) - Radio Edit
# 1216       201122                                     Lush Life
#
# [1217 rows x 12 columns]

# %%
columns = ["id","names"]
name = df[columns]
name
# Out:
#                           id                                         names
# 0     1VU8t2MpJRLG5iFEIxqq7z                           Geboren um zu leben
# 1     4YRvb9B8cgvhst11qk8CKn                                    Sonnentanz
# 2     7qiZfU4dY1lWllzX7mPBI3                                  Shape of You
# 3     0E9ZjEAyAwOXZ7wJC0PD33                                    In My Mind
# 4     4OSBTYWVwsQhGLF9NHvIbR                           Rolling in the Deep
# ...                      ...                                           ...
# 1212  34gCuhDGsG4bRPIf9bb02f                             Thinking out Loud
# 1213  5Ohxk2dO5COHF1krpoPigN                             Sign of the Times
# 1214  6i0V12jOa3mr6uu4WYhUBr                                      Heathens
# 1215  7vFoFDWqTX0mHzLfrF1Cfy  Cheerleader (Felix Jaehn Remix) - Radio Edit
# 1216  1rIKgCH4H52lrvDcz50hS8                                     Lush Life
#
# [1217 rows x 2 columns]

# %%
features = ["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "duration_ms"]

features = df[features]
features
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.513   0.868    -5.061       0.0410        0.0185
# 1            0.646   0.359   -10.388       0.1550        0.2470
# 2            0.825   0.652    -3.183       0.0802        0.5810
# 3            0.694   0.770    -5.335       0.1490        0.1760
# 4            0.730   0.769    -5.114       0.0298        0.1380
# ...            ...     ...       ...          ...           ...
# 1212         0.781   0.445    -6.061       0.0295        0.4740
# 1213         0.516   0.595    -4.630       0.0313        0.0275
# 1214         0.732   0.396    -9.348       0.0286        0.0841
# 1215         0.782   0.685    -6.237       0.0309        0.1660
# 1216         0.694   0.712    -3.923       0.0460        0.1320
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000000    0.1210    0.367   92.009       230467
# 1             0.914000    0.0872    0.154  119.885       360147
# 2             0.000000    0.0931    0.931   95.977       233713
# 3             0.000011    0.1180    0.163  125.905       184560
# 4             0.000000    0.0473    0.507  104.948       228093
# ...                ...       ...      ...      ...          ...
# 1212          0.000000    0.1840    0.591   78.998       281560
# 1213          0.000000    0.1090    0.222  119.972       340707
# 1214          0.000036    0.1050    0.548   90.024       195920
# 1215          0.000012    0.1600    0.603  118.020       180566
# 1216          0.000000    0.2110    0.799   98.023       201122
#
# [1217 rows x 10 columns]

# %%
features["cluster"] = pred
# Out:
# /var/folders/1p/3nvyb0qn4zbfkzm72nmsffqh0000gn/T/ipykernel_15506/2072673538.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features["cluster"] = pred

# %%
df = pd.concat([features, name], axis = 1)

# %%
display(df.head(50))
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0
# 13  0lKyMPBRuIDCX56NORu5NZ                   Die immer lacht - Radio 2016 Mix
# 14  7bolFIVYrui4h98GEK0MIK                                       Geiles Leben
# 15  3dYD57lRAUcMHufyqn9GcI                                  Take Me To Church
# 16  60nZcImufyMA1MKQY3dcCH                     Happy - From "Despicable Me 2"
# 17  7DFSnCBYlus7i4U9KKlbdU                                           No Roots
# 18  2IxixfQUSQkwCCblJT3Eq1                                        Heavy Cross
# 19  7vFoFDWqTX0mHzLfrF1Cfy       Cheerleader (Felix Jaehn Remix) - Radio Edit
# 20  2RB1n3NWUmG5X0rdihAQ3e  Waka Waka (This Time for Africa) [The Official...
# 21  4255amV4enzl28KAn16rUO                                    Are You with Me
# 22  3ZSqMer9RLSglvi18bWXYV                                       Sky and Sand
# 23  1HNkqx9Ahdgi1Ixy2xkKkL                                         Photograph
# 24  1rfofaqEpACxVEHIZBJe6W                          Havana (feat. Young Thug)
# 25  0nrRP2bk19rLc0orkWPQk2                                         Wake Me Up
# 26  3WlVUkLgGYByiGj8gF4erq                                    I Follow Rivers
# 27  2CbuG4ib5Wg5q8AEhVgll7  Ma Chérie - DJ Antoine Vs Mad Mark 2K12 Radio ...
# 28  1zB4vmk8tFRmM9UULNzbLB                                            Thunder
# 29  5fnA9mkIfScSqHIpeDyvck              Prayer in C - Robin Schulz Radio Edit
# 30  4icNLSquKZp6e0iEkBn9RP                                  Glow - Radio Edit
# 31  3di5hcvxxciiqwMH1jarhY                               Set Fire to the Rain
# 32  0eZBeB2xFIS65jQHerispi                               The Sound of Silence
# 33  3c8iiZGfEammKJuWTErE5x  Ain't Nobody (Loves Me Better) (feat. Jasmine ...
# 34  1I8tHoNBFTuoJAlh4hfVVE                                          Firestone
# 35  4yDjzVhXig9tfO7Zv46FE8                                   Over the Rainbow
# 36  7DnAm9FOTWE3cUvso43HhI                                   Sweet but Psycho
# 37  7qEHsqek33rTcFNT9PFqLf                                  Someone You Loved
# 38  1rqqCSm0Qe4I9rUvWncaom                                         High Hopes
# 39  3bidbhpOYeV4knp8AIu8Xn                   Can't Hold Us (feat. Ray Dalton)
# 40  0mlAOSILGRys2IbvyOT5VJ                                    Échame La Culpa
# 41  0Oe49j06Bjrxs8PltuVeaW                          On The Floor - Radio Edit
# 42  5RfxjgQMne0dRNiORcLtMg                                            Wolke 4
# 43  6RUKPb4LETWmmr3iAEQktW                           Something Just Like This
# 44  7mitXLIMCflkhZiD34uEQI                                  Party Rock Anthem
# 45  1HFfMOxCAT4GAwaPfCdmUs                    Waves - Robin Schulz Radio Edit
# 46  2GYHyAoLWpkxLVa4oYTVko                        Alors on danse - Radio Edit
# 47  1CmUZGtH29Kx36C1Hleqlz                           Thrift Shop (feat. Wanz)
# 48  20I6sIOMTCkB6w7ryavxtO                                      Call Me Maybe
# 49  2YWjW3wwQIBLNhxWKBQd16                      Lean On (feat. MØ & DJ Snake)

# %%
df.cluster.value_counts()
# Out:
# cluster
# 0    1212
# 2       4
# 1       1
# Name: count, dtype: int64
